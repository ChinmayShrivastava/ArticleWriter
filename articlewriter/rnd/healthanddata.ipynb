# %%
from chromadb import PersistentClient
from chromadb.utils import embedding_functions
import os

topic = 'healthanddata'

chroma_client = PersistentClient(path=f"data/{topic}/storage")
emb_fn = embedding_functions.OpenAIEmbeddingFunction(
    api_key='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',
    model_name="text-embedding-ada-002"
)

# %%
desc = {
    'fullform': 'Healthcare and the related data laws and breaches',
}
topic_collection = chroma_client.get_or_create_collection(name=topic, embedding_function=emb_fn, metadata={"hnsw:space": "cosine"})

# %%
topic_collection.peek()
# Out:
# {'ids': [],
#  'embeddings': [],
#  'metadatas': [],
#  'documents': [],
#  'uris': None,
#  'data': None}

# %%
import sys
sys.path.append('..')
from prompts.general import PROMPT_TO_EXTRACT_TRIPLETS
print(PROMPT_TO_EXTRACT_TRIPLETS)
# Out:
# Some text is provided below related to <<topic>>. Given the text, to better understand <<requirement>>, extract up to <<num_triplets>> knowledge triplets in the form of (parent_topic, relation_type, topic). Avoid stopwords.
# ---------------------
# Example:Text: <<FIRST_CHUNK_EX>>Triplets:
# <<FIRST_CHUNK_TRIPLETS>>
# Text: <<SECOND_CHUNK_EX>>Triplets:
# <<SECOND_CHUNK_TRIPLETS>>
# ---------------------
# Text: {text}
# Triplets:

# %%
num_triplets = 5
requirement = 'understand the implications of the act on the organizations and how they can comply with the act'
first_chunk = """The bill grouped personal data into different categories and required elevated levels of protection for “sensitive” and “critical” personal data. Certain businesses were also to be categorized as “significant data fiduciaries,” and additional obligations were proposed for them—registration in India, data audits, and data impact assessments."""
first_triplets = (
    "(personal data, grouped into, different categories - sensitive and critical)\n"
    "(certain businesses, to be categorized as, significant data fiduciaries)\n"
    "(significant data fiduciaries, to require, additional obligations - registration in India, data audits, and data impact assessments)\n"
)
second_chunk = """The DPDP Act applies to Indian residents and businesses collecting the data of Indian residents. Interestingly, it also applies to non-citizens living in India whose data processing “in connection with any activity related to offering of goods or services” happens outside India."""
second_triplets = (
    "(DPDP Act, applies to, Indian residents and businesses collecting the data of Indian residents)\n"
    "(DPDP Act, applies to, non-citizens living in India whose data processing in connection with any activity related to offering of goods or services happens outside India)\n"
)
prompt = PROMPT_TO_EXTRACT_TRIPLETS.replace("<<topic>>", topic).replace("<<requirement>>", requirement).replace("<<FIRST_CHUNK_EX>>", first_chunk).replace("<<FIRST_CHUNK_TRIPLETS>>", first_triplets).replace("<<SECOND_CHUNK_EX>>", second_chunk).replace("<<SECOND_CHUNK_TRIPLETS>>", second_triplets).replace("<<num_triplets>>", str(num_triplets))
print(prompt)
# Out:
# Some text is provided below related to healthanddata. Given the text, to better understand understand the implications of the act on the organizations and how they can comply with the act, extract up to 5 knowledge triplets in the form of (parent_topic, relation_type, topic). Avoid stopwords.
# ---------------------
# Example:Text: The bill grouped personal data into different categories and required elevated levels of protection for “sensitive” and “critical” personal data. Certain businesses were also to be categorized as “significant data fiduciaries,” and additional obligations were proposed for them—registration in India, data audits, and data impact assessments.Triplets:
# (personal data, grouped into, different categories - sensitive and critical)
# (certain businesses, to be categorized as, significant data fiduciaries)
# (significant data fiduciaries, to require, additional obligations - registration in India, data audits, and data impact assessments)
#
# Text: The DPDP Act applies to Indian residents and businesses collecting the data of Indian residents. Interestingly, it also applies to non-citizens living in India whose data processing “in connection with any activity related to offering of goods or services” happens outside India.Triplets:
# (DPDP Act, applies to, Indian residents and businesses collecting the data of Indian residents)
# (DPDP Act, applies to, non-citizens living in India whose data processing in connection with any activity related to offering of goods or services happens outside India)
#
# ---------------------
# Text: {text}
# Triplets:

# %%
from llama_index.llms import OpenAI
llm = OpenAI(model="gpt-3.5-turbo")

# %%
resp = llm.complete(prompt)
print(resp.text)
# Out:
# (organizations, implications of, the act)
# (organizations, how to comply with, the act)
# (the act, requires, elevated levels of protection)
# (the act, categorizes, personal data into different categories)
# (the act, proposes, additional obligations for certain businesses)

# %%
from llama_index import SimpleDirectoryReader

reader = SimpleDirectoryReader(input_dir="data/healthanddata/documents")
documents = reader.load_data()

# %%
from llama_index.node_parser import SentenceSplitter

# parse nodes
parser = SentenceSplitter()
nodes = parser.get_nodes_from_documents(documents)

# %%
nodes
# Out:
# [TextNode(id_='e61cce3d-30c9-4f59-b423-ae4b9be4f158', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='50e5d18c-4157-4241-9d9d-3681059475ae', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='e99f098b0263295575797b8a8c9310c06fbb97317fbfd7f6ad20c83a47d25732')}, hash='9402219c6207a9d41053503c185a1ba6cdac3366c3c7c117f3403ddbc7505cff', text='Go to:\nAbstract\nThe introduction of Big Data Analytics (BDA) in healthcare will allow to use new technologies both in treatment of patients and health management. The paper aims at analyzing the possibilities of using Big Data Analytics in healthcare. The research is based on a critical analysis of the literature, as well as the presentation of selected results of direct research on the use of Big Data Analytics in medical facilities. The direct research was carried out based on research questionnaire and conducted on a sample of 217 medical facilities in Poland. Literature studies have shown that the use of Big Data Analytics can bring many benefits to medical facilities, while direct research has shown that medical facilities in Poland are moving towards data-based healthcare because they use structured and unstructured data, reach for analytics in the administrative, business and clinical area. The research positively confirmed that medical facilities are working on both structural data and unstructured data. The following kinds and sources of data can be distinguished: from databases, transaction data, unstructured content of emails and documents, data from devices and sensors. However, the use of data from social media is lower as in their activity they reach for analytics, not only in the administrative and business but also in the clinical area. It clearly shows that the decisions made in medical facilities are highly data-driven. The results of the study confirm what has been analyzed in the literature that medical facilities are moving towards data-based healthcare, together with its benefits.\n\nKeywords: Big Data, Big Data Analytics, Data-driven healthcare\nGo to:\nIntroduction\nThe main contribution of this paper is to present an analytical overview of using structured and unstructured data (Big Data) analytics in medical facilities in Poland. Medical facilities use both structured and unstructured data in their practice. Structured data has a predetermined schema, it is extensive, freeform, and comes in variety of forms [27]. In contrast, unstructured data, referred to as Big Data (BD), does not fit into the typical data processing format. Big Data is a massive amount of data sets that cannot be stored, processed, or analyzed using traditional tools. It remains stored but not analyzed. Due to the lack of a well-defined schema, it is difficult to search and analyze such data and, therefore, it requires a specific technology and method to transform it into value [20, 68]. Integrating data stored in both structured and unstructured formats can add significant value to an organization [27]. Organizations must approach uns ...
#  TextNode(id_='50e5d18c-4157-4241-9d9d-3681059475ae', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='e61cce3d-30c9-4f59-b423-ae4b9be4f158', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='9402219c6207a9d41053503c185a1ba6cdac3366c3c7c117f3403ddbc7505cff'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='bad6a865-0420-4701-97ae-8c18a495136b', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8df6fa7e1b48c282b79a68689230b561c10a9f8abd5c93d5b149512424a0467d')}, hash='e99f098b0263295575797b8a8c9310c06fbb97317fbfd7f6ad20c83a47d25732', text='The next challenges that healthcare will have to face is the growing number of elderly people and a decline in fertility. Fertility rates in the country are found below the reproductive minimum necessary to keep the population stable [10]. The reflection of both effects, namely the increase in age and lower fertility rates, are demographic load indicators, which is constantly growing. Forecasts show that providing healthcare in the form it is provided today will become impossible in the next 20 years [70]. It is especially visible now during the Covid-19 pandemic when healthcare faced quite a challenge related to the analysis of huge data amounts and the need to identify trends and predict the spread of the coronavirus. The pandemic showed it even more that patients should have access to information about their health condition, the possibility of digital analysis of this data and access to reliable medical support online. Health monitoring and cooperation with doctors in order to prevent diseases can actually revolutionize the healthcare system. One of the most important aspects of the change necessary in healthcare is putting the patient in the center of the system.\n\nTechnology is not enough to achieve these goals. Therefore, changes should be made not only at the technological level but also in the management and design of complete healthcare processes and what is more, they should affect the business models of service providers. The use of Big Data Analytics is becoming more and more common in enterprises [17, 54]. However, medical enterprises still cannot keep up with the information needs of patients, clinicians, administrators and the creator’s policy. The adoption of a Big Data approach would allow the implementation of personalized and precise medicine based on personalized information, delivered in real time and tailored to individual patients.\n\nTo achieve this goal, it is necessary to implement systems that will be able to learn quickly about the data generated by people within clinical care and everyday life. This will enable data-driven decision making, receiving better personalized predictions about prognosis and responses to treatments; a deeper understanding of the complex factor ...
#  TextNode(id_='bad6a865-0420-4701-97ae-8c18a495136b', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='50e5d18c-4157-4241-9d9d-3681059475ae', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='e99f098b0263295575797b8a8c9310c06fbb97317fbfd7f6ad20c83a47d25732'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='94dbee40-40b2-42b0-a2bb-8b8bbf91b256', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='ee34aa96cb017a5a1d53b663b021619c315feb36bf2b83e18aa6013e53af4923')}, hash='8df6fa7e1b48c282b79a68689230b561c10a9f8abd5c93d5b149512424a0467d', text='The next part involves the explanation of the proposed method. The result of direct research and discussion are presented in the fifth part, while the following part of the paper is the conclusion. The seventh part of the paper presents practical implications. The final section of the paper provides limitations and directions for future research.\n\nGo to:\nConsiderations on use Big Data and Big Data Analytics in the healthcare\nIn recent years one can observe a constantly increasing demand for solutions offering effective analytical tools. This trend is also noticeable in the analysis of large volumes of data (Big Data, BD). Organizations are looking for ways to use the power of Big Data to improve their decision making, competitive advantage or business performance [7, 54]. Big Data is considered to offer potential solutions to public and private organizations, however, still not much is known about the outcome of the practical use of Big Data in different types of organizations [24].\n\nAs already mentioned, in recent years, healthcare management worldwide has been changed from a disease-centered model to a patient-centered model, even in value-based healthcare delivery model [68]. In order to meet the requirements of this model and provide effective patient-centered care, it is necessary to manage and analyze healthcare Big Data.\n\nThe issue often raised when it comes to the use of data in healthcare is the appropriate use of Big Data. Healthcare has always generated huge amounts of data and nowadays, the introduction of electronic medical records, as well as the huge amount of data sent by various types of sensors or generated by patients in social media causes data streams to constantly grow. Also, the medical industry generates significant amounts of data, including clinical records, medical images, genomic data and health behaviors. Proper use of the data will allow healthcare organizations to support clinical decision-making, disease surveillance, and public health management. The challenge posed by clinical data processing involves not only the quantity of data but also the difficulty in processing it.\n\nIn the literature one can find many different definitions of Big Data. This concept  ...
#  TextNode(id_='94dbee40-40b2-42b0-a2bb-8b8bbf91b256', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='bad6a865-0420-4701-97ae-8c18a495136b', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='8df6fa7e1b48c282b79a68689230b561c10a9f8abd5c93d5b149512424a0467d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2cf02359-f9ed-4832-ac44-5b423174d750', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='ac4ca9e72aada01d301447f4799f23dc84a3d1cf2ed4bbdf646e6a851f1ee5d3')}, hash='ee34aa96cb017a5a1d53b663b021619c315feb36bf2b83e18aa6013e53af4923', text='Following the definition of Laney for Big Data, it can be state that: it is large amount of data generated in very fast motion and it contains a lot of content [43]. Such data comes from unstructured sources, such as stream of clicks on the web, social networks (Twitter, blogs, Facebook), video recordings from the shops, recording of calls in a call center, real time information from various kinds of sensors, RFID, GPS devices, mobile phones and other devices that identify and monitor something [8]. Big Data is a powerful digital data silo, raw, collected with all sorts of sources, unstructured and difficult, or even impossible, to analyze using conventional techniques used so far to relational databases.\n\nWhile describing Big Data, it cannot be overlooked that the term refers more to a phenomenon than to specific technology. Therefore, instead of defining this phenomenon, trying to describe them, more authors are describing Big Data by giving them characteristics included a collection of V’s related to its nature [2, 3, 23, 25, 58]:\n\nVolume (refers to the amount of data and is one of the biggest challenges in Big Data Analytics),\nVelocity (speed with which new data is generated, the challenge is to be able to manage data effectively and in real time),\nVariety (heterogeneity of data, many different types of healthcare data, the challenge is to derive insights by looking at all available heterogenous data in a holistic manner),\nVariability (inconsistency of data, the challenge is to correct the interpretation of data that can vary significantly depending on the context),\nVeracity (how trustworthy the data is, quality of the data),\nVisualization (ability to interpret data and resulting insights, challenging for Big Data due to its other features as described above).\nValue (the goal of Big Data Analytics is to discover the hidden knowledge from huge amounts of data).\nBig Data is defined as an information asset with high volume, velocity, and variety, which requires specific technology and method for its transformation into value [21, 77]. Big Data is also a collection of information about high-volume, high volatility or high diversity, requiring new forms of processing in order to support de ...
#  TextNode(id_='2cf02359-f9ed-4832-ac44-5b423174d750', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='94dbee40-40b2-42b0-a2bb-8b8bbf91b256', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='ee34aa96cb017a5a1d53b663b021619c315feb36bf2b83e18aa6013e53af4923'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='eadd3c37-01d1-4426-9eaf-ea8875acb89f', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='939f3c6c4b8fbd9c23ec47d2e5db143e2d28c5eaeb37d60225d3832e23ddebd2')}, hash='ac4ca9e72aada01d301447f4799f23dc84a3d1cf2ed4bbdf646e6a851f1ee5d3', text='results of research, including drug research, design of medical devices and new methods of treatment,\ndata provided by patients, including description of preferences, level of satisfaction, information from systems for self-monitoring of their activity: exercises, sleep, meals consumed, etc.\ndata from social media.\nThese data are provided not only by patients but also by organizations and institutions, as well as by various types of monitoring devices, sensors or instruments [16]. Data that has been generated so far in the healthcare sector is stored in both paper and digital form. Thus, the essence and the specificity of the process of Big Data analyses means that organizations need to face new technological and organizational challenges [67]. The healthcare sector has always generated huge amounts of data and this is connected, among others, with the need to store medical records of patients. However, the problem with Big Data in healthcare is not limited to an overwhelming volume but also an unprecedented diversity in terms of types, data formats and speed with which it should be analyzed in order to provide the necessary information on an ongoing basis [3]. It is also difficult to apply traditional tools and methods for management of unstructured data [67]. Due to the diversity and quantity of data sources that are growing all the time, advanced analytical tools and technologies, as well as Big Data analysis methods which can meet and exceed the possibilities of managing healthcare data, are needed [3, 68].\n\nTherefore, the potential is seen in Big Data analyses, especially in the aspect of improving the quality of medical care, saving lives or reducing costs [30]. Extracting from this tangle of given association rules, patterns and trends will allow health service providers and other stakeholders in the healthcare sector to offer more accurate and more insightful diagnoses of patients, personalized treatment, monitoring of the patients, preventive medicine, support of medical research and health population, as well as better quality of medical services and patient care while, at the same time, the ability to reduce costs (Fig. 1).\n\nAn external file that holds a picture, illustration, etc. ...
#  TextNode(id_='eadd3c37-01d1-4426-9eaf-ea8875acb89f', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='2cf02359-f9ed-4832-ac44-5b423174d750', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='ac4ca9e72aada01d301447f4799f23dc84a3d1cf2ed4bbdf646e6a851f1ee5d3'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='871030e6-ab36-4633-bae8-5561bd512a0a', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='ead29cd398561f97e584f4508432366a9ec2df54a835cb906680e4ab783815c8')}, hash='939f3c6c4b8fbd9c23ec47d2e5db143e2d28c5eaeb37d60225d3832e23ddebd2', text='When analyzing the phenomenon of Big Data in the healthcare sector, it should be noted that it can be considered from the point of view of three areas: epidemiological, clinical and business.\n\nFrom a clinical point of view, the Big Data analysis aims to improve the health and condition of patients, enable long-term predictions about their health status and implementation of appropriate therapeutic procedures. Ultimately, the use of data analysis in medicine is to allow the adaptation of therapy to a specific patient, that is personalized medicine (precision, personalized medicine).\n\nFrom an epidemiological point of view, it is desirable to obtain an accurate prognosis of morbidity in order to implement preventive programs in advance.\n\nIn the business context, Big Data analysis may enable offering personalized packages of commercial services or determining the probability of individual disease and infection occurrence. It is worth noting that Big Data means not only the collection and processing of data but, most of all, the inference and visualization of data necessary to obtain specific business benefits.\n\nIn order to introduce new management methods and new solutions in terms of effectiveness and transparency, it becomes necessary to make data more accessible, digital, searchable, as well as analyzed and visualized.\n\nErickson and Rothberg state that the information and data do not reveal their full value until insights are drawn from them. Data becomes useful when it enhances decision making and decision making is enhanced only when analytical techniques are used and an element of human interaction is applied [22].\n\nThus, healthcare has experienced much progress in usage and analysis of data. A large-scale digitalization and transparency in this sector is a key statement of almost all countries governments policies. For centuries, the treatment of patients was based on the judgment of doctors who made treatment decisions. In recent years, however, Evidence-Based Medicine has become more and more important as a result of it being related to the systematic analysis of clinical data and decision-making treatment based on the best available information [42]. In the healthcare sector, Big D ...
#  TextNode(id_='871030e6-ab36-4633-bae8-5561bd512a0a', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='eadd3c37-01d1-4426-9eaf-ea8875acb89f', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='939f3c6c4b8fbd9c23ec47d2e5db143e2d28c5eaeb37d60225d3832e23ddebd2'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='b8cc5b0d-c5d4-4439-acfe-4123003b250b', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='db8141624c82c60921ba982100fff5d1014fde0de15010392362cf41af57866d')}, hash='ead29cd398561f97e584f4508432366a9ec2df54a835cb906680e4ab783815c8', text='It can be used to i.e. predict the response of different patient groups to different drugs (dosages) or reactions (clinical trials), anticipate risk and find relationships in health data and detect hidden patterns [62]. In this way, it is possible to predict the epidemic spread, anticipate service contracts and plan healthcare resources. Predictive analytics is used in proper diagnosis and for appropriate treatments to be given to patients suffering from certain diseases [39].\nprescriptive analytics—occurs when health problems involve too many choices or alternatives. It uses health and medical knowledge in addition to data or information. Prescriptive analytics is used in many areas of healthcare, including drug prescriptions and treatment alternatives. Personalized medicine and evidence-based medicine are both supported by prescriptive analytics.\ndiscovery analytics—utilizes knowledge about knowledge to discover new “inventions” like drugs (drug discovery), previously unknown diseases and medical conditions, alternative treatments, etc.\nAlthough the models and tools used in descriptive, predictive, prescriptive, and discovery analytics are different, many applications involve all four of them [62]. Big Data Analytics in healthcare can help enable personalized medicine by identifying optimal patient-specific treatments. This can influence the improvement of life standards, reduce waste of healthcare resources and save costs of healthcare [56, 63, 71]. The introduction of large data analysis gives new analytical possibilities in terms of scope, flexibility and visualization. Techniques such as data mining (computational pattern discovery process in large data sets) facilitate inductive reasoning and analysis of exploratory data, enabling scientists to identify data patterns that are independent of specific hypotheses. As a result, predictive analysis and real-time analysis becomes possible, making it easier for medical staff to start early treatments and reduce potential morbidity and mortality. In addition, document analysis, statistical modeling, discovering patterns and topics in document collections and data in the EHR, as well as an inductive approach can help identify and discover relations ...
#  TextNode(id_='b8cc5b0d-c5d4-4439-acfe-4123003b250b', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='871030e6-ab36-4633-bae8-5561bd512a0a', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='ead29cd398561f97e584f4508432366a9ec2df54a835cb906680e4ab783815c8'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='8c09a731-94e4-47fc-bf35-5d418668e7b4', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='7e42f168e3f4455eccd5a0cfb79667a6f2c016c95b3f49f3df6492aaaf54dab0')}, hash='db8141624c82c60921ba982100fff5d1014fde0de15010392362cf41af57866d', text="Thus, some areas in which enhanced data and analytics can yield the greatest results include various healthcare stakeholders (Table \u200b(Table11).\n\nTable 1\nThe use of analytics by various healthcare stakeholders\n\nSource: own elaboration on the basis of [19, 20]\n\nThe use of analytics by healthcare providers\tHealthcare providers are the main recipients and users of analytical systems in healthcare. Thanks to the introduction of electronic medical records, medical facilities will have access to data and the possibility of using analytical systems, enabling the compilation of health services, maximizing its usefulness, profitability, taking into account market demand, costs and without reducing the quality of services. They will be able to securely share patient data between themselves and other entities providing health services. The use of analytics will allow access to statistical forecasts and it will allow to estimate the likelihood of occurrence of specific diseases and, on this basis, to plan types of health services. Thanks to analytics, medical centers will have a complete picture of their activities, taking into account the clinical, management, financial and quality perspectives\nThe use of analytics by the Payer\tThe analytics will allow payers to develop plans for managing health and preventive programs, so it can be a factor in improving the quality of patients' health insurance and improving the health and quality of life of insured persons. It will be possible to carry out analyses allowing to determine the structure and cost-effectiveness of medical procedures for a given disease or the risk of its occurrence. Access to cross-sectional information about the consumers will enable payers to identify factors (genetic, demographic or environmental) affecting the emergence and development of specific diseases. It will allow to plan contracting services and implement information and preventive programs, as well as informing patients what diseases they might come across or what are the risks\nAnalytics in the field of Life Sciences\tIn pharmaceutical forms and companies producing medical equipment, analytics has been used for several years, as these industries evolve very quickly. Cu ...
#  TextNode(id_='8c09a731-94e4-47fc-bf35-5d418668e7b4', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b8cc5b0d-c5d4-4439-acfe-4123003b250b', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='db8141624c82c60921ba982100fff5d1014fde0de15010392362cf41af57866d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='dfe048b4-243b-4e3d-a878-579bec0d4f40', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='dec5ff1a91338035a30dec80f674ffffbe45883afbd523ea0682a62452f38401')}, hash='7e42f168e3f4455eccd5a0cfb79667a6f2c016c95b3f49f3df6492aaaf54dab0', text='It is worth noting that there are many changes and challenges in the structure of the healthcare sector. Digitization and effective use of Big Data in healthcare can bring benefits to every stakeholder in this sector. A single doctor would benefit the same as the entire healthcare system. Potential opportunities to achieve benefits and effects from Big Data in healthcare can be divided into four groups [8]:\n\nImproving the quality of healthcare services:\nassessment of diagnoses made by doctors and the manner of treatment of diseases indicated by them based on the decision support system working on Big Data collections,\ndetection of more effective, from a medical point of view, and more cost-effective ways to diagnose and treat patients,\nanalysis of large volumes of data to reach practical information useful for identifying needs, introducing new health services, preventing and overcoming crises,\nprediction of the incidence of diseases,\ndetecting trends that lead to an improvement in health and lifestyle of the society,\nanalysis of the human genome for the introduction of personalized treatment.\nSupporting the work of medical personnel\ndoctors’ comparison of current medical cases to cases from the past for better diagnosis and treatment adjustment,\ndetection of diseases at earlier stages when they can be more easily and quickly cured,\ndetecting epidemiological risks and improving control of pathogenic spots and reaction rates,\nidentification of patients who are predicted to have the highest risk of specific, life-threatening diseases by collating data on the history of the most common diseases, in healing people with reports entering insurance companies,\nhealth management of each patient individually (personalized medicine) and health management of the whole society,\ncapturing and analyzing large amounts of data from hospitals and homes in real time, life monitoring devices to monitor safety and predict adverse events,\nanalysis of patient profiles to identify people for whom prevention should be applied, lifestyle change or preventive care approach,\nthe ability to predict the occurrence of specific diseases or worsening of patients’ results,\npredicting disease progression and its det ...
#  TextNode(id_='dfe048b4-243b-4e3d-a878-579bec0d4f40', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='8c09a731-94e4-47fc-bf35-5d418668e7b4', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='7e42f168e3f4455eccd5a0cfb79667a6f2c016c95b3f49f3df6492aaaf54dab0'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2d68d018-b6b6-4c22-bbf7-590093dcac06', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='2dc432ce90ba4fa3a7eb5bd383b1f189f91040ac8acfcac618d4de3960973d40')}, hash='dec5ff1a91338035a30dec80f674ffffbe45883afbd523ea0682a62452f38401', text='The above specification does not constitute a full list of potential areas of use of Big Data Analysis in healthcare because the possibilities of using analysis are practically unlimited. In addition, advanced analytical tools allow to analyze data from all possible sources and conduct cross-analyses to provide better data insights [26]. For example, a cross-analysis can refer to a combination of patient characteristics, as well as costs and care results that can help identify the best, in medical terms, and the most cost-effective treatment or treatments and this may allow a better adjustment of the service provider’s offer [62].\n\nIn turn, the analysis of patient profiles (e.g. segmentation and predictive modeling) allows identification of people who should be subject to prophylaxis, prevention or should change their lifestyle [8]. Shortened list of benefits for Big Data Analytics in healthcare is presented in paper [3] and consists of: better performance, day-to-day guides, detection of diseases in early stages, making predictive analytics, cost effectiveness, Evidence Based Medicine and effectiveness in patient treatment.\n\nSummarizing, healthcare big data represents a huge potential for the transformation of healthcare: improvement of patients’ results, prediction of outbreaks of epidemics, valuable insights, avoidance of preventable diseases, reduction of the cost of healthcare delivery and improvement of the quality of life in general [1]. Big Data also generates many challenges such as difficulties in data capture, data storage, data analysis and data visualization [15]. The main challenges are connected with the issues of: data structure (Big Data should be user-friendly, transparent, and menu-driven but it is fragmented, dispersed, rarely standardized and difficult to aggregate and analyze), security (data security, privacy and sensitivity of healthcare data, there are significant concerns related to confidentiality), data standardization (data is stored in formats that are not compatible with all applications and technologies), storage and transfers (especially costs associated with securing, storing, and transferring unstructured data), managerial skills, such as data governance, lack  ...
#  TextNode(id_='2d68d018-b6b6-4c22-bbf7-590093dcac06', embedding=None, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='db1d0fc4-7283-4e2c-a301-91b7ea49d790', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='a7ee2c77fe6fe461f1cb5efe9082f2413031e8a80f6580a60b910b7f9ef870ac'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='dfe048b4-243b-4e3d-a878-579bec0d4f40', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/01.txt', 'file_name': '01.txt', 'file_type': 'text/plain', 'file_size': 66288, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='dec5ff1a91338035a30dec80f674ffffbe45883afbd523ea0682a62452f38401'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='c7c2f9e6-5093-4cd0-862f-4e21f0264411', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='1dd6cd6796d4ba99d0015964780e28f536bcf16ca584b1377590adcabdd07bd1')}, hash='2dc432ce90ba4fa3a7eb5bd383b1f189f91040ac8acfcac618d4de3960973d40', text='The research was of all-Poland nature, and the entities included in the research sample come from all of the voivodships. The largest group were entities from Łódzkie (32%), Śląskie (18%) and Mazowieckie (18%) voivodships, as these voivodships have the largest number of medical institutions. Other regions of the country were represented by single units. The selection of the research sample was random—layered. As part of medical facilities database, groups of private and public medical facilities have been identified and the ones to which the questionnaire was targeted were drawn from each of these groups. The analyses were performed using the GNU PSPP 0.10.2 software.\n\nThe aim of the study was to determine whether medical facilities in Poland use Big Data Analytics and if so, in which areas. Characteristics of the research sample is presented in Table \u200bTable22.\n\nTable 2\nCharacteristics of the research sample\n\nThe form of ownership\n Public\t49.31%\n Private\t50.69%\nType of services provided (due to reimbursement)\n Under a contract with the NFZ (payer)\t23.51%\n Commercial only\t11.52%\n Both forms\t64.97%\nNumber of employees\n Up to 9\t17.51%\n 10–50\t34.10%\n 51–250\t27.19%\n 251–500\t13.36%\n 501–1000\t5.53%\n Over 1000\t2.30%\nVoivodeship\n Dolnośląskie\t3.2%\n Kujawsko pomorskie\t0.9%\n Lubelskie\t9.2%\n Lubuskie\t2.8%\n Łódzkie\t32.3%\n Małopolskie\t4.1%\n Mazowieckie\t18.4%\n Opolskie\t1.4%\n Podkarpackie\t1.4%\n Podlaskie\t1.4%\n Pomorskie\t1.4%\n Śląskie\t18.4%\n Świętokrzyskie\t1.4%\n Warmińsko pomorskie\t1.4%\n Wielkopolskie\t0.9%\n Zachodniopomorskie\t1.4%\nOpen in a separate window\nThe research is non-exhaustive due to the incomplete and uneven regional distribution of the samples, overrepresented in three voivodeships (Łódzkie, Mazowieckie and Śląskie). The size of the research sample (217 entities) allows the authors of the paper to formulate specific conclusions on the use of Big Data in the process of its management.\n\nFor the purpose of this paper, the following research hypotheses were formulated: (1) medical facilities in Poland are working on both structured and unstructured data (2) medical facilities in Poland are moving towards data-based healthcare and its be ...
# ...
#  TextNode(id_='9717bfb7-5588-4727-9745-1494c0fe1c08', embedding=None, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e34405d9-2ede-491d-bf88-954b2d52d8a5', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='7b5513b5b4d79c6815b3a755c810cae125af56d212206e1f4e8a809a9b910c86'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='1e247b98-4531-4497-8844-2a87d1912609', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='06d05b3e017d0463724fdc408dd71ac13f5b931e71a5e58bb1e222d7c3a8e5c2'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='9efbb763-3584-4b53-aa06-391252aa3b75', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='d3b8370dc2110f899073935bef5cd6c0ed9453ab716787e10e4d325f7764b082')}, hash='6742a7322683e2fe044488bc7c5f51a81ccf541dbc681561abd0ef6bcff59a8d', text='Notably, unlike other state consumer privacy laws, the law does not contain a revenue threshold and it applies regardless of whether an organization collects consumer health data from a certain number of consumers or derives a certain percentage of revenue from selling consumer health data. Further, the law also applies to any “small business” that collects, processes, sells, or shares consumer health data of less than 100,000 consumers or derives less than 50% of its gross revenue from collecting, processing, selling, or sharing consumer health data, and controls, processes, sells, or shares consumer health data of less than 25,000 consumers. Finally, the law protects Washington residents and any persons whose data is collected within the state of Washington. As such, the MHMDA casts a wide net and will apply to nearly any entity that collects, processes, shares, or sells consumer health data in Washington.\n\nThe MHMDA exempts various entities and information, such as government agencies, tribal nations, contracted service providers that process consumer health data on behalf of government agencies, publicly available information, de-identified data in accordance with HIPAA, employee and B2B information, information governed by HIPAA, certain information governed by 42 C.F.R. Part 2, information governed by the Fair Credit Reporting Act, information governed by the Gramm-Leach-Bliley Act (GLBA), and information governed by the Family Educational Rights and Privacy Act (FERPA), among others. Notably, the law does not contain a broad entity-level exemption for HIPAA-regulated entities as these entities should comply with this law to the extent that they maintain consumer health data distinguishable from HIPAA-covered data.\n\nFurthermore, the definition of “consumer health data” is defined broadly as “personal information that is linked or reasonably linkable to a consumer and that identifies the consumer’s past, present or future physical or mental health status.” The law further defines consumer health data in categories, such as:\n\nGeneral health data e.g., (1) individual health conditions, treatment, diseases, or diagnosis; (2) social, psychological, behavioral, or medical interventions; (3) su ...
#  TextNode(id_='9efbb763-3584-4b53-aa06-391252aa3b75', embedding=None, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e34405d9-2ede-491d-bf88-954b2d52d8a5', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='7b5513b5b4d79c6815b3a755c810cae125af56d212206e1f4e8a809a9b910c86'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='9717bfb7-5588-4727-9745-1494c0fe1c08', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='6742a7322683e2fe044488bc7c5f51a81ccf541dbc681561abd0ef6bcff59a8d'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='8ec4623f-c1b2-49ff-a64d-97a6892dc6dc', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='c86ff62a7b02ebbcf36a0e0f24fecb24f073aa0538eca3876a96cd57403f49ad')}, hash='d3b8370dc2110f899073935bef5cd6c0ed9453ab716787e10e4d325f7764b082', text='The law broadly defines “healthcare services” to include any service used to assess, measure, improve, or learn about a person’s mental or physical health. As such, nontraditional health care entities, such as retailers, that use geofencing technology could potentially violate the law if such technology is used to serve consumers advertisements related to their health care or health care services.\n\nAlthough the MHMDA goes into effect March 31, 2024, the prohibition on geofencing goes into effect July 23, 2023. Organizations that collect consumer health data in Washington must be ready to comply with this prohibition later this month.\n\nNevada’s Consumer Health Data Privacy Law\nOn June 16, 2023, the Nevada Governor signed SB 370, which creates a health data privacy law to protect consumer health data outside the scope of HIPAA. Nevada’s law will go into effect March 31, 2024. The law applies to a “regulated entity” that conducts business in Nevada or produces or provides products or services that are targeted to consumers in Nevada and determines the purpose and means of processing, sharing, or selling consumer health data. There are many types of entities and information that are exempt from this law, such as HIPAA-regulated entities, GLBA-covered financial institutions and affiliates, certain information governed by 42 C.F.R. Part 2, information governed by FERPA, de-identified data in accordance with HIPAA, publicly available information, information that is used to provide access to or enable gameplay, and information used to identify the shopping habits or interests of a consumer, among others. Like the MHMDA, Nevada’s law protects Nevada residents and any person whose consumer health data is collected in Nevada.\n\nNevada’s law defines “consumer health data” as “personally identifiable information that is linked or reasonably capable of being linked to a consumer and is used by a regulated entity to identify the health status of the consumer.” Like the MHMDA, Nevada’s law further defines consumer health data in categories and includes, without limitation:\n\nGeneral health data e.g., (1) any health condition or status, disease, or diagnosis; (2) social, psychological, behavioral, or medical ...
#  TextNode(id_='8ec4623f-c1b2-49ff-a64d-97a6892dc6dc', embedding=None, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e34405d9-2ede-491d-bf88-954b2d52d8a5', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='7b5513b5b4d79c6815b3a755c810cae125af56d212206e1f4e8a809a9b910c86'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='9efbb763-3584-4b53-aa06-391252aa3b75', node_type=<ObjectType.TEXT: '1'>, metadata={'file_path': 'data/healthanddata/documents/10.txt', 'file_name': '10.txt', 'file_type': 'text/plain', 'file_size': 14635, 'creation_date': '2023-12-27', 'last_modified_date': '2023-12-27', 'last_accessed_date': '2023-12-27'}, hash='d3b8370dc2110f899073935bef5cd6c0ed9453ab716787e10e4d325f7764b082')}, hash='c86ff62a7b02ebbcf36a0e0f24fecb24f073aa0538eca3876a96cd57403f49ad', text='Originally, the amendment related to consumer health data was set to go into effect July 1, 2023, but the Connecticut legislature recently passed the state budget bill, delaying the effective date of the consumer health data provisions. These provisions will now go into effect October 1, 2023. The amendment is like the MHMDA in various ways and below we highlight a couple key requirements.\n\nThe amendment to the CTDPA seeks to protect “consumer health data,” which includes any personal data that a controller uses to identify a consumer’s physical or mental health condition or diagnosis. Like the MHMDA, the CTDPA amendment further defines consumer health data in categories, including gender-affirming health data and reproductive or sexual health data. Further, the CTDPA exempts various entities and information from its scope, as we previously addressed.\n\nAgain, like the MHMDA, the CTDPA amendment also contains a prohibition on geofencing. The law now prohibits any person from using a geofence to establish a “virtual boundary within 1,750 feet of any mental health facility or reproductive or sexual health facility for the purpose of identifying, tracking, collecting data from or sending any notification to a consumer regarding the consumer’s health data.” As such, organizations that use geofencing or wish to use geofencing technology must determine the purposes for which it is used, including targeted advertising.\n\nKey Takeaways\nDue to the increased focus of federal and state regulators on protecting consumer health data outside the scope of HIPAA, organizations need to monitor these developments if they collect health data as these new requirements will likely require updates to their privacy compliance programs. Specifically, to get started, organizations should conduct a data mapping exercise and assess how they collect, process, sell, or share health data to determine if their current operations will need to be adjusted to meet these new compliance obligations. As we only highlighted a few of the new requirements, organizations that process any consumer health data should review these new laws fully and continuously follow the changing landscape in this space.\n\nFor more information about complying with the Health Breach Notification Rule or state consumer health data privacy laws, please contact any of the partners or senior counsel in Foley & Lardner’s Cybersecurity and Data Privacy team.\n\nThe aut ...

# %%
chunks = [x.text for x in nodes]
len(chunks)
# Out:
# 57

# %%
import logging
logging.basicConfig(level=logging.INFO)
triplets = []
for chunk in chunks:
    resp = llm.complete(prompt.replace("{text}", chunk))
    triplets.extend(resp.text.split("\n"))
triplets
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ['(Big Data Analytics, can bring, benefits to medical facilities)',
#  '(medical facilities, use, structured and unstructured data)',
#  '(medical facilities, reach for, analytics in the administrative, business, and clinical area)',
#  '(decisions made in medical facilities, are, highly data-driven)',
#  '(Big Data Analytics, allows to analyze, large datasets from thousands of patients)',
#  '(Big Data, offers potential solutions to, public and private organizations)',
#  '(Big Data, improve decision making, competitive advantage or business performance)',
#  '(Big Data Analytics, use in, healthcare)',
#  '(Big Data Analytics, improve decision making, competitive advantage or business performance)',
#  '(Big Data Analytics, use in, healthcare)',
#  '(Big Data, offers potential solutions to, public and private organizations)',
#  '(healthcare organizations, can use Big Data to, support clinical decision-making, disease surveillance, and public health management)',
#  '(Big Data, can be defined as, datasets that are of such large sizes that they pose challenges in traditional storage and analysis techniques)',
#  '(Big Data, is identified as, a tool to gather information from different databases and processes, allowing users to manage large amounts of data)',
#  '(Big Data, needs data bases for data to be stored in, programs and tools to be managed, as well as expertise and personnel able to retrieve useful information and visualization to be understood)',
#  '(Big Data, is defined as, an information asset with high volume, velocity, and variety)',
#  '(Big Data, requires, specific technology and method for its transformation into value)',
#  '(Big Data, is a collection of information about, high-volume, high volatility or high diversity)',
#  '(organizations, must approach, unstructured data in a different way)',
#  '(Big Data, creates opportunities for, access to valuable analyses, conclusions and enables making more accurate decisions)',
#  '(Big Data, challenges with, handling large amount of information)',
#  '(Big Data Analytics, result of data processing, appropriate data storytelling)',
#  '(Big Data Analytics, can benefit, healthcare stakeholders)',
#  '(Big Data Analytics, refers to, integration and analysis of complex heterogeneous data)',
#  '(Big Data analysis, aims to, improve health and condition of patients)',
#  '(Big Data analysis, aims to improve, health and condition of patients)',
#  '(Big Data analysis, enables offering, personalized packages of commercial services)',
#  '(Big Data Analytics, improves and increases, understanding of information contained in data)',
#  '(Big Data Analytics, can be used for, better diagnosis in the context of comprehensive patient data)',
#  '(Big Data Analytics, can be used for, reducing fraud and improving data security)',
#  '(healthcare providers, main recipients and users of, analytical systems in healthcare)',
#  '(electronic medical records, enable the compilation of, health services)',
#  '(analytical systems, enable the compilation of, health services)',
#  '(patient data, securely share between, healthcare providers and other entities providing health services)',
#  '(analytics, allow access to, statistical forecasts)',
#  '(healthcare providers, use of analytics by, main recipients and users of analytical systems in healthcare)',
#  '(payers, use of analytics by, developing plans for managing health and preventive programs)',
#  '(Life Sciences, analytics in the field of, used for several years in pharmaceutical forms and companies producing medical equipment)',
#  '(patients, use of analytics by, finding the best medical facilities and doctors, checking the effectiveness of treatments and medicines ordered)',
#  '(healthcare organizations, opportunity to grow through, investments in Big Data Analytics)',
#  '(Improving the quality of healthcare services, assessment of, diagnoses made by doctors and the manner of treatment of diseases indicated by them based on the decision support system working on Big Data collections)',
#  '(Improving the quality of healthcare services, detection of, more effective, from a medical point of view, and more cost-effective ways to diagnose and treat patients)',
#  '(Improving the quality of healthcare services, analysis of, large volumes of data to reach practical information useful for identifying needs, introducing new health services, preventing and overcoming crises)',
#  '(Improving the quality of healthcare services, prediction of, the incidence of diseases)',
#  '(Improving the quality of healthcare services, detecting trends that lead to, an improvement in health and lifestyle of the society)',
#  "(Supporting the work of medical personnel, doctors' comparison of, current medical cases to cases from the past for better diagnosis and treatment adjustment)",
#  '(Supporting the work of medical personnel, detection of, diseases at earlier stages when they can be more easily and quickly cured)',
#  '(Supporting the work of medical personnel, detecting epidemiological risks and improving control of, pathogenic spots and reaction rates)',
#  '(Supporting the work of medical personnel, identification of, patients who are predicted to have the highest risk of specific, life-threatening diseases by collating data on the history of the most common diseases, in healing people with reports entering insurance companies)',
#  '(Supporting scientific and research activity, supporting work on, new drugs and clinical trials thanks to the possibility of analyzing "all data" instead of selecting a test sample)',
#  '(Business and management, reduction of, costs and counteracting abuse and counseling practices)',
#  '(Business and management, faster and more effective identification of, incorrect or unauthorized financial operations in order to prevent abuse and eliminate errors)',
#  '(Business and management, increase in, profitability by detecting patients generating high costs or identifying doctors whose work, procedures and treatment methods cost the most and offering them solutions that reduce the amount of money spent)',
#  '(Business and management, identification of, unnecessary medical activities and procedures, e.g. duplicate tests)',
#  '(Big Data Analysis, potential areas of use, healthcare)',
#  '(advanced analytical tools, analyze data, all possible sources)',
#  '(patient profiles, identification of people, subject to prophylaxis, prevention or change their lifestyle)',
#  '(healthcare big data, challenges, difficulties in data capture, data storage, data analysis and data visualization)',
#  '(research sample, medical facilities in Poland, use Big Data Analytics)',
#  '(medical facilities, use, variety of data sources)',
#  '(medical facilities, collect and use, structured data)',
#  '(medical facilities, collect and use, unstructured data)',
#  '(medical facilities, collect and use, structured data)',
#  '(medical facilities, collect and use, unstructured data)',
#  '(size of medical facility, has an impact on, collection and use of structured data)',
#  '(size of medical facility, has an impact on, collection and use of unstructured data)',
#  '(form of ownership of medical facility, does not affect, data collection)',
#  '(medical facilities, use of, structured data)',
#  '(medical facility ownership, affects, data collection)',
#  '(medical facilities, collect and use, data from various sources)',
#  '(medical facilities, use extensively, information published in databases, reports to external units, and transaction data)',
#  '(medical facilities, use, unstructured data from e-mails, medical devices, sensors, phone calls, audio and video data)',
#  '(medical facilities, use, data analytics)',
#  '(medical facilities, use, data analytics in administration and business)',
#  '(medical facilities, use, data analytics in the clinical area)',
#  '(organization, use, data and analytical systems to support business decisions)',
#  '(organization, use, data and analytical systems to support clinical decisions)',
#  '(analytical maturity, level of, medical facilities)',
#  '(medical facilities, use, data and analytical systems to support clinical decisions)',
#  "(size of medical facility, depends on, facility's performance in the clinical area)",
#  '(form of ownership, determines, conditions of using Big Data Analytics in medical facilities)',
#  "(predictive analyses, performed, to support the organization's activity)",
#  '(medical facilities, working on, structured and unstructured data)',
#  '(data analytics, increase, accuracy of diagnoses)',
#  '(predictive analytics, allows to identify, risk factors for a given patient)',
#  '(Big Data Analytics, has the potential for, positive impact and global implications in healthcare)',
#  '(medical facilities, moving towards, data-based healthcare)',
#  '(Big Data Analytics, has the potential for, positive impact and global implications in healthcare)',
#  '(medical facilities, are moving towards, data-based healthcare)',
#  '(research, sought to narrow the gap, in analyzing the possibility of using Big Data Analytics in healthcare)',
#  '(medical facilities in Poland, are doing, in this respect)',
#  '(research, does not fully exhaust, the questions related to the use of Big Data Analytics in Polish healthcare facilities)',
#  '(Big Data, can help, healthcare providers meet goals)',
#  '(Big Data, relies on, ability to detect patterns and turn data into actionable knowledge)',
#  '(Big Data, offering solutions, improvement of patient care and generation of value in healthcare organizations)',
#  '(Big Data, requires, relevant stakeholders to collaborate and adapt systems)',
#  '(Big Data, requires, technological infrastructure and investment in human capital)',
#  '(Big Data, can reveal, new approaches to improve health)',
#  '(Big Data, can contribute at, different levels - increasing earlier diagnosis and effectiveness of treatments, widening possibilities for prevention of diseases, improvement of pharmacovigilance and patient safety, prediction of outcomes)',
#  '(Big Data, can help identify and promptly intervene on, high-risk and high-cost patients)',
#  '(Big Data, can contribute to, precision medicine by enabling detection of heterogeneity in patient responses to treatments and tailoring of healthcare to the specific needs of individuals)',
#  '(Big Data, can contribute to, precision public health by improving public health surveillance and assessment)',
#  '(e-health platforms, can be effective in improving, management of chronic patients in the community setting)',
#  '(Big Data and predictive analytics, can contribute to, precision public health)',
#  '(gathering of a very large amount of data, constitute, inestimable resource to be used, in epidemiological research)',
#  '(projects on Big Data, implemented in Europe, aimed to support, sustainability of health systems)',
#  '(specific initiatives, focused on, chronic conditions, rare diseases, and psychiatric disorders)',
#  '(Big Data analytics, given cancer researchers, powerful new ways to extract value from diverse sources of data)',
#  '(cancer, recognized as, one of the major contributors to premature deaths in the EU)',
#  '(omics data, can provide, a unique molecular profile for each patient)',
#  '(Comprehensive Cancer Centres, implement, the approach of combining these sources of data)',
#  '(MASTER trial, illustrated as, an example of a highly successful programme addressing the molecular profiling in cancer patients)',
#  '(Cancer Core Europe, potential umbrella for, bringing together national efforts)',
#  '(The Cancer Genome Atlas and the International Cancer Genome Consortium, provide researchers with, access to thousands of sequenced patients with different types of cancer)',
#  '(public databases, provide access to, catalogues of mutations found to be involved in cancer)',
#  '(CCCs across Europe, offer the potential to, increase the number of patients that can be offered molecular profiling and individualized treatment)',
#  '(German Cancer Research Center, develop tools to, grant ways to access and analyse own data together with data from partners)',
#  '(Big Data, beginning to revolutionize, healthcare in Europe)',
#  '(Big Data, offers paths and solutions, to improve health of individual persons)',
#  '(Big Data, offers paths and solutions, to improve the performance and outcomes, of healthcare systems)',
#  "(EU Data Protection Regulation (GDPR), tries to balance, patients' privacy while ensuring patient's data can be shared, for healthcare and research purposes)",
#  '(Guidelines on the protection of individuals with regard to the processing of personal data in a world of Big Data, provides suggested measures, for preventing any possible negative effects, of the use of Big Data on human rights and freedoms)',
#  '(big data in healthcare, can help, reduce costs of treatment)',
#  '(big data in healthcare, can help, predict outbreaks of epidemics)',
#  '(big data in healthcare, can help, avoid preventable diseases)',
#  '(big data in healthcare, can help, improve the quality of life)',
#  '(big data in healthcare, can help, enhance patient care)',
#  '(healthcare data analysis, purpose of, using data-driven findings to predict and solve a problem before it is too late)',
#  '(big data, importance in, healthcare industry)',
#  '(big data, analytical approach, improve processes, enhance patient care, and save lives)',
#  '(big data, helping to solve, staffing problem in hospitals)',
#  "(data scientists, crunched, 10 years' worth of hospital admissions records)",
#  '(data science team, developed, web-based user interface that forecasts patient loads and helps in planning resource allocation)',
#  '(Electronic Health Records, most widespread application of, big data in medicine)',
#  '(EHRs, shared via, secure information systems)',
#  '(EHRs, trigger warnings and reminders, when a patient should get a new lab test or track prescriptions)',
#  '(Clinical Decision Support software, analyzes, medical data on the spot)',
#  "(wearables, collect, patients' health data continuously and send this data to the cloud)",
#  '(Asthmapolis, using inhalers with GPS-enabled trackers, identify asthma trends and develop better treatment plans)',
#  "(Wearables, collect, patients' health data)",
#  '(Wearables, send, data to the cloud)',
#  '(database, accessed to, information on the state of health of the general public)',
#  '(doctors, compare, data in a socio-economic context)',
#  '(system, send, live alert to the doctor)',
#  '(big data, use of, healthcare)',
#  "(Cancer Moonshot program, goal of accomplishing, 10 years' worth of progress toward curing cancer in half that time)",
#  '(medical researchers, use large amounts of data on, treatment plans and recovery rates of cancer patients)',
#  '(researchers, examine tumor samples in biobanks, linked up with patient treatment records)',
#  '(data, lead to, finding that Desipramine has the ability to help cure certain types of lung cancer)',
#  '(patient databases, need to be linked up, from different institutions)',
#  '(obstacles, in the way, incompatible data systems)',
#  '(obstacles, in the way, patient confidentiality issues)',
#  '(obstacles, in the way, institutions not eager to share their own cancer dataset)',
#  '(predictive analysis, recognized as, one of the biggest business intelligence trends)',
#  '(Optum Labs, collected EHRs of over 30 million patients, to create a database for predictive analysis tools)',
#  '(healthcare organizations, experienced a data breach, 93%)',
#  '(analytics, help prevent security threats, by identifying changes in network traffic or any other behavior)',
#  '(big data, has inherent security issues)',
#  '(encryption technology, firewalls, anti-virus software, etc., answer the need for more security)',
#  '(analytical tools, help streamline the processing of insurance claims)',
#  '(Centers for Medicare and Medicaid Services, saved over $210.7 million in fraud, in just a year)',
#  '(telemedicine, refers to, the delivery of remote clinical services using technology)',
#  '(telemedicine, used for, primary consultations and initial diagnosis)',
#  '(telemedicine, used for, remote patient monitoring)',
#  '(telemedicine, used for, medical education for health professionals)',
#  '(telemedicine, used for, telesurgery)',
#  '(telemedicine, used for, primary consultations and initial diagnosis, remote patient monitoring, and medical education for health professionals)',
#  '(telemedicine, helps to, reduce costs and improve the quality of service)',
#  '(big data analytics for healthcare, could change, how images are read)',
#  '(big data analytics for healthcare, could identify, specific patterns in the pixels and convert them into a number to help the physician with the diagnosis)',
#  '(prevent unnecessary ER visits, Alameda County hospitals, created a program called PreManage ED)',
#  '(healthcare institutions, can use, big data tools)',
#  '(big data tools, streamline, staff administration activities)',
#  '(data-driven analytics, predict, when staff might be needed in particular departments)',
#  '(medical data analysis, empower, senior staff or operatives to offer support)',
#  '(healthcare institutions, use, healthcare data analysis to gain insight into who needs support or training)',
#  '(supply chain, weakened or fragmented, everything else)',
#  '(analytical tools, track, supply chain performance metrics)',
#  '(hospitals, save, up to $10 million per year)',
#  '(descriptive and predictive models, enhance decisions, negotiating prices, reducing variation in supplies, optimizing ordering process)',
#  '(financial facility management, ensure optimal financial health across facilities)',
#  '(big data in healthcare, provide necessary tools and knowledge, ensure finances are in check)',
#  '(drug costs, claims denial rates, reimbursement rates, financial indicators, unique to healthcare sector)',
#  '(software, collect, arrange, analyze data, ensure finances are in check, facility remains profitable)',
#  '(big data analysis in healthcare, assist in new therapy and innovative drug discoveries)',
#  '(historical, real-time, predictive metrics, data visualization techniques, identify strengths and weaknesses in trials or processes)',
#  '(data-driven genetic information analysis, reactionary predictions in patients, development of groundbreaking new drugs and forward-thinking therapies)',
#  '(big data, assist in managing and tracking mass diseases)',
#  '(advanced data management technologies, track in real-time how COVID was spreading, how fast it mutated, effect on world economies)',
#  '(massive data sets, diverse sources, medical records, individual human behaviors)',
#  '(AI-powered software, analyze images of lungs, identify signs of coronavirus, assess lesions)',
#  '(technology, allows hospitals, prevent the spread of the virus)',
#  '(AI-powered software, analyses images of the lungs taken by a CT scanner, identifies the signs of coronavirus, and assesses the lesions)',
#  '(Express Scripts, collected data from, 83 million patients)',
#  '(Express Scripts, can predict, who is likely to become addicted to a certain medication or who is not adhering to its treatment)',
#  '(big data and forecasting, identify and prevent, fraud or human error quickly)',
#  '(patient experience, will improve dramatically, quality of treatment and satisfaction levels)',
#  '(overall health of the population, can be enhanced, on a sustainable basis)',
#  '(operational costs, can be reduced significantly)',
#  '(big data in healthcare, applied on, a hospital dashboard)',
#  '(big data in healthcare, applied in the form of, hospital KPI dashboard)',
#  '(hospital KPI dashboard, displaying, specific healthcare analytics)',
#  '(top administrators, use, holistic view to identify potential bottlenecks, spot trends and patterns, and assess the situation)',
#  '(big data in healthcare, application of, patient dashboard displaying relevant metrics related to patient experience and care)',
#  '(medical institutions, use, patient dashboard to create harmony between departments and streamline care processes)',
#  '(big data in healthcare, need for, reducing costs)',
#  '(insurance companies, switching from, fee-for-service plans to plans that prioritize patient outcomes)',
#  '(healthcare providers, have a financial incentive, to share data that can be used to improve the lives of patients while cutting costs for insurance companies)',
#  "(big data in healthcare, can be used to, reduce medical errors and improve the facility's reputation)",
#  '(professionals, can be easily alerted, when the wrong medication, test, treatment, or other has been provided and remediate it immediately)',
#  '(data gathering and management, getting bigger, and professionals, need help in the matter)',
#  '(data gathering and management, getting bigger, in healthcare facilities)',
#  '(professionals, gather and analyze, real-time data)',
#  '(predictive analytics technologies, provide, relevant information regarding admission rates)',
#  '(wearable devices, tell, heart rate)',
#  '(data integration and storage, standing in the way of, using big data in medicine)',
#  '(data literacy, presents a limitation for, average users)',
#  '(data analytics, facilitates, early identification and intervention in illnesses)',
#  '(data-driven analytics, streamlines, institutions for swifter, safer, and more accurate patient care)',
#  "(healthcare data management, can be improved with, datapine's 14-day free trial)",
#  '(data analytics, can save lives and should be a top priority of, experts across the field)',
#  '(healthcare data breaches, impacted, upwards of 112M individuals)',
#  '(HealthITSecurity, compiled, list of top ten biggest healthcare data breaches)',
#  '(HCA Healthcare, reported, breach to OCR in July)',
#  '(HCA Healthcare, breach occurred, when unauthorized party stole a list of information)',
#  '(Perry Johnson & Associates, disclosed, May data breach)',
#  '(data breach, involved, personal information)',
#  '(data breach, impacted, millions of individuals)',
#  '(data breach, claimed responsibility, LockBit ransomware group)',
#  '(data breach, impacted, healthcare providers and plans)',
#  '(data breach, included, names, addresses, email addresses, and phone numbers)',
#  '(Regal Medical Group, disclosed, breach)',
#  '(breach, involved, unauthorized access to Social Security numbers, names, medical information, and health information)',
#  '(CareSource, fell victim to, MOVEit hack)',
#  '(CareSource, mentioned, Clop ransomware group in its breach notification)',
#  '(Cerebral, notified, data breach)',
#  '(NationsBenefits, reported, breach)',
#  '(breach, impacted, more than 3 million individuals)',
#  "(NationsBenefits, determined, certain members' personal information impacted)",
#  '(personal information, included, names, demographic information, health insurance numbers, Social Security numbers, dates of service, phone numbers, and provider names)',
#  "(NationsBenefits, stopped using, Fortra's software)",
#  '(healthcare industry, suffers, highest volumes of cyberattacks)',
#  '(cyber resilience, strengthen, healthcare entities)',
#  '(data breaches, ordered by, degree of impact)',
#  '(data breach, compromised, social security numbers, names, addresses, phone numbers, personal health data, clinical notes, lab tests, prescription information)',
#  '(data encryption policy, aligns with, federal standards)',
#  '(cybercriminals, located in, China, exploited, software vulnerability)',
#  '(sensitive patient data, compromised, names, birth dates, social security numbers, phone numbers, addresses)',
#  '(data breach, compromised, names, dates of birth, social security numbers, Medicaid, health plan identification numbers, some medical data)',
#  '(breach notification protocol, specified under, HIPAA)',
#  '(data breaches, following, theft of four personal computers storing unencrypted medical information)',
#  '(data breach, compromised, names, addresses, dates of birth, credit card numbers with expiration dates, demographic information, clinical information, health insurance information)',
#  '(data protection standards, outlined in, HIPAA)',
#  '(data breach, fined, $5.55 million, payable to, Health and Human Services Department)',
#  '(physical security controls, specified in, ISO 27001, implemented, protect internal devices from theft)',
#  '(data breach, occurred in, Advocate Health Care)',
#  '(data compromised, includes, names, addresses, dates of birth, credit card numbers, demographic information, clinical information, health insurance information)',
#  '(data breach, violated, data protection standards outlined in HIPAA)',
#  '(Advocate Health Care Network, fined, $5.55 million)',
#  '(preventive measure, physical security controls, specified in ISO 27001, should be implemented)',
#  '(data breach, occurred in, Medical Informatics Engineering)',
#  '(data compromised, includes, names, telephone numbers, mailing addresses, usernames, hashed passwords, security questions and answers, spousal information, email addresses, dates of birth, social security numbers, lab results, health insurance policy information, diagnosis, disability codes, doctor names, medical conditions, names of children, birth statistics)',
#  '(data breach, violated, HIPAA security rule 45 CFR § 164.308)',
#  '(Medical Informatics Engineering, fined, $100,000)',
#  '(preventive measure, security solution capable of mapping specific compliance efforts against recognized security frameworks, should be implemented)',
#  '(data breach, occurred in, Newkirk Products)',
#  '(data compromised, includes, primary care provider information, Medicaid ID numbers, patient names, names of dependants, dates of birth, invoice information)',
#  '(preventive measures, rigorously test server software for security vulnerabilities and misconfigurations, secure all privileged access management protocols, continuously scan servers for potential exploits)',
#  '(data breach, occurred in, Banner Health)',
#  '(data compromised, includes, patient names, addresses, birth dates, social security information, appointment dates, physician information, health insurance information)',
#  '(preventive measures, ensure third-party vendors comply with mandatory financial regulations, ensure continued improvements of security postures across all third-party vendors through regular risk assessments and security rating monitoring)',
#  '(data breach, occurred in, Trinity Health)',
#  '(data compromised, includes, backup of donor database)',
#  '(Trinity Health, affected by, ransomware attack attempt)',
#  '(data breach, occurred in, Morley Companies)',
#  '(Morley Companies, impacted, 521,046 individuals)',
#  '',
#  'What data was compromised?',
#  'The following data was compromised in the Morley Companies data breach:',
#  '',
#  'Names',
#  'Addresses',
#  'Social security numbers',
#  'Dates of birth',
#  "Driver's license numbers",
#  'Bank account information',
#  'Learn from this data breach',
#  'Implement strong data encryption measures to protect sensitive information such as social security numbers and bank account information.',
#  'Regularly monitor and update security measures to prevent unauthorized access to sensitive data.',
#  '(OneTouchPoint, provided services mainly to, healthcare organizations)',
#  '(OneTouchPoint, noticed, files had been locked and decrypted in July 2022)',
#  '(OneTouchPoint, concluded, systems had been illegally accessed in the months prior)',
#  '(healthcare providers, reported, data breaches of medical and patient records)',
#  '(OneTouchPoint, provided services to, healthcare organizations)',
#  '(OTP, noticed, files had been locked and decrypted)',
#  '(OTP, concluded, systems had been illegally accessed)',
#  '(healthcare providers, began to report, data breaches of medical and patient records)',
#  '(OTP, undergoing, class-action lawsuit)',
#  '(healthcare, target for, cybercrime)',
#  '(health data, valuable commodity, cybercriminals)',
#  '(Health Insurance Portability and Accountability Act (HIPAA), sets out to create, framework for data protection)',
#  '(HIPAA Security Rule, covers, data integrity, confidentiality, and availability of data)',
#  '(HIPAA Privacy Rule, focuses on, right of the user to control health data)',
#  '(HIPAA Privacy Rule, focuses on, right of the user to control what happens to their health data)',
#  '(HIPAA Privacy Rule, covers, administration, physical and technical aspects of data protection)',
#  '(HIPAA Omnibus rule, allows, requirements under the two rules above to be applied across all business associate organizations)',
#  '(HITECH, focuses on, electronic health records (EHR))',
#  '(HITECH, requires, users to have access to their ePHI)',
#  '(HIPAA Privacy Rule, sets, baseline of protection for certain individually identifiable health information)',
#  '(covered health care providers, may decide to offer, patients a choice as to whether their health information may be exchanged electronically)',
#  "(U.S. Department of Health and Human Services, does not set out, specific steps or requirements for obtaining a patient's choice whether to participate in eHIE)",
#  "(federal and state privacy laws, require, health care providers to obtain patients' written consent before they disclose their health information to other people and organizations)",
#  '(HIPAA, overrides, other privacy laws that are less protective)',
#  '(My Health, My Data Act, designed to protect, independence and dignity of individuals when making healthcare decisions)',
#  "(My Health, My Data Act, increases protections regarding, collection, sharing, and sale of health data without the consumer's knowledge)",
#  '(consumers, demand, more rights to access, delete, or withdraw consent of their PHI)',
#  '(consumers, demand, clearer guidelines, as to how such data can be used)',
#  "(Cassie, spoke directly to, US consumers, in order to delve into the heart of consumer trust and confidence in the healthcare system's ability to protect and uphold data)",
#  '(HIPAA, covers, several areas relating to health data)',
#  '(HIPAA, requires, a set of standards - the Privacy Rule and the Security Rule)',
#  '(HIPAA, is regulated by, the Department of Health and Human Services)',
#  '(HITECH Act, covers, vendors of personal health records and third-party service providers not covered by HIPAA)',
#  '(GDPR, comes under the remit of, the General Data Protection Regulation)',
#  '(GDPR, includes, personal information collected during registration or the provision of health care services)',
#  '(GDPR, treats, data breaches as violations if the company concerned is found to have not followed correct procedures)',
#  "(Section 251, allows, personal information to be shared with researchers with consumer's consent or special permission from certain governmental offices)",
#  '(digital data protection rights bill, is being progressed through, the UK Parliament)',
#  '(Cassie CMP software, provides, full HIPAA and GDPR compliance)',
#  '(data privacy, important in, healthcare)',
#  '(data breaches, affect, covered entities)',
#  '(bad actors, want access to, patient information)',
#  '(noncompliance penalties, vary based on, extent of the issue)',
#  '(violation, determines how, individual or organization is penalized)',
#  '(HIPAA, passed in, 1996)',
#  '(HIPAA, create, standards that protect the privacy of identifiable health information)',
#  '(HIPAA, gives, patients control over their medical records)',
#  '(HIPAA, consists of, the privacy rule and security rule)',
#  '(HIPAA, focuses on, electronically transmitted patient data)',
#  '(HIPAA, consists of, privacy rule and security rule)',
#  '(security rule, focuses on, electronically transmitted patient data)',
#  '(HITECH Act, was signed in, 2009)',
#  "(EHRs, help increase efficiency by, making it easier for authorized providers to access patients' medical records)",
#  "(EHRs, make it easier for providers to share, patients' records with authorized providers)",
#  '(telehealth visits, can be in the form of, a video call, telephone call, or text messages exchanged between a patient and provider)',
#  '(telehealth visits, have the potential to raise, privacy concerns)',
#  '(provider, should confirm, a patient is in a safe and private location before beginning the call)',
#  '(provider, should make every effort to limit, the potential disclosure of private information)',
#  '(technology, is key to, protecting confidential patient information and minimizing the risk of a breach)',
#  '(Box Content Cloud, gives your practice, a single place to secure and manage your content and workflows)',
#  '(Box, integrates with, the apps your organization is already using)',
#  '(Box, ensures you maintain compliance with, HIPAA and other industry standards)',
#  "(team, needs to know, how to use the content management system and what to do to protect patients' confidential health information)",
#  '(training areas, to focus on, include creating strong passwords, securing personal and work-related mobile devices, identifying scams, adopting security measures)',
#  '(HIPAA-compliant content management system, can take, organization so far)',
#  "(team, needs to know, how to use HIPAA-compliant content management system and what to do to protect patients' confidential health information)",
#  '(training areas, to focus on, creating strong passwords, securing personal and work-related mobile devices, identifying scams, adopting security measures)',
#  '(organization, must keep tabs on, changing regulations to ensure it maintains compliance)',
#  '(cloud-based content management system, can make it easier, for organization to keep up to date on any changing regulations)',
#  '(regulators, focused on, protecting consumer health data)',
#  '(HIPAA, regulates, protected health information maintained by covered entities)',
#  '(regulators, want to close, the gap between HIPAA-protected data and other consumer health data)',
#  '(FTC, issued, a Notice of Proposed Rulemaking seeking public comments on proposed changes to the Health Breach Notification Rule)',
#  "(Health Breach Notification Rule, seeks to protect, consumers' personal health records not subject to protection under HIPAA)",
#  '(MHMDA, exempts, various entities and information - government agencies, tribal nations, contracted service providers, publicly available information, de-identified data, employee and B2B information, information governed by HIPAA, information governed by 42 C.F.R. Part 2, information governed by the Fair Credit Reporting Act, information governed by the Gramm-Leach-Bliley Act, information governed by the Family Educational Rights and Privacy Act)',
#  "(MHMDA, defines, consumer health data broadly as personal information that is linked or reasonably linkable to a consumer and that identifies the consumer's past, present or future physical or mental health status)",
#  '(MHMDA, places, various obligations on organizations similar to other state consumer privacy laws)',
#  '(MHMDA, requires, regulated entities and small businesses to obtain authorizations from consumers to sell their data)',
#  '(MHMDA, prohibits, regulated entities from using geofencing around an entity that provides in-person healthcare services)',
#  '(MHMDA, goes into effect, March 31, 2024)',
#  '(prohibition on geofencing, goes into effect, July 23, 2023)',
#  '(organizations, must be ready to comply with, prohibition on geofencing)',
#  "(Nevada's Consumer Health Data Privacy Law, creates, health data privacy law)",
#  "(Nevada's law, applies to, regulated entity that conducts business in Nevada or produces or provides products or services targeted to consumers in Nevada)",
#  '(CTDPA amendment, seeks to protect, consumer health data)',
#  '(CTDPA amendment, further defines, consumer health data in categories - gender-affirming health data and reproductive or sexual health data)',
#  '(CTDPA amendment, contains, prohibition on geofencing)',
#  '(organizations, need to monitor, developments if they collect health data)',
#  '(organizations, should conduct, data mapping exercise)']

# %%
# Assuming triplets is a list of strings like '(DPDP Act, passed by, Indian Parliament)'
new_triplets = [t.replace('(', '').replace(')', '') for t in triplets]  # Remove parentheses
new_triplets = [tuple(map(str.strip, t.split(','))) for t in new_triplets]  # Split by comma and convert to tuple
new_triplets
# Out:
# [('Big Data Analytics', 'can bring', 'benefits to medical facilities'),
#  ('medical facilities', 'use', 'structured and unstructured data'),
#  ('medical facilities',
#   'reach for',
#   'analytics in the administrative',
#   'business',
#   'and clinical area'),
#  ('decisions made in medical facilities', 'are', 'highly data-driven'),
#  ('Big Data Analytics',
#   'allows to analyze',
#   'large datasets from thousands of patients'),
#  ('Big Data',
#   'offers potential solutions to',
#   'public and private organizations'),
#  ('Big Data',
#   'improve decision making',
#   'competitive advantage or business performance'),
#  ('Big Data Analytics', 'use in', 'healthcare'),
#  ('Big Data Analytics',
#   'improve decision making',
#   'competitive advantage or business performance'),
#  ('Big Data Analytics', 'use in', 'healthcare'),
#  ('Big Data',
#   'offers potential solutions to',
#   'public and private organizations'),
#  ('healthcare organizations',
#   'can use Big Data to',
#   'support clinical decision-making',
#   'disease surveillance',
#   'and public health management'),
#  ('Big Data',
#   'can be defined as',
#   'datasets that are of such large sizes that they pose challenges in traditional storage and analysis techniques'),
#  ('Big Data',
#   'is identified as',
#   'a tool to gather information from different databases and processes',
#   'allowing users to manage large amounts of data'),
#  ('Big Data',
#   'needs data bases for data to be stored in',
#   'programs and tools to be managed',
#   'as well as expertise and personnel able to retrieve useful information and visualization to be understood'),
#  ('Big Data',
#   'is defined as',
#   'an information asset with high volume',
#   'velocity',
#   'and variety'),
#  ('Big Data',
#   'requires',
#   'specific technology and method for its transformation into value'),
#  ('Big Data',
#   'is a collection of information about',
#   'high-volume',
#   'high volatility or high diversity'),
#  ('organizations', 'must approach', 'unstructured data in a different way'),
#  ('Big Data',
#   'creates opportunities for',
#   'access to valuable analyses',
#   'conclusions and enables making more accurate decisions'),
#  ('Big Data', 'challenges with', 'handling large amount of information'),
#  ('Big Data Analytics',
#   'result of data processing',
#   'appropriate data storytelling'),
#  ('Big Data Analytics', 'can benefit', 'healthcare stakeholders'),
#  ('Big Data Analytics',
#   'refers to',
#   'integration and analysis of complex heterogeneous data'),
#  ('Big Data analysis', 'aims to', 'improve health and condition of patients'),
#  ('Big Data analysis', 'aims to improve', 'health and condition of patients'),
#  ('Big Data analysis',
#   'enables offering',
#   'personalized packages of commercial services'),
#  ('Big Data Analytics',
#   'improves and increases',
#   'understanding of information contained in data'),
#  ('Big Data Analytics',
#   'can be used for',
#   'better diagnosis in the context of comprehensive patient data'),
#  ('Big Data Analytics',
#   'can be used for',
#   'reducing fraud and improving data security'),
#  ('healthcare providers',
#   'main recipients and users of',
#   'analytical systems in healthcare'),
#  ('electronic medical records',
#   'enable the compilation of',
#   'health services'),
#  ('analytical systems', 'enable the compilation of', 'health services'),
#  ('patient data',
#   'securely share between',
#   'healthcare providers and other entities providing health services'),
#  ('analytics', 'allow access to', 'statistical forecasts'),
#  ('healthcare providers',
#   'use of analytics by',
#   'main recipients and users of analytical systems in healthcare'),
#  ('payers',
#   'use of analytics by',
#   'developing plans for managing health and preventive programs'),
#  ('Life Sciences',
#   'analytics in the field of',
#   'used for several years in pharmaceutical forms and companies producing medical equipment'),
#  ('patients',
#   'use of analytics by',
#   'finding the best medical facilities and doctors',
#   'checking the effectiveness of treatments and medicines ordered'),
#  ('healthcare organizations',
#   'opportunity to grow through',
#   'investments in Big Data Analytics'),
#  ('Improving the quality of healthcare services',
#   'assessment of',
#   'diagnoses made by doctors and the manner of treatment of diseases indicated by them based on the decision support system working on Big Data collections'),
#  ('Improving the quality of healthcare services',
#   'detection of',
#   'more effective',
#   'from a medical point of view',
#   'and more cost-effective ways to diagnose and treat patients'),
#  ('Improving the quality of healthcare services',
#   'analysis of',
#   'large volumes of data to reach practical information useful for identifying needs',
#   'introducing new health services',
#   'preventing and overcoming crises'),
#  ('Improving the quality of healthcare services',
#   'prediction of',
#   'the incidence of diseases'),
#  ('Improving the quality of healthcare services',
#   'detecting trends that lead to',
#   'an improvement in health and lifestyle of the society'),
#  ('Supporting the work of medical personnel',
#   "doctors' comparison of",
#   'current medical cases to cases from the past for better diagnosis and treatment adjustment'),
#  ('Supporting the work of medical personnel',
#   'detection of',
#   'diseases at earlier stages when they can be more easily and quickly cured'),
#  ('Supporting the work of medical personnel',
#   'detecting epidemiological risks and improving control of',
#   'pathogenic spots and reaction rates'),
#  ('Supporting the work of medical personnel',
#   'identification of',
#   'patients who are predicted to have the highest risk of specific',
#   'life-threatening diseases by collating data on the history of the most common diseases',
#   'in healing people with reports entering insurance companies'),
#  ('Supporting scientific and research activity',
#   'supporting work on',
#   'new drugs and clinical trials thanks to the possibility of analyzing "all data" instead of selecting a test sample'),
#  ('Business and management',
#   'reduction of',
#   'costs and counteracting abuse and counseling practices'),
#  ('Business and management',
#   'faster and more effective identification of',
#   'incorrect or unauthorized financial operations in order to prevent abuse and eliminate errors'),
#  ('Business and management',
#   'increase in',
#   'profitability by detecting patients generating high costs or identifying doctors whose work',
#   'procedures and treatment methods cost the most and offering them solutions that reduce the amount of money spent'),
#  ('Business and management',
#   'identification of',
#   'unnecessary medical activities and procedures',
#   'e.g. duplicate tests'),
#  ('Big Data Analysis', 'potential areas of use', 'healthcare'),
#  ('advanced analytical tools', 'analyze data', 'all possible sources'),
#  ('patient profiles',
#   'identification of people',
#   'subject to prophylaxis',
#   'prevention or change their lifestyle'),
#  ('healthcare big data',
#   'challenges',
#   'difficulties in data capture',
#   'data storage',
#   'data analysis and data visualization'),
#  ('research sample', 'medical facilities in Poland', 'use Big Data Analytics'),
#  ('medical facilities', 'use', 'variety of data sources'),
#  ('medical facilities', 'collect and use', 'structured data'),
#  ('medical facilities', 'collect and use', 'unstructured data'),
#  ('medical facilities', 'collect and use', 'structured data'),
#  ('medical facilities', 'collect and use', 'unstructured data'),
#  ('size of medical facility',
#   'has an impact on',
#   'collection and use of structured data'),
#  ('size of medical facility',
#   'has an impact on',
#   'collection and use of unstructured data'),
#  ('form of ownership of medical facility',
#   'does not affect',
#   'data collection'),
#  ('medical facilities', 'use of', 'structured data'),
#  ('medical facility ownership', 'affects', 'data collection'),
#  ('medical facilities', 'collect and use', 'data from various sources'),
#  ('medical facilities',
#   'use extensively',
#   'information published in databases',
#   'reports to external units',
#   'and transaction data'),
#  ('medical facilities',
#   'use',
#   'unstructured data from e-mails',
#   'medical devices',
#   'sensors',
#   'phone calls',
#   'audio and video data'),
#  ('medical facilities', 'use', 'data analytics'),
#  ('medical facilities',
#   'use',
#   'data analytics in administration and business'),
#  ('medical facilities', 'use', 'data analytics in the clinical area'),
#  ('organization',
#   'use',
#   'data and analytical systems to support business decisions'),
#  ('organization',
#   'use',
#   'data and analytical systems to support clinical decisions'),
#  ('analytical maturity', 'level of', 'medical facilities'),
#  ('medical facilities',
#   'use',
#   'data and analytical systems to support clinical decisions'),
#  ('size of medical facility',
#   'depends on',
#   "facility's performance in the clinical area"),
#  ('form of ownership',
#   'determines',
#   'conditions of using Big Data Analytics in medical facilities'),
#  ('predictive analyses',
#   'performed',
#   "to support the organization's activity"),
#  ('medical facilities', 'working on', 'structured and unstructured data'),
#  ('data analytics', 'increase', 'accuracy of diagnoses'),
#  ('predictive analytics',
#   'allows to identify',
#   'risk factors for a given patient'),
#  ('Big Data Analytics',
#   'has the potential for',
#   'positive impact and global implications in healthcare'),
#  ('medical facilities', 'moving towards', 'data-based healthcare'),
#  ('Big Data Analytics',
#   'has the potential for',
#   'positive impact and global implications in healthcare'),
#  ('medical facilities', 'are moving towards', 'data-based healthcare'),
#  ('research',
#   'sought to narrow the gap',
#   'in analyzing the possibility of using Big Data Analytics in healthcare'),
#  ('medical facilities in Poland', 'are doing', 'in this respect'),
#  ('research',
#   'does not fully exhaust',
#   'the questions related to the use of Big Data Analytics in Polish healthcare facilities'),
#  ('Big Data', 'can help', 'healthcare providers meet goals'),
#  ('Big Data',
#   'relies on',
#   'ability to detect patterns and turn data into actionable knowledge'),
#  ('Big Data',
#   'offering solutions',
#   'improvement of patient care and generation of value in healthcare organizations'),
#  ('Big Data',
#   'requires',
#   'relevant stakeholders to collaborate and adapt systems'),
#  ('Big Data',
#   'requires',
#   'technological infrastructure and investment in human capital'),
#  ('Big Data', 'can reveal', 'new approaches to improve health'),
#  ('Big Data',
#   'can contribute at',
#   'different levels - increasing earlier diagnosis and effectiveness of treatments',
#   'widening possibilities for prevention of diseases',
#   'improvement of pharmacovigilance and patient safety',
#   'prediction of outcomes'),
#  ('Big Data',
#   'can help identify and promptly intervene on',
#   'high-risk and high-cost patients'),
#  ('Big Data',
#   'can contribute to',
#   'precision medicine by enabling detection of heterogeneity in patient responses to treatments and tailoring of healthcare to the specific needs of individuals'),
#  ('Big Data',
#   'can contribute to',
#   'precision public health by improving public health surveillance and assessment'),
#  ('e-health platforms',
#   'can be effective in improving',
#   'management of chronic patients in the community setting'),
#  ('Big Data and predictive analytics',
#   'can contribute to',
#   'precision public health'),
#  ('gathering of a very large amount of data',
#   'constitute',
#   'inestimable resource to be used',
#   'in epidemiological research'),
#  ('projects on Big Data',
#   'implemented in Europe',
#   'aimed to support',
#   'sustainability of health systems'),
#  ('specific initiatives',
#   'focused on',
#   'chronic conditions',
#   'rare diseases',
#   'and psychiatric disorders'),
#  ('Big Data analytics',
#   'given cancer researchers',
#   'powerful new ways to extract value from diverse sources of data'),
#  ('cancer',
#   'recognized as',
#   'one of the major contributors to premature deaths in the EU'),
#  ('omics data', 'can provide', 'a unique molecular profile for each patient'),
#  ('Comprehensive Cancer Centres',
#   'implement',
#   'the approach of combining these sources of data'),
#  ('MASTER trial',
#   'illustrated as',
#   'an example of a highly successful programme addressing the molecular profiling in cancer patients'),
#  ('Cancer Core Europe',
#   'potential umbrella for',
#   'bringing together national efforts'),
#  ('The Cancer Genome Atlas and the International Cancer Genome Consortium',
#   'provide researchers with',
#   'access to thousands of sequenced patients with different types of cancer'),
#  ('public databases',
#   'provide access to',
#   'catalogues of mutations found to be involved in cancer'),
#  ('CCCs across Europe',
#   'offer the potential to',
#   'increase the number of patients that can be offered molecular profiling and individualized treatment'),
#  ('German Cancer Research Center',
#   'develop tools to',
#   'grant ways to access and analyse own data together with data from partners'),
#  ('Big Data', 'beginning to revolutionize', 'healthcare in Europe'),
#  ('Big Data',
#   'offers paths and solutions',
#   'to improve health of individual persons'),
#  ('Big Data',
#   'offers paths and solutions',
#   'to improve the performance and outcomes',
#   'of healthcare systems'),
#  ('EU Data Protection Regulation GDPR',
#   'tries to balance',
#   "patients' privacy while ensuring patient's data can be shared",
#   'for healthcare and research purposes'),
#  ('Guidelines on the protection of individuals with regard to the processing of personal data in a world of Big Data',
#   'provides suggested measures',
#   'for preventing any possible negative effects',
#   'of the use of Big Data on human rights and freedoms'),
#  ('big data in healthcare', 'can help', 'reduce costs of treatment'),
#  ('big data in healthcare', 'can help', 'predict outbreaks of epidemics'),
#  ('big data in healthcare', 'can help', 'avoid preventable diseases'),
#  ('big data in healthcare', 'can help', 'improve the quality of life'),
#  ('big data in healthcare', 'can help', 'enhance patient care'),
#  ('healthcare data analysis',
#   'purpose of',
#   'using data-driven findings to predict and solve a problem before it is too late'),
#  ('big data', 'importance in', 'healthcare industry'),
#  ('big data',
#   'analytical approach',
#   'improve processes',
#   'enhance patient care',
#   'and save lives'),
#  ('big data', 'helping to solve', 'staffing problem in hospitals'),
#  ('data scientists',
#   'crunched',
#   "10 years' worth of hospital admissions records"),
#  ('data science team',
#   'developed',
#   'web-based user interface that forecasts patient loads and helps in planning resource allocation'),
#  ('Electronic Health Records',
#   'most widespread application of',
#   'big data in medicine'),
#  ('EHRs', 'shared via', 'secure information systems'),
#  ('EHRs',
#   'trigger warnings and reminders',
#   'when a patient should get a new lab test or track prescriptions'),
#  ('Clinical Decision Support software',
#   'analyzes',
#   'medical data on the spot'),
#  ('wearables',
#   'collect',
#   "patients' health data continuously and send this data to the cloud"),
#  ('Asthmapolis',
#   'using inhalers with GPS-enabled trackers',
#   'identify asthma trends and develop better treatment plans'),
#  ('Wearables', 'collect', "patients' health data"),
#  ('Wearables', 'send', 'data to the cloud'),
#  ('database',
#   'accessed to',
#   'information on the state of health of the general public'),
#  ('doctors', 'compare', 'data in a socio-economic context'),
#  ('system', 'send', 'live alert to the doctor'),
#  ('big data', 'use of', 'healthcare'),
#  ('Cancer Moonshot program',
#   'goal of accomplishing',
#   "10 years' worth of progress toward curing cancer in half that time"),
#  ('medical researchers',
#   'use large amounts of data on',
#   'treatment plans and recovery rates of cancer patients'),
#  ('researchers',
#   'examine tumor samples in biobanks',
#   'linked up with patient treatment records'),
#  ('data',
#   'lead to',
#   'finding that Desipramine has the ability to help cure certain types of lung cancer'),
#  ('patient databases', 'need to be linked up', 'from different institutions'),
#  ('obstacles', 'in the way', 'incompatible data systems'),
#  ('obstacles', 'in the way', 'patient confidentiality issues'),
#  ('obstacles',
#   'in the way',
#   'institutions not eager to share their own cancer dataset'),
#  ('predictive analysis',
#   'recognized as',
#   'one of the biggest business intelligence trends'),
#  ('Optum Labs',
#   'collected EHRs of over 30 million patients',
#   'to create a database for predictive analysis tools'),
#  ('healthcare organizations', 'experienced a data breach', '93%'),
#  ('analytics',
#   'help prevent security threats',
#   'by identifying changes in network traffic or any other behavior'),
#  ('big data', 'has inherent security issues'),
#  ('encryption technology',
#   'firewalls',
#   'anti-virus software',
#   'etc.',
#   'answer the need for more security'),
#  ('analytical tools', 'help streamline the processing of insurance claims'),
#  ('Centers for Medicare and Medicaid Services',
#   'saved over $210.7 million in fraud',
#   'in just a year'),
#  ('telemedicine',
#   'refers to',
#   'the delivery of remote clinical services using technology'),
#  ('telemedicine', 'used for', 'primary consultations and initial diagnosis'),
#  ('telemedicine', 'used for', 'remote patient monitoring'),
#  ('telemedicine', 'used for', 'medical education for health professionals'),
#  ('telemedicine', 'used for', 'telesurgery'),
#  ('telemedicine',
#   'used for',
#   'primary consultations and initial diagnosis',
#   'remote patient monitoring',
#   'and medical education for health professionals'),
#  ('telemedicine',
#   'helps to',
#   'reduce costs and improve the quality of service'),
#  ('big data analytics for healthcare', 'could change', 'how images are read'),
#  ('big data analytics for healthcare',
#   'could identify',
#   'specific patterns in the pixels and convert them into a number to help the physician with the diagnosis'),
#  ('prevent unnecessary ER visits',
#   'Alameda County hospitals',
#   'created a program called PreManage ED'),
#  ('healthcare institutions', 'can use', 'big data tools'),
#  ('big data tools', 'streamline', 'staff administration activities'),
#  ('data-driven analytics',
#   'predict',
#   'when staff might be needed in particular departments'),
#  ('medical data analysis',
#   'empower',
#   'senior staff or operatives to offer support'),
#  ('healthcare institutions',
#   'use',
#   'healthcare data analysis to gain insight into who needs support or training'),
#  ('supply chain', 'weakened or fragmented', 'everything else'),
#  ('analytical tools', 'track', 'supply chain performance metrics'),
#  ('hospitals', 'save', 'up to $10 million per year'),
#  ('descriptive and predictive models',
#   'enhance decisions',
#   'negotiating prices',
#   'reducing variation in supplies',
#   'optimizing ordering process'),
#  ('financial facility management',
#   'ensure optimal financial health across facilities'),
#  ('big data in healthcare',
#   'provide necessary tools and knowledge',
#   'ensure finances are in check'),
#  ('drug costs',
#   'claims denial rates',
#   'reimbursement rates',
#   'financial indicators',
#   'unique to healthcare sector'),
#  ('software',
#   'collect',
#   'arrange',
#   'analyze data',
#   'ensure finances are in check',
#   'facility remains profitable'),
#  ('big data analysis in healthcare',
#   'assist in new therapy and innovative drug discoveries'),
#  ('historical',
#   'real-time',
#   'predictive metrics',
#   'data visualization techniques',
#   'identify strengths and weaknesses in trials or processes'),
#  ('data-driven genetic information analysis',
#   'reactionary predictions in patients',
#   'development of groundbreaking new drugs and forward-thinking therapies'),
#  ('big data', 'assist in managing and tracking mass diseases'),
#  ('advanced data management technologies',
#   'track in real-time how COVID was spreading',
#   'how fast it mutated',
#   'effect on world economies'),
#  ('massive data sets',
#   'diverse sources',
#   'medical records',
#   'individual human behaviors'),
#  ('AI-powered software',
#   'analyze images of lungs',
#   'identify signs of coronavirus',
#   'assess lesions'),
#  ('technology', 'allows hospitals', 'prevent the spread of the virus'),
#  ('AI-powered software',
#   'analyses images of the lungs taken by a CT scanner',
#   'identifies the signs of coronavirus',
#   'and assesses the lesions'),
#  ('Express Scripts', 'collected data from', '83 million patients'),
#  ('Express Scripts',
#   'can predict',
#   'who is likely to become addicted to a certain medication or who is not adhering to its treatment'),
#  ('big data and forecasting',
#   'identify and prevent',
#   'fraud or human error quickly'),
#  ('patient experience',
#   'will improve dramatically',
#   'quality of treatment and satisfaction levels'),
#  ('overall health of the population',
#   'can be enhanced',
#   'on a sustainable basis'),
#  ('operational costs', 'can be reduced significantly'),
#  ('big data in healthcare', 'applied on', 'a hospital dashboard'),
#  ('big data in healthcare',
#   'applied in the form of',
#   'hospital KPI dashboard'),
#  ('hospital KPI dashboard', 'displaying', 'specific healthcare analytics'),
#  ('top administrators',
#   'use',
#   'holistic view to identify potential bottlenecks',
#   'spot trends and patterns',
#   'and assess the situation'),
#  ('big data in healthcare',
#   'application of',
#   'patient dashboard displaying relevant metrics related to patient experience and care'),
#  ('medical institutions',
#   'use',
#   'patient dashboard to create harmony between departments and streamline care processes'),
#  ('big data in healthcare', 'need for', 'reducing costs'),
#  ('insurance companies',
#   'switching from',
#   'fee-for-service plans to plans that prioritize patient outcomes'),
#  ('healthcare providers',
#   'have a financial incentive',
#   'to share data that can be used to improve the lives of patients while cutting costs for insurance companies'),
#  ('big data in healthcare',
#   'can be used to',
#   "reduce medical errors and improve the facility's reputation"),
#  ('professionals',
#   'can be easily alerted',
#   'when the wrong medication',
#   'test',
#   'treatment',
#   'or other has been provided and remediate it immediately'),
#  ('data gathering and management',
#   'getting bigger',
#   'and professionals',
#   'need help in the matter'),
#  ('data gathering and management',
#   'getting bigger',
#   'in healthcare facilities'),
#  ('professionals', 'gather and analyze', 'real-time data'),
#  ('predictive analytics technologies',
#   'provide',
#   'relevant information regarding admission rates'),
#  ('wearable devices', 'tell', 'heart rate'),
#  ('data integration and storage',
#   'standing in the way of',
#   'using big data in medicine'),
#  ('data literacy', 'presents a limitation for', 'average users'),
#  ('data analytics',
#   'facilitates',
#   'early identification and intervention in illnesses'),
#  ('data-driven analytics',
#   'streamlines',
#   'institutions for swifter',
#   'safer',
#   'and more accurate patient care'),
#  ('healthcare data management',
#   'can be improved with',
#   "datapine's 14-day free trial"),
#  ('data analytics',
#   'can save lives and should be a top priority of',
#   'experts across the field'),
#  ('healthcare data breaches', 'impacted', 'upwards of 112M individuals'),
#  ('HealthITSecurity',
#   'compiled',
#   'list of top ten biggest healthcare data breaches'),
#  ('HCA Healthcare', 'reported', 'breach to OCR in July'),
#  ('HCA Healthcare',
#   'breach occurred',
#   'when unauthorized party stole a list of information'),
#  ('Perry Johnson & Associates', 'disclosed', 'May data breach'),
#  ('data breach', 'involved', 'personal information'),
#  ('data breach', 'impacted', 'millions of individuals'),
#  ('data breach', 'claimed responsibility', 'LockBit ransomware group'),
#  ('data breach', 'impacted', 'healthcare providers and plans'),
#  ('data breach',
#   'included',
#   'names',
#   'addresses',
#   'email addresses',
#   'and phone numbers'),
#  ('Regal Medical Group', 'disclosed', 'breach'),
#  ('breach',
#   'involved',
#   'unauthorized access to Social Security numbers',
#   'names',
#   'medical information',
#   'and health information'),
#  ('CareSource', 'fell victim to', 'MOVEit hack'),
#  ('CareSource',
#   'mentioned',
#   'Clop ransomware group in its breach notification'),
#  ('Cerebral', 'notified', 'data breach'),
#  ('NationsBenefits', 'reported', 'breach'),
#  ('breach', 'impacted', 'more than 3 million individuals'),
#  ('NationsBenefits',
#   'determined',
#   "certain members' personal information impacted"),
#  ('personal information',
#   'included',
#   'names',
#   'demographic information',
#   'health insurance numbers',
#   'Social Security numbers',
#   'dates of service',
#   'phone numbers',
#   'and provider names'),
#  ('NationsBenefits', 'stopped using', "Fortra's software"),
#  ('healthcare industry', 'suffers', 'highest volumes of cyberattacks'),
#  ('cyber resilience', 'strengthen', 'healthcare entities'),
#  ('data breaches', 'ordered by', 'degree of impact'),
#  ('data breach',
#   'compromised',
#   'social security numbers',
#   'names',
#   'addresses',
#   'phone numbers',
#   'personal health data',
#   'clinical notes',
#   'lab tests',
#   'prescription information'),
#  ('data encryption policy', 'aligns with', 'federal standards'),
#  ('cybercriminals',
#   'located in',
#   'China',
#   'exploited',
#   'software vulnerability'),
#  ('sensitive patient data',
#   'compromised',
#   'names',
#   'birth dates',
#   'social security numbers',
#   'phone numbers',
#   'addresses'),
#  ('data breach',
#   'compromised',
#   'names',
#   'dates of birth',
#   'social security numbers',
#   'Medicaid',
#   'health plan identification numbers',
#   'some medical data'),
#  ('breach notification protocol', 'specified under', 'HIPAA'),
#  ('data breaches',
#   'following',
#   'theft of four personal computers storing unencrypted medical information'),
#  ('data breach',
#   'compromised',
#   'names',
#   'addresses',
#   'dates of birth',
#   'credit card numbers with expiration dates',
#   'demographic information',
#   'clinical information',
#   'health insurance information'),
#  ('data protection standards', 'outlined in', 'HIPAA'),
#  ('data breach',
#   'fined',
#   '$5.55 million',
#   'payable to',
#   'Health and Human Services Department'),
#  ('physical security controls',
#   'specified in',
#   'ISO 27001',
#   'implemented',
#   'protect internal devices from theft'),
#  ('data breach', 'occurred in', 'Advocate Health Care'),
#  ('data compromised',
#   'includes',
#   'names',
#   'addresses',
#   'dates of birth',
#   'credit card numbers',
#   'demographic information',
#   'clinical information',
#   'health insurance information'),
#  ('data breach', 'violated', 'data protection standards outlined in HIPAA'),
#  ('Advocate Health Care Network', 'fined', '$5.55 million'),
#  ('preventive measure',
#   'physical security controls',
#   'specified in ISO 27001',
#   'should be implemented'),
#  ('data breach', 'occurred in', 'Medical Informatics Engineering'),
#  ('data compromised',
#   'includes',
#   'names',
#   'telephone numbers',
#   'mailing addresses',
#   'usernames',
#   'hashed passwords',
#   'security questions and answers',
#   'spousal information',
#   'email addresses',
#   'dates of birth',
#   'social security numbers',
#   'lab results',
#   'health insurance policy information',
#   'diagnosis',
#   'disability codes',
#   'doctor names',
#   'medical conditions',
#   'names of children',
#   'birth statistics'),
#  ('data breach', 'violated', 'HIPAA security rule 45 CFR § 164.308'),
#  ('Medical Informatics Engineering', 'fined', '$100', '000'),
#  ('preventive measure',
#   'security solution capable of mapping specific compliance efforts against recognized security frameworks',
#   'should be implemented'),
#  ('data breach', 'occurred in', 'Newkirk Products'),
#  ('data compromised',
#   'includes',
#   'primary care provider information',
#   'Medicaid ID numbers',
#   'patient names',
#   'names of dependants',
#   'dates of birth',
#   'invoice information'),
#  ('preventive measures',
#   'rigorously test server software for security vulnerabilities and misconfigurations',
#   'secure all privileged access management protocols',
#   'continuously scan servers for potential exploits'),
#  ('data breach', 'occurred in', 'Banner Health'),
#  ('data compromised',
#   'includes',
#   'patient names',
#   'addresses',
#   'birth dates',
#   'social security information',
#   'appointment dates',
#   'physician information',
#   'health insurance information'),
#  ('preventive measures',
#   'ensure third-party vendors comply with mandatory financial regulations',
#   'ensure continued improvements of security postures across all third-party vendors through regular risk assessments and security rating monitoring'),
#  ('data breach', 'occurred in', 'Trinity Health'),
#  ('data compromised', 'includes', 'backup of donor database'),
#  ('Trinity Health', 'affected by', 'ransomware attack attempt'),
#  ('data breach', 'occurred in', 'Morley Companies'),
#  ('Morley Companies', 'impacted', '521', '046 individuals'),
#  ('',),
#  ('What data was compromised?',),
#  ('The following data was compromised in the Morley Companies data breach:',),
#  ('',),
#  ('Names',),
#  ('Addresses',),
#  ('Social security numbers',),
#  ('Dates of birth',),
#  ("Driver's license numbers",),
#  ('Bank account information',),
#  ('Learn from this data breach',),
#  ('Implement strong data encryption measures to protect sensitive information such as social security numbers and bank account information.',),
#  ('Regularly monitor and update security measures to prevent unauthorized access to sensitive data.',),
#  ('OneTouchPoint', 'provided services mainly to', 'healthcare organizations'),
#  ('OneTouchPoint',
#   'noticed',
#   'files had been locked and decrypted in July 2022'),
#  ('OneTouchPoint',
#   'concluded',
#   'systems had been illegally accessed in the months prior'),
#  ('healthcare providers',
#   'reported',
#   'data breaches of medical and patient records'),
#  ('OneTouchPoint', 'provided services to', 'healthcare organizations'),
#  ('OTP', 'noticed', 'files had been locked and decrypted'),
#  ('OTP', 'concluded', 'systems had been illegally accessed'),
#  ('healthcare providers',
#   'began to report',
#   'data breaches of medical and patient records'),
#  ('OTP', 'undergoing', 'class-action lawsuit'),
#  ('healthcare', 'target for', 'cybercrime'),
#  ('health data', 'valuable commodity', 'cybercriminals'),
#  ('Health Insurance Portability and Accountability Act HIPAA',
#   'sets out to create',
#   'framework for data protection'),
#  ('HIPAA Security Rule',
#   'covers',
#   'data integrity',
#   'confidentiality',
#   'and availability of data'),
#  ('HIPAA Privacy Rule',
#   'focuses on',
#   'right of the user to control health data'),
#  ('HIPAA Privacy Rule',
#   'focuses on',
#   'right of the user to control what happens to their health data'),
#  ('HIPAA Privacy Rule',
#   'covers',
#   'administration',
#   'physical and technical aspects of data protection'),
#  ('HIPAA Omnibus rule',
#   'allows',
#   'requirements under the two rules above to be applied across all business associate organizations'),
#  ('HITECH', 'focuses on', 'electronic health records EHR'),
#  ('HITECH', 'requires', 'users to have access to their ePHI'),
#  ('HIPAA Privacy Rule',
#   'sets',
#   'baseline of protection for certain individually identifiable health information'),
#  ('covered health care providers',
#   'may decide to offer',
#   'patients a choice as to whether their health information may be exchanged electronically'),
#  ('U.S. Department of Health and Human Services',
#   'does not set out',
#   "specific steps or requirements for obtaining a patient's choice whether to participate in eHIE"),
#  ('federal and state privacy laws',
#   'require',
#   "health care providers to obtain patients' written consent before they disclose their health information to other people and organizations"),
#  ('HIPAA', 'overrides', 'other privacy laws that are less protective'),
#  ('My Health',
#   'My Data Act',
#   'designed to protect',
#   'independence and dignity of individuals when making healthcare decisions'),
#  ('My Health',
#   'My Data Act',
#   'increases protections regarding',
#   'collection',
#   'sharing',
#   "and sale of health data without the consumer's knowledge"),
#  ('consumers',
#   'demand',
#   'more rights to access',
#   'delete',
#   'or withdraw consent of their PHI'),
#  ('consumers',
#   'demand',
#   'clearer guidelines',
#   'as to how such data can be used'),
#  ('Cassie',
#   'spoke directly to',
#   'US consumers',
#   "in order to delve into the heart of consumer trust and confidence in the healthcare system's ability to protect and uphold data"),
#  ('HIPAA', 'covers', 'several areas relating to health data'),
#  ('HIPAA',
#   'requires',
#   'a set of standards - the Privacy Rule and the Security Rule'),
#  ('HIPAA', 'is regulated by', 'the Department of Health and Human Services'),
#  ('HITECH Act',
#   'covers',
#   'vendors of personal health records and third-party service providers not covered by HIPAA'),
#  ('GDPR',
#   'comes under the remit of',
#   'the General Data Protection Regulation'),
#  ('GDPR',
#   'includes',
#   'personal information collected during registration or the provision of health care services'),
#  ('GDPR',
#   'treats',
#   'data breaches as violations if the company concerned is found to have not followed correct procedures'),
#  ('Section 251',
#   'allows',
#   "personal information to be shared with researchers with consumer's consent or special permission from certain governmental offices"),
#  ('digital data protection rights bill',
#   'is being progressed through',
#   'the UK Parliament'),
#  ('Cassie CMP software', 'provides', 'full HIPAA and GDPR compliance'),
#  ('data privacy', 'important in', 'healthcare'),
#  ('data breaches', 'affect', 'covered entities'),
#  ('bad actors', 'want access to', 'patient information'),
#  ('noncompliance penalties', 'vary based on', 'extent of the issue'),
#  ('violation', 'determines how', 'individual or organization is penalized'),
#  ('HIPAA', 'passed in', '1996'),
#  ('HIPAA',
#   'create',
#   'standards that protect the privacy of identifiable health information'),
#  ('HIPAA', 'gives', 'patients control over their medical records'),
#  ('HIPAA', 'consists of', 'the privacy rule and security rule'),
#  ('HIPAA', 'focuses on', 'electronically transmitted patient data'),
#  ('HIPAA', 'consists of', 'privacy rule and security rule'),
#  ('security rule', 'focuses on', 'electronically transmitted patient data'),
#  ('HITECH Act', 'was signed in', '2009'),
#  ('EHRs',
#   'help increase efficiency by',
#   "making it easier for authorized providers to access patients' medical records"),
#  ('EHRs',
#   'make it easier for providers to share',
#   "patients' records with authorized providers"),
#  ('telehealth visits',
#   'can be in the form of',
#   'a video call',
#   'telephone call',
#   'or text messages exchanged between a patient and provider'),
#  ('telehealth visits', 'have the potential to raise', 'privacy concerns'),
#  ('provider',
#   'should confirm',
#   'a patient is in a safe and private location before beginning the call'),
#  ('provider',
#   'should make every effort to limit',
#   'the potential disclosure of private information'),
#  ('technology',
#   'is key to',
#   'protecting confidential patient information and minimizing the risk of a breach'),
#  ('Box Content Cloud',
#   'gives your practice',
#   'a single place to secure and manage your content and workflows'),
#  ('Box', 'integrates with', 'the apps your organization is already using'),
#  ('Box',
#   'ensures you maintain compliance with',
#   'HIPAA and other industry standards'),
#  ('team',
#   'needs to know',
#   "how to use the content management system and what to do to protect patients' confidential health information"),
#  ('training areas',
#   'to focus on',
#   'include creating strong passwords',
#   'securing personal and work-related mobile devices',
#   'identifying scams',
#   'adopting security measures'),
#  ('HIPAA-compliant content management system',
#   'can take',
#   'organization so far'),
#  ('team',
#   'needs to know',
#   "how to use HIPAA-compliant content management system and what to do to protect patients' confidential health information"),
#  ('training areas',
#   'to focus on',
#   'creating strong passwords',
#   'securing personal and work-related mobile devices',
#   'identifying scams',
#   'adopting security measures'),
#  ('organization',
#   'must keep tabs on',
#   'changing regulations to ensure it maintains compliance'),
#  ('cloud-based content management system',
#   'can make it easier',
#   'for organization to keep up to date on any changing regulations'),
#  ('regulators', 'focused on', 'protecting consumer health data'),
#  ('HIPAA',
#   'regulates',
#   'protected health information maintained by covered entities'),
#  ('regulators',
#   'want to close',
#   'the gap between HIPAA-protected data and other consumer health data'),
#  ('FTC',
#   'issued',
#   'a Notice of Proposed Rulemaking seeking public comments on proposed changes to the Health Breach Notification Rule'),
#  ('Health Breach Notification Rule',
#   'seeks to protect',
#   "consumers' personal health records not subject to protection under HIPAA"),
#  ('MHMDA',
#   'exempts',
#   'various entities and information - government agencies',
#   'tribal nations',
#   'contracted service providers',
#   'publicly available information',
#   'de-identified data',
#   'employee and B2B information',
#   'information governed by HIPAA',
#   'information governed by 42 C.F.R. Part 2',
#   'information governed by the Fair Credit Reporting Act',
#   'information governed by the Gramm-Leach-Bliley Act',
#   'information governed by the Family Educational Rights and Privacy Act'),
#  ('MHMDA',
#   'defines',
#   "consumer health data broadly as personal information that is linked or reasonably linkable to a consumer and that identifies the consumer's past",
#   'present or future physical or mental health status'),
#  ('MHMDA',
#   'places',
#   'various obligations on organizations similar to other state consumer privacy laws'),
#  ('MHMDA',
#   'requires',
#   'regulated entities and small businesses to obtain authorizations from consumers to sell their data'),
#  ('MHMDA',
#   'prohibits',
#   'regulated entities from using geofencing around an entity that provides in-person healthcare services'),
#  ('MHMDA', 'goes into effect', 'March 31', '2024'),
#  ('prohibition on geofencing', 'goes into effect', 'July 23', '2023'),
#  ('organizations',
#   'must be ready to comply with',
#   'prohibition on geofencing'),
#  ("Nevada's Consumer Health Data Privacy Law",
#   'creates',
#   'health data privacy law'),
#  ("Nevada's law",
#   'applies to',
#   'regulated entity that conducts business in Nevada or produces or provides products or services targeted to consumers in Nevada'),
#  ('CTDPA amendment', 'seeks to protect', 'consumer health data'),
#  ('CTDPA amendment',
#   'further defines',
#   'consumer health data in categories - gender-affirming health data and reproductive or sexual health data'),
#  ('CTDPA amendment', 'contains', 'prohibition on geofencing'),
#  ('organizations',
#   'need to monitor',
#   'developments if they collect health data'),
#  ('organizations', 'should conduct', 'data mapping exercise')]

# %%
# _unique_nodes = [{
#     'id': "->".join(n),
#     'text': f'Subject: Digital Privacy Data Protection (DPDP) Act \nSub-Topic: {"->".join(n)}'
#     } for n in new_triplets]
# _unique_nodes
_unique_nodes = [{
    'id': "->".join(n),
    'text': f'{"->".join(n)}'
    } for n in list(set(new_triplets))]
_unique_nodes
# Out:
# [{'id': 'Business and management->reduction of->costs and counteracting abuse and counseling practices',
#   'text': 'Business and management->reduction of->costs and counteracting abuse and counseling practices'},
#  {'id': 'medical facilities->use->variety of data sources',
#   'text': 'medical facilities->use->variety of data sources'},
#  {'id': 'research->does not fully exhaust->the questions related to the use of Big Data Analytics in Polish healthcare facilities',
#   'text': 'research->does not fully exhaust->the questions related to the use of Big Data Analytics in Polish healthcare facilities'},
#  {'id': 'CareSource->fell victim to->MOVEit hack',
#   'text': 'CareSource->fell victim to->MOVEit hack'},
#  {'id': "team->needs to know->how to use the content management system and what to do to protect patients' confidential health information",
#   'text': "team->needs to know->how to use the content management system and what to do to protect patients' confidential health information"},
#  {'id': 'Big Data analysis->aims to improve->health and condition of patients',
#   'text': 'Big Data analysis->aims to improve->health and condition of patients'},
#  {'id': 'Big Data Analytics->can be used for->reducing fraud and improving data security',
#   'text': 'Big Data Analytics->can be used for->reducing fraud and improving data security'},
#  {'id': 'omics data->can provide->a unique molecular profile for each patient',
#   'text': 'omics data->can provide->a unique molecular profile for each patient'},
#  {'id': 'data literacy->presents a limitation for->average users',
#   'text': 'data literacy->presents a limitation for->average users'},
#  {'id': 'Implement strong data encryption measures to protect sensitive information such as social security numbers and bank account information.',
#   'text': 'Implement strong data encryption measures to protect sensitive information such as social security numbers and bank account information.'},
#  {'id': "big data in healthcare->can be used to->reduce medical errors and improve the facility's reputation",
#   'text': "big data in healthcare->can be used to->reduce medical errors and improve the facility's reputation"},
#  {'id': 'EHRs->shared via->secure information systems',
#   'text': 'EHRs->shared via->secure information systems'},
#  {'id': 'decisions made in medical facilities->are->highly data-driven',
#   'text': 'decisions made in medical facilities->are->highly data-driven'},
#  {'id': 'cloud-based content management system->can make it easier->for organization to keep up to date on any changing regulations',
#   'text': 'cloud-based content management system->can make it easier->for organization to keep up to date on any changing regulations'},
#  {'id': 'research->sought to narrow the gap->in analyzing the possibility of using Big Data Analytics in healthcare',
#   'text': 'research->sought to narrow the gap->in analyzing the possibility of using Big Data Analytics in healthcare'},
#  {'id': "Nevada's Consumer Health Data Privacy Law->creates->health data privacy law",
#   'text': "Nevada's Consumer Health Data Privacy Law->creates->health data privacy law"},
#  {'id': 'patients->use of analytics by->finding the best medical facilities and doctors->checking the effectiveness of treatments and medicines ordered',
#   'text': 'patients->use of analytics by->finding the best medical facilities and doctors->checking the effectiveness of treatments and medicines ordered'},
#  {'id': 'organizations->must approach->unstructured data in a different way',
#   'text': 'organizations->must approach->unstructured data in a different way'},
#  {'id': 'big data in healthcare->can help->predict outbreaks of epidemics',
#   'text': 'big data in healthcare->can help->predict outbreaks of epidemics'},
#  {'id': 'HITECH->focuses on->electronic health records EHR',
#   'text': 'HITECH->focuses on->electronic health records EHR'},
#  {'id': 'OTP->concluded->systems had been illegally accessed',
#   'text': 'OTP->concluded->systems had been illegally accessed'},
#  {'id': 'Addresses', 'text': 'Addresses'},
#  {'id': 'Big Data->is defined as->an information asset with high volume->velocity->and variety',
#   'text': 'Big Data->is defined as->an information asset with high volume->velocity->and variety'},
#  {'id': 'prevent unnecessary ER visits->Alameda County hospitals->created a program called PreManage ED',
#   'text': 'prevent unnecessary ER visits->Alameda County hospitals->created a program called PreManage ED'},
#  {'id': "data scientists->crunched->10 years' worth of hospital admissions records",
#   'text': "data scientists->crunched->10 years' worth of hospital admissions records"},
#  {'id': 'big data in healthcare->applied on->a hospital dashboard',
#   'text': 'big data in healthcare->applied on->a hospital dashboard'},
#  {'id': 'medical facilities->use->data analytics',
#   'text': 'medical facilities->use->data analytics'},
#  {'id': 'OneTouchPoint->provided services mainly to->healthcare organizations',
#   'text': 'OneTouchPoint->provided services mainly to->healthcare organizations'},
#  {'id': 'preventive measures->ensure third-party vendors comply with mandatory financial regulations->ensure continued improvements of security postures across all third-party vendors through regular risk assessments and security rating monitoring',
#   'text': 'preventive measures->ensure third-party vendors comply with mandatory financial regulations->ensure continued improvements of security postures across all third-party vendors through regular risk assessments and security rating monitoring'},
#  {'id': 'data-driven genetic information analysis->reactionary predictions in patients->development of groundbreaking new drugs and forward-thinking therapies',
#   'text': 'data-driven genetic information analysis->reactionary predictions in patients->development of groundbreaking new drugs and forward-thinking therapies'},
#  {'id': 'Supporting the work of medical personnel->detecting epidemiological risks and improving control of->pathogenic spots and reaction rates',
#   'text': 'Supporting the work of medical personnel->detecting epidemiological risks and improving control of->pathogenic spots and reaction rates'},
#  {'id': 'organization->must keep tabs on->changing regulations to ensure it maintains compliance',
#   'text': 'organization->must keep tabs on->changing regulations to ensure it maintains compliance'},
#  {'id': 'preventive measure->security solution capable of mapping specific compliance efforts against recognized security frameworks->should be implemented',
#   'text': 'preventive measure->security solution capable of mapping specific compliance efforts against recognized security frameworks->should be implemented'},
#  {'id': "Section 251->allows->personal information to be shared with researchers with consumer's consent or special permission from certain governmental offices",
#   'text': "Section 251->allows->personal information to be shared with researchers with consumer's consent or special permission from certain governmental offices"},
#  {'id': "Nevada's law->applies to->regulated entity that conducts business in Nevada or produces or provides products or services targeted to consumers in Nevada",
#   'text': "Nevada's law->applies to->regulated entity that conducts business in Nevada or produces or provides products or services targeted to consumers in Nevada"},
#  {'id': 'security rule->focuses on->electronically transmitted patient data',
#   'text': 'security rule->focuses on->electronically transmitted patient data'},
#  {'id': 'HIPAA Privacy Rule->focuses on->right of the user to control health data',
#   'text': 'HIPAA Privacy Rule->focuses on->right of the user to control health data'},
#  {'id': 'data gathering and management->getting bigger->in healthcare facilities',
#   'text': 'data gathering and management->getting bigger->in healthcare facilities'},
#  {'id': 'Big Data->improve decision making->competitive advantage or business performance',
#   'text': 'Big Data->improve decision making->competitive advantage or business performance'},
#  {'id': "Cancer Moonshot program->goal of accomplishing->10 years' worth of progress toward curing cancer in half that time",
#   'text': "Cancer Moonshot program->goal of accomplishing->10 years' worth of progress toward curing cancer in half that time"},
#  {'id': 'public databases->provide access to->catalogues of mutations found to be involved in cancer',
#   'text': 'public databases->provide access to->catalogues of mutations found to be involved in cancer'},
#  {'id': 'operational costs->can be reduced significantly',
#   'text': 'operational costs->can be reduced significantly'},
#  {'id': 'HIPAA Privacy Rule->covers->administration->physical and technical aspects of data protection',
#   'text': 'HIPAA Privacy Rule->covers->administration->physical and technical aspects of data protection'},
#  {'id': 'MHMDA->requires->regulated entities and small businesses to obtain authorizations from consumers to sell their data',
#   'text': 'MHMDA->requires->regulated entities and small businesses to obtain authorizations from consumers to sell their data'},
#  {'id': 'Big Data Analytics->refers to->integration and analysis of complex heterogeneous data',
#   'text': 'Big Data Analytics->refers to->integration and analysis of complex heterogeneous data'},
#  {'id': 'Regal Medical Group->disclosed->breach',
#   'text': 'Regal Medical Group->disclosed->breach'},
#  {'id': 'data compromised->includes->patient names->addresses->birth dates->social security information->appointment dates->physician information->health insurance information',
#   'text': 'data compromised->includes->patient names->addresses->birth dates->social security information->appointment dates->physician information->health insurance information'},
#  {'id': 'training areas->to focus on->include creating strong passwords->securing personal and work-related mobile devices->identifying scams->adopting security measures',
#   'text': 'training areas->to focus on->include creating strong passwords->securing personal and work-related mobile devices->identifying scams->adopting security measures'},
#  {'id': "EU Data Protection Regulation GDPR->tries to balance->patients' privacy while ensuring patient's data can be shared->for healthcare and research purposes",
#   'text': "EU Data Protection Regulation GDPR->tries to balance->patients' privacy while ensuring patient's data can be shared->for healthcare and research purposes"},
#  {'id': "NationsBenefits->stopped using->Fortra's software",
#   'text': "NationsBenefits->stopped using->Fortra's software"},
#  {'id': 'HITECH Act->was signed in->2009',
#   'text': 'HITECH Act->was signed in->2009'},
#  {'id': 'data breach->fined->$5.55 million->payable to->Health and Human Services Department',
#   'text': 'data breach->fined->$5.55 million->payable to->Health and Human Services Department'},
#  {'id': 'analytical tools->track->supply chain performance metrics',
#   'text': 'analytical tools->track->supply chain performance metrics'},
#  {'id': 'Big Data Analytics->improves and increases->understanding of information contained in data',
#   'text': 'Big Data Analytics->improves and increases->understanding of information contained in data'},
#  {'id': 'Names', 'text': 'Names'},
#  {'id': 'data compromised->includes->names->addresses->dates of birth->credit card numbers->demographic information->clinical information->health insurance information',
#   'text': 'data compromised->includes->names->addresses->dates of birth->credit card numbers->demographic information->clinical information->health insurance information'},
#  {'id': 'patient profiles->identification of people->subject to prophylaxis->prevention or change their lifestyle',
#   'text': 'patient profiles->identification of people->subject to prophylaxis->prevention or change their lifestyle'},
#  {'id': 'data analytics->facilitates->early identification and intervention in illnesses',
#   'text': 'data analytics->facilitates->early identification and intervention in illnesses'},
#  {'id': 'Box Content Cloud->gives your practice->a single place to secure and manage your content and workflows',
#   'text': 'Box Content Cloud->gives your practice->a single place to secure and manage your content and workflows'},
#  {'id': 'form of ownership->determines->conditions of using Big Data Analytics in medical facilities',
#   'text': 'form of ownership->determines->conditions of using Big Data Analytics in medical facilities'},
#  {'id': 'Asthmapolis->using inhalers with GPS-enabled trackers->identify asthma trends and develop better treatment plans',
#   'text': 'Asthmapolis->using inhalers with GPS-enabled trackers->identify asthma trends and develop better treatment plans'},
#  {'id': 'big data in healthcare->provide necessary tools and knowledge->ensure finances are in check',
#   'text': 'big data in healthcare->provide necessary tools and knowledge->ensure finances are in check'},
#  {'id': 'The Cancer Genome Atlas and the International Cancer Genome Consortium->provide researchers with->access to thousands of sequenced patients with different types of cancer',
#   'text': 'The Cancer Genome Atlas and the International Cancer Genome Consortium->provide researchers with->access to thousands of sequenced patients with different types of cancer'},
#  {'id': 'financial facility management->ensure optimal financial health across facilities',
#   'text': 'financial facility management->ensure optimal financial health across facilities'},
#  {'id': 'data breach->included->names->addresses->email addresses->and phone numbers',
#   'text': 'data breach->included->names->addresses->email addresses->and phone numbers'},
#  {'id': 'Big Data->can be defined as->datasets that are of such large sizes that they pose challenges in traditional storage and analysis techniques',
#   'text': 'Big Data->can be defined as->datasets that are of such large sizes that they pose challenges in traditional storage and analysis techniques'},
#  {'id': 'data breach->occurred in->Advocate Health Care',
#   'text': 'data breach->occurred in->Advocate Health Care'},
#  {'id': 'specific initiatives->focused on->chronic conditions->rare diseases->and psychiatric disorders',
#   'text': 'specific initiatives->focused on->chronic conditions->rare diseases->and psychiatric disorders'},
#  {'id': "predictive analyses->performed->to support the organization's activity",
#   'text': "predictive analyses->performed->to support the organization's activity"},
#  {'id': 'medical facilities->collect and use->structured data',
#   'text': 'medical facilities->collect and use->structured data'},
#  {'id': 'Morley Companies->impacted->521->046 individuals',
#   'text': 'Morley Companies->impacted->521->046 individuals'},
#  {'id': "NationsBenefits->determined->certain members' personal information impacted",
#   'text': "NationsBenefits->determined->certain members' personal information impacted"},
#  {'id': 'OneTouchPoint->concluded->systems had been illegally accessed in the months prior',
#   'text': 'OneTouchPoint->concluded->systems had been illegally accessed in the months prior'},
#  {'id': 'research sample->medical facilities in Poland->use Big Data Analytics',
#   'text': 'research sample->medical facilities in Poland->use Big Data Analytics'},
#  {'id': 'breach->impacted->more than 3 million individuals',
#   'text': 'breach->impacted->more than 3 million individuals'},
#  {'id': 'professionals->gather and analyze->real-time data',
#   'text': 'professionals->gather and analyze->real-time data'},
#  {'id': 'Big Data->can contribute to->precision medicine by enabling detection of heterogeneity in patient responses to treatments and tailoring of healthcare to the specific needs of individuals',
#   'text': 'Big Data->can contribute to->precision medicine by enabling detection of heterogeneity in patient responses to treatments and tailoring of healthcare to the specific needs of individuals'},
#  {'id': 'HIPAA Privacy Rule->focuses on->right of the user to control what happens to their health data',
#   'text': 'HIPAA Privacy Rule->focuses on->right of the user to control what happens to their health data'},
#  {'id': 'Express Scripts->collected data from->83 million patients',
#   'text': 'Express Scripts->collected data from->83 million patients'},
#  {'id': 'Big Data->requires->specific technology and method for its transformation into value',
#   'text': 'Big Data->requires->specific technology and method for its transformation into value'},
#  {'id': 'organizations->should conduct->data mapping exercise',
#   'text': 'organizations->should conduct->data mapping exercise'},
#  {'id': 'preventive measure->physical security controls->specified in ISO 27001->should be implemented',
#   'text': 'preventive measure->physical security controls->specified in ISO 27001->should be implemented'},
#  {'id': 'big data in healthcare->can help->reduce costs of treatment',
#   'text': 'big data in healthcare->can help->reduce costs of treatment'},
#  {'id': 'Big Data->can contribute at->different levels - increasing earlier diagnosis and effectiveness of treatments->widening possibilities for prevention of diseases->improvement of pharmacovigilance and patient safety->prediction of outcomes',
#   'text': 'Big Data->can contribute at->different levels - increasing earlier diagnosis and effectiveness of treatments->widening possibilities for prevention of diseases->improvement of pharmacovigilance and patient safety->prediction of outcomes'},
#  {'id': 'technology->is key to->protecting confidential patient information and minimizing the risk of a breach',
#   'text': 'technology->is key to->protecting confidential patient information and minimizing the risk of a breach'},
#  {'id': 'HIPAA->regulates->protected health information maintained by covered entities',
#   'text': 'HIPAA->regulates->protected health information maintained by covered entities'},
#  {'id': "Driver's license numbers", 'text': "Driver's license numbers"},
#  {'id': 'regulators->want to close->the gap between HIPAA-protected data and other consumer health data',
#   'text': 'regulators->want to close->the gap between HIPAA-protected data and other consumer health data'},
#  {'id': "Health Breach Notification Rule->seeks to protect->consumers' personal health records not subject to protection under HIPAA",
#   'text': "Health Breach Notification Rule->seeks to protect->consumers' personal health records not subject to protection under HIPAA"},
#  {'id': 'telemedicine->used for->medical education for health professionals',
#   'text': 'telemedicine->used for->medical education for health professionals'},
#  {'id': 'MHMDA->exempts->various entities and information - government agencies->tribal nations->contracted service providers->publicly available information->de-identified data->employee and B2B information->information governed by HIPAA->information governed by 42 C.F.R. Part 2->information governed by the Fair Credit Reporting Act->information governed by the Gramm-Leach-Bliley Act->information governed by the Family Educational Rights and Privacy Act',
#   'text': 'MHMDA->exempts->various entities and information - government agencies->tribal nations->contracted service providers->publicly available information->de-identified data->employee and B2B information->information governed by HIPAA->information governed by 42 C.F.R. Part 2->information governed by the Fair Credit Reporting Act->information governed by the Gramm-Leach-Bliley Act->information governed by the Family Educational Rights and Privacy Act'},
#  {'id': 'EHRs->trigger warnings and reminders->when a patient should get a new lab test or track prescriptions',
#   'text': 'EHRs->trigger warnings and reminders->when a patient should get a new lab test or track prescriptions'},
#  {'id': 'CTDPA amendment->seeks to protect->consumer health data',
#   'text': 'CTDPA amendment->seeks to protect->consumer health data'},
#  {'id': 'data breach->involved->personal information',
#   'text': 'data breach->involved->personal information'},
#  {'id': 'Big Data and predictive analytics->can contribute to->precision public health',
#   'text': 'Big Data and predictive analytics->can contribute to->precision public health'},
#  {'id': 'patient experience->will improve dramatically->quality of treatment and satisfaction levels',
#   'text': 'patient experience->will improve dramatically->quality of treatment and satisfaction levels'},
#  {'id': 'database->accessed to->information on the state of health of the general public',
#   'text': 'database->accessed to->information on the state of health of the general public'},
#  {'id': "team->needs to know->how to use HIPAA-compliant content management system and what to do to protect patients' confidential health information",
#   'text': "team->needs to know->how to use HIPAA-compliant content management system and what to do to protect patients' confidential health information"},
#  {'id': 'advanced data management technologies->track in real-time how COVID was spreading->how fast it mutated->effect on world economies',
#   'text': 'advanced data management technologies->track in real-time how COVID was spreading->how fast it mutated->effect on world economies'},
#  {'id': 'AI-powered software->analyses images of the lungs taken by a CT scanner->identifies the signs of coronavirus->and assesses the lesions',
#   'text': 'AI-powered software->analyses images of the lungs taken by a CT scanner->identifies the signs of coronavirus->and assesses the lesions'},
#  {'id': 'overall health of the population->can be enhanced->on a sustainable basis',
#   'text': 'overall health of the population->can be enhanced->on a sustainable basis'},
#  {'id': 'big data analytics for healthcare->could identify->specific patterns in the pixels and convert them into a number to help the physician with the diagnosis',
#   'text': 'big data analytics for healthcare->could identify->specific patterns in the pixels and convert them into a number to help the physician with the diagnosis'},
#  {'id': 'HIPAA Privacy Rule->sets->baseline of protection for certain individually identifiable health information',
#   'text': 'HIPAA Privacy Rule->sets->baseline of protection for certain individually identifiable health information'},
#  {'id': 'data breaches->ordered by->degree of impact',
#   'text': 'data breaches->ordered by->degree of impact'},
#  {'id': 'HIPAA->passed in->1996', 'text': 'HIPAA->passed in->1996'},
#  {'id': 'insurance companies->switching from->fee-for-service plans to plans that prioritize patient outcomes',
#   'text': 'insurance companies->switching from->fee-for-service plans to plans that prioritize patient outcomes'},
#  {'id': 'Comprehensive Cancer Centres->implement->the approach of combining these sources of data',
#   'text': 'Comprehensive Cancer Centres->implement->the approach of combining these sources of data'},
#  {'id': "size of medical facility->depends on->facility's performance in the clinical area",
#   'text': "size of medical facility->depends on->facility's performance in the clinical area"},
#  {'id': 'system->send->live alert to the doctor',
#   'text': 'system->send->live alert to the doctor'},
#  {'id': 'HealthITSecurity->compiled->list of top ten biggest healthcare data breaches',
#   'text': 'HealthITSecurity->compiled->list of top ten biggest healthcare data breaches'},
#  {'id': 'OneTouchPoint->provided services to->healthcare organizations',
#   'text': 'OneTouchPoint->provided services to->healthcare organizations'},
#  {'id': 'big data->analytical approach->improve processes->enhance patient care->and save lives',
#   'text': 'big data->analytical approach->improve processes->enhance patient care->and save lives'},
#  {'id': 'data privacy->important in->healthcare',
#   'text': 'data privacy->important in->healthcare'},
#  {'id': 'data breach->claimed responsibility->LockBit ransomware group',
#   'text': 'data breach->claimed responsibility->LockBit ransomware group'},
#  {'id': 'Big Data Analytics->use in->healthcare',
#   'text': 'Big Data Analytics->use in->healthcare'},
#  {'id': 'healthcare->target for->cybercrime',
#   'text': 'healthcare->target for->cybercrime'},
#  {'id': 'Cancer Core Europe->potential umbrella for->bringing together national efforts',
#   'text': 'Cancer Core Europe->potential umbrella for->bringing together national efforts'},
#  {'id': 'Big Data->offers paths and solutions->to improve the performance and outcomes->of healthcare systems',
#   'text': 'Big Data->offers paths and solutions->to improve the performance and outcomes->of healthcare systems'},
#  {'id': 'obstacles->in the way->incompatible data systems',
#   'text': 'obstacles->in the way->incompatible data systems'},
#  {'id': 'big data tools->streamline->staff administration activities',
#   'text': 'big data tools->streamline->staff administration activities'},
#  {'id': 'data compromised->includes->names->telephone numbers->mailing addresses->usernames->hashed passwords->security questions and answers->spousal information->email addresses->dates of birth->social security numbers->lab results->health insurance policy information->diagnosis->disability codes->doctor names->medical conditions->names of children->birth statistics',
#   'text': 'data compromised->includes->names->telephone numbers->mailing addresses->usernames->hashed passwords->security questions and answers->spousal information->email addresses->dates of birth->social security numbers->lab results->health insurance policy information->diagnosis->disability codes->doctor names->medical conditions->names of children->birth statistics'},
#  {'id': 'medical researchers->use large amounts of data on->treatment plans and recovery rates of cancer patients',
#   'text': 'medical researchers->use large amounts of data on->treatment plans and recovery rates of cancer patients'},
#  {'id': 'Perry Johnson & Associates->disclosed->May data breach',
#   'text': 'Perry Johnson & Associates->disclosed->May data breach'},
#  {'id': 'telemedicine->used for->remote patient monitoring',
#   'text': 'telemedicine->used for->remote patient monitoring'},
#  {'id': 'data gathering and management->getting bigger->and professionals->need help in the matter',
#   'text': 'data gathering and management->getting bigger->and professionals->need help in the matter'},
#  {'id': 'HIPAA->consists of->the privacy rule and security rule',
#   'text': 'HIPAA->consists of->the privacy rule and security rule'},
#  {'id': 'HIPAA Omnibus rule->allows->requirements under the two rules above to be applied across all business associate organizations',
#   'text': 'HIPAA Omnibus rule->allows->requirements under the two rules above to be applied across all business associate organizations'},
#  {'id': 'organizations->need to monitor->developments if they collect health data',
#   'text': 'organizations->need to monitor->developments if they collect health data'},
#  {'id': 'data integration and storage->standing in the way of->using big data in medicine',
#   'text': 'data integration and storage->standing in the way of->using big data in medicine'},
#  {'id': 'Big Data->can help->healthcare providers meet goals',
#   'text': 'Big Data->can help->healthcare providers meet goals'},
#  {'id': 'telehealth visits->have the potential to raise->privacy concerns',
#   'text': 'telehealth visits->have the potential to raise->privacy concerns'},
#  {'id': 'HIPAA->gives->patients control over their medical records',
#   'text': 'HIPAA->gives->patients control over their medical records'},
#  {'id': 'big data in healthcare->can help->enhance patient care',
#   'text': 'big data in healthcare->can help->enhance patient care'},
#  {'id': 'gathering of a very large amount of data->constitute->inestimable resource to be used->in epidemiological research',
#   'text': 'gathering of a very large amount of data->constitute->inestimable resource to be used->in epidemiological research'},
#  {'id': 'violation->determines how->individual or organization is penalized',
#   'text': 'violation->determines how->individual or organization is penalized'},
#  {'id': 'preventive measures->rigorously test server software for security vulnerabilities and misconfigurations->secure all privileged access management protocols->continuously scan servers for potential exploits',
#   'text': 'preventive measures->rigorously test server software for security vulnerabilities and misconfigurations->secure all privileged access management protocols->continuously scan servers for potential exploits'},
#  {'id': 'data analytics->can save lives and should be a top priority of->experts across the field',
#   'text': 'data analytics->can save lives and should be a top priority of->experts across the field'},
#  {'id': 'medical institutions->use->patient dashboard to create harmony between departments and streamline care processes',
#   'text': 'medical institutions->use->patient dashboard to create harmony between departments and streamline care processes'},
#  {'id': 'breach notification protocol->specified under->HIPAA',
#   'text': 'breach notification protocol->specified under->HIPAA'},
#  {'id': 'Improving the quality of healthcare services->assessment of->diagnoses made by doctors and the manner of treatment of diseases indicated by them based on the decision support system working on Big Data collections',
#   'text': 'Improving the quality of healthcare services->assessment of->diagnoses made by doctors and the manner of treatment of diseases indicated by them based on the decision support system working on Big Data collections'},
#  {'id': 'Big Data->offers potential solutions to->public and private organizations',
#   'text': 'Big Data->offers potential solutions to->public and private organizations'},
#  {'id': 'e-health platforms->can be effective in improving->management of chronic patients in the community setting',
#   'text': 'e-health platforms->can be effective in improving->management of chronic patients in the community setting'},
#  {'id': 'Box->ensures you maintain compliance with->HIPAA and other industry standards',
#   'text': 'Box->ensures you maintain compliance with->HIPAA and other industry standards'},
#  {'id': 'Big Data analysis->enables offering->personalized packages of commercial services',
#   'text': 'Big Data analysis->enables offering->personalized packages of commercial services'},
#  {'id': 'Dates of birth', 'text': 'Dates of birth'},
#  {'id': 'big data in healthcare->need for->reducing costs',
#   'text': 'big data in healthcare->need for->reducing costs'},
#  {'id': 'data-driven analytics->streamlines->institutions for swifter->safer->and more accurate patient care',
#   'text': 'data-driven analytics->streamlines->institutions for swifter->safer->and more accurate patient care'},
#  {'id': 'Medical Informatics Engineering->fined->$100->000',
#   'text': 'Medical Informatics Engineering->fined->$100->000'},
#  {'id': 'physical security controls->specified in->ISO 27001->implemented->protect internal devices from theft',
#   'text': 'physical security controls->specified in->ISO 27001->implemented->protect internal devices from theft'},
#  {'id': 'data breach->occurred in->Morley Companies',
#   'text': 'data breach->occurred in->Morley Companies'},
#  {'id': 'Improving the quality of healthcare services->detecting trends that lead to->an improvement in health and lifestyle of the society',
#   'text': 'Improving the quality of healthcare services->detecting trends that lead to->an improvement in health and lifestyle of the society'},
#  {'id': 'MHMDA->places->various obligations on organizations similar to other state consumer privacy laws',
#   'text': 'MHMDA->places->various obligations on organizations similar to other state consumer privacy laws'},
#  {'id': 'Clinical Decision Support software->analyzes->medical data on the spot',
#   'text': 'Clinical Decision Support software->analyzes->medical data on the spot'},
#  {'id': 'cancer->recognized as->one of the major contributors to premature deaths in the EU',
#   'text': 'cancer->recognized as->one of the major contributors to premature deaths in the EU'},
#  {'id': 'patient data->securely share between->healthcare providers and other entities providing health services',
#   'text': 'patient data->securely share between->healthcare providers and other entities providing health services'},
#  {'id': 'Improving the quality of healthcare services->prediction of->the incidence of diseases',
#   'text': 'Improving the quality of healthcare services->prediction of->the incidence of diseases'},
#  {'id': "Wearables->collect->patients' health data",
#   'text': "Wearables->collect->patients' health data"},
#  {'id': 'medical facilities->use->data analytics in administration and business',
#   'text': 'medical facilities->use->data analytics in administration and business'},
#  {'id': 'MHMDA->prohibits->regulated entities from using geofencing around an entity that provides in-person healthcare services',
#   'text': 'MHMDA->prohibits->regulated entities from using geofencing around an entity that provides in-person healthcare services'},
#  {'id': 'cybercriminals->located in->China->exploited->software vulnerability',
#   'text': 'cybercriminals->located in->China->exploited->software vulnerability'},
#  {'id': 'data breach->occurred in->Banner Health',
#   'text': 'data breach->occurred in->Banner Health'},
#  {'id': 'medical facilities in Poland->are doing->in this respect',
#   'text': 'medical facilities in Poland->are doing->in this respect'},
#  {'id': 'obstacles->in the way->institutions not eager to share their own cancer dataset',
#   'text': 'obstacles->in the way->institutions not eager to share their own cancer dataset'},
#  {'id': 'Big Data->beginning to revolutionize->healthcare in Europe',
#   'text': 'Big Data->beginning to revolutionize->healthcare in Europe'},
#  {'id': 'data breach->occurred in->Medical Informatics Engineering',
#   'text': 'data breach->occurred in->Medical Informatics Engineering'},
#  {'id': 'medical facilities->use->unstructured data from e-mails->medical devices->sensors->phone calls->audio and video data',
#   'text': 'medical facilities->use->unstructured data from e-mails->medical devices->sensors->phone calls->audio and video data'},
#  {'id': 'telemedicine->helps to->reduce costs and improve the quality of service',
#   'text': 'telemedicine->helps to->reduce costs and improve the quality of service'},
#  {'id': 'HIPAA->requires->a set of standards - the Privacy Rule and the Security Rule',
#   'text': 'HIPAA->requires->a set of standards - the Privacy Rule and the Security Rule'},
#  {'id': "federal and state privacy laws->require->health care providers to obtain patients' written consent before they disclose their health information to other people and organizations",
#   'text': "federal and state privacy laws->require->health care providers to obtain patients' written consent before they disclose their health information to other people and organizations"},
#  {'id': 'analytical maturity->level of->medical facilities',
#   'text': 'analytical maturity->level of->medical facilities'},
#  {'id': 'healthcare institutions->can use->big data tools',
#   'text': 'healthcare institutions->can use->big data tools'},
#  {'id': 'HIPAA Security Rule->covers->data integrity->confidentiality->and availability of data',
#   'text': 'HIPAA Security Rule->covers->data integrity->confidentiality->and availability of data'},
#  {'id': 'Life Sciences->analytics in the field of->used for several years in pharmaceutical forms and companies producing medical equipment',
#   'text': 'Life Sciences->analytics in the field of->used for several years in pharmaceutical forms and companies producing medical equipment'},
#  {'id': 'analytics->allow access to->statistical forecasts',
#   'text': 'analytics->allow access to->statistical forecasts'},
#  {'id': 'bad actors->want access to->patient information',
#   'text': 'bad actors->want access to->patient information'},
#  {'id': 'Trinity Health->affected by->ransomware attack attempt',
#   'text': 'Trinity Health->affected by->ransomware attack attempt'},
#  {'id': 'HIPAA->consists of->privacy rule and security rule',
#   'text': 'HIPAA->consists of->privacy rule and security rule'},
#  {'id': 'medical facilities->collect and use->data from various sources',
#   'text': 'medical facilities->collect and use->data from various sources'},
#  {'id': 'healthcare organizations->experienced a data breach->93%',
#   'text': 'healthcare organizations->experienced a data breach->93%'},
#  {'id': 'data breach->occurred in->Newkirk Products',
#   'text': 'data breach->occurred in->Newkirk Products'},
#  {'id': 'My Health->My Data Act->designed to protect->independence and dignity of individuals when making healthcare decisions',
#   'text': 'My Health->My Data Act->designed to protect->independence and dignity of individuals when making healthcare decisions'},
#  {'id': 'supply chain->weakened or fragmented->everything else',
#   'text': 'supply chain->weakened or fragmented->everything else'},
#  {'id': 'software->collect->arrange->analyze data->ensure finances are in check->facility remains profitable',
#   'text': 'software->collect->arrange->analyze data->ensure finances are in check->facility remains profitable'},
#  {'id': 'data breach->compromised->social security numbers->names->addresses->phone numbers->personal health data->clinical notes->lab tests->prescription information',
#   'text': 'data breach->compromised->social security numbers->names->addresses->phone numbers->personal health data->clinical notes->lab tests->prescription information'},
#  {'id': 'Big Data->relies on->ability to detect patterns and turn data into actionable knowledge',
#   'text': 'Big Data->relies on->ability to detect patterns and turn data into actionable knowledge'},
#  {'id': 'doctors->compare->data in a socio-economic context',
#   'text': 'doctors->compare->data in a socio-economic context'},
#  {'id': 'data protection standards->outlined in->HIPAA',
#   'text': 'data protection standards->outlined in->HIPAA'},
#  {'id': 'medical facilities->are moving towards->data-based healthcare',
#   'text': 'medical facilities->are moving towards->data-based healthcare'},
#  {'id': 'data encryption policy->aligns with->federal standards',
#   'text': 'data encryption policy->aligns with->federal standards'},
#  {'id': 'data breach->impacted->healthcare providers and plans',
#   'text': 'data breach->impacted->healthcare providers and plans'},
#  {'id': 'Electronic Health Records->most widespread application of->big data in medicine',
#   'text': 'Electronic Health Records->most widespread application of->big data in medicine'},
#  {'id': 'healthcare data analysis->purpose of->using data-driven findings to predict and solve a problem before it is too late',
#   'text': 'healthcare data analysis->purpose of->using data-driven findings to predict and solve a problem before it is too late'},
#  {'id': 'breach->involved->unauthorized access to Social Security numbers->names->medical information->and health information',
#   'text': 'breach->involved->unauthorized access to Social Security numbers->names->medical information->and health information'},
#  {'id': 'Business and management->faster and more effective identification of->incorrect or unauthorized financial operations in order to prevent abuse and eliminate errors',
#   'text': 'Business and management->faster and more effective identification of->incorrect or unauthorized financial operations in order to prevent abuse and eliminate errors'},
#  {'id': 'HIPAA->create->standards that protect the privacy of identifiable health information',
#   'text': 'HIPAA->create->standards that protect the privacy of identifiable health information'},
#  {'id': 'Guidelines on the protection of individuals with regard to the processing of personal data in a world of Big Data->provides suggested measures->for preventing any possible negative effects->of the use of Big Data on human rights and freedoms',
#   'text': 'Guidelines on the protection of individuals with regard to the processing of personal data in a world of Big Data->provides suggested measures->for preventing any possible negative effects->of the use of Big Data on human rights and freedoms'},
#  {'id': 'organizations->must be ready to comply with->prohibition on geofencing',
#   'text': 'organizations->must be ready to comply with->prohibition on geofencing'},
#  {'id': 'Supporting the work of medical personnel->identification of->patients who are predicted to have the highest risk of specific->life-threatening diseases by collating data on the history of the most common diseases->in healing people with reports entering insurance companies',
#   'text': 'Supporting the work of medical personnel->identification of->patients who are predicted to have the highest risk of specific->life-threatening diseases by collating data on the history of the most common diseases->in healing people with reports entering insurance companies'},
#  {'id': 'Improving the quality of healthcare services->detection of->more effective->from a medical point of view->and more cost-effective ways to diagnose and treat patients',
#   'text': 'Improving the quality of healthcare services->detection of->more effective->from a medical point of view->and more cost-effective ways to diagnose and treat patients'},
#  {'id': 'analytics->help prevent security threats->by identifying changes in network traffic or any other behavior',
#   'text': 'analytics->help prevent security threats->by identifying changes in network traffic or any other behavior'},
#  {'id': 'consumers->demand->more rights to access->delete->or withdraw consent of their PHI',
#   'text': 'consumers->demand->more rights to access->delete->or withdraw consent of their PHI'},
#  {'id': 'CCCs across Europe->offer the potential to->increase the number of patients that can be offered molecular profiling and individualized treatment',
#   'text': 'CCCs across Europe->offer the potential to->increase the number of patients that can be offered molecular profiling and individualized treatment'},
#  {'id': 'Health Insurance Portability and Accountability Act HIPAA->sets out to create->framework for data protection',
#   'text': 'Health Insurance Portability and Accountability Act HIPAA->sets out to create->framework for data protection'},
#  {'id': "Supporting the work of medical personnel->doctors' comparison of->current medical cases to cases from the past for better diagnosis and treatment adjustment",
#   'text': "Supporting the work of medical personnel->doctors' comparison of->current medical cases to cases from the past for better diagnosis and treatment adjustment"},
#  {'id': 'OneTouchPoint->noticed->files had been locked and decrypted in July 2022',
#   'text': 'OneTouchPoint->noticed->files had been locked and decrypted in July 2022'},
#  {'id': 'telemedicine->used for->primary consultations and initial diagnosis',
#   'text': 'telemedicine->used for->primary consultations and initial diagnosis'},
#  {'id': 'Big Data->offers paths and solutions->to improve health of individual persons',
#   'text': 'Big Data->offers paths and solutions->to improve health of individual persons'},
#  {'id': 'big data in healthcare->applied in the form of->hospital KPI dashboard',
#   'text': 'big data in healthcare->applied in the form of->hospital KPI dashboard'},
#  {'id': 'HIPAA->is regulated by->the Department of Health and Human Services',
#   'text': 'HIPAA->is regulated by->the Department of Health and Human Services'},
#  {'id': 'Big Data Analytics->allows to analyze->large datasets from thousands of patients',
#   'text': 'Big Data Analytics->allows to analyze->large datasets from thousands of patients'},
#  {'id': 'data breach->violated->HIPAA security rule 45 CFR § 164.308',
#   'text': 'data breach->violated->HIPAA security rule 45 CFR § 164.308'},
#  {'id': 'historical->real-time->predictive metrics->data visualization techniques->identify strengths and weaknesses in trials or processes',
#   'text': 'historical->real-time->predictive metrics->data visualization techniques->identify strengths and weaknesses in trials or processes'},
#  {'id': 'data breach->impacted->millions of individuals',
#   'text': 'data breach->impacted->millions of individuals'},
#  {'id': 'sensitive patient data->compromised->names->birth dates->social security numbers->phone numbers->addresses',
#   'text': 'sensitive patient data->compromised->names->birth dates->social security numbers->phone numbers->addresses'},
#  {'id': 'healthcare providers->use of analytics by->main recipients and users of analytical systems in healthcare',
#   'text': 'healthcare providers->use of analytics by->main recipients and users of analytical systems in healthcare'},
#  {'id': 'Big Data->requires->relevant stakeholders to collaborate and adapt systems',
#   'text': 'Big Data->requires->relevant stakeholders to collaborate and adapt systems'},
#  {'id': 'Cassie CMP software->provides->full HIPAA and GDPR compliance',
#   'text': 'Cassie CMP software->provides->full HIPAA and GDPR compliance'},
#  {'id': 'Big Data Analytics->result of data processing->appropriate data storytelling',
#   'text': 'Big Data Analytics->result of data processing->appropriate data storytelling'},
#  {'id': 'big data->has inherent security issues',
#   'text': 'big data->has inherent security issues'},
#  {'id': 'technology->allows hospitals->prevent the spread of the virus',
#   'text': 'technology->allows hospitals->prevent the spread of the virus'},
#  {'id': 'covered health care providers->may decide to offer->patients a choice as to whether their health information may be exchanged electronically',
#   'text': 'covered health care providers->may decide to offer->patients a choice as to whether their health information may be exchanged electronically'},
#  {'id': 'big data in healthcare->can help->improve the quality of life',
#   'text': 'big data in healthcare->can help->improve the quality of life'},
#  {'id': "My Health->My Data Act->increases protections regarding->collection->sharing->and sale of health data without the consumer's knowledge",
#   'text': "My Health->My Data Act->increases protections regarding->collection->sharing->and sale of health data without the consumer's knowledge"},
#  {'id': 'medical facilities->use->structured and unstructured data',
#   'text': 'medical facilities->use->structured and unstructured data'},
#  {'id': 'Big Data Analytics->can be used for->better diagnosis in the context of comprehensive patient data',
#   'text': 'Big Data Analytics->can be used for->better diagnosis in the context of comprehensive patient data'},
#  {'id': 'health data->valuable commodity->cybercriminals',
#   'text': 'health data->valuable commodity->cybercriminals'},
#  {'id': 'advanced analytical tools->analyze data->all possible sources',
#   'text': 'advanced analytical tools->analyze data->all possible sources'},
#  {'id': 'HIPAA->focuses on->electronically transmitted patient data',
#   'text': 'HIPAA->focuses on->electronically transmitted patient data'},
#  {'id': 'What data was compromised?', 'text': 'What data was compromised?'},
#  {'id': 'Big Data->requires->technological infrastructure and investment in human capital',
#   'text': 'Big Data->requires->technological infrastructure and investment in human capital'},
#  {'id': 'Supporting the work of medical personnel->detection of->diseases at earlier stages when they can be more easily and quickly cured',
#   'text': 'Supporting the work of medical personnel->detection of->diseases at earlier stages when they can be more easily and quickly cured'},
#  {'id': 'Big Data->can help identify and promptly intervene on->high-risk and high-cost patients',
#   'text': 'Big Data->can help identify and promptly intervene on->high-risk and high-cost patients'},
#  {'id': 'medical facility ownership->affects->data collection',
#   'text': 'medical facility ownership->affects->data collection'},
#  {'id': 'big data in healthcare->application of->patient dashboard displaying relevant metrics related to patient experience and care',
#   'text': 'big data in healthcare->application of->patient dashboard displaying relevant metrics related to patient experience and care'},
#  {'id': 'FTC->issued->a Notice of Proposed Rulemaking seeking public comments on proposed changes to the Health Breach Notification Rule',
# ...
#  {'id': 'Big Data Analysis->potential areas of use->healthcare',
#   'text': 'Big Data Analysis->potential areas of use->healthcare'},
#  {'id': 'big data->assist in managing and tracking mass diseases',
#   'text': 'big data->assist in managing and tracking mass diseases'},
#  {'id': 'data breach->violated->data protection standards outlined in HIPAA',
#   'text': 'data breach->violated->data protection standards outlined in HIPAA'},
#  {'id': 'Learn from this data breach', 'text': 'Learn from this data breach'},
#  {'id': 'CTDPA amendment->further defines->consumer health data in categories - gender-affirming health data and reproductive or sexual health data',
#   'text': 'CTDPA amendment->further defines->consumer health data in categories - gender-affirming health data and reproductive or sexual health data'},
#  {'id': 'medical facilities->use extensively->information published in databases->reports to external units->and transaction data',
#   'text': 'medical facilities->use extensively->information published in databases->reports to external units->and transaction data'},
#  {'id': 'predictive analytics->allows to identify->risk factors for a given patient',
#   'text': 'predictive analytics->allows to identify->risk factors for a given patient'},
#  {'id': "U.S. Department of Health and Human Services->does not set out->specific steps or requirements for obtaining a patient's choice whether to participate in eHIE",
#   'text': "U.S. Department of Health and Human Services->does not set out->specific steps or requirements for obtaining a patient's choice whether to participate in eHIE"},
#  {'id': 'medical facilities->use->data and analytical systems to support clinical decisions',
#   'text': 'medical facilities->use->data and analytical systems to support clinical decisions'},
#  {'id': 'electronic medical records->enable the compilation of->health services',
#   'text': 'electronic medical records->enable the compilation of->health services'},
#  {'id': 'Improving the quality of healthcare services->analysis of->large volumes of data to reach practical information useful for identifying needs->introducing new health services->preventing and overcoming crises',
#   'text': 'Improving the quality of healthcare services->analysis of->large volumes of data to reach practical information useful for identifying needs->introducing new health services->preventing and overcoming crises'},
#  {'id': 'Centers for Medicare and Medicaid Services->saved over $210.7 million in fraud->in just a year',
#   'text': 'Centers for Medicare and Medicaid Services->saved over $210.7 million in fraud->in just a year'},
#  {'id': 'OTP->noticed->files had been locked and decrypted',
#   'text': 'OTP->noticed->files had been locked and decrypted'},
#  {'id': 'Business and management->identification of->unnecessary medical activities and procedures->e.g. duplicate tests',
#   'text': 'Business and management->identification of->unnecessary medical activities and procedures->e.g. duplicate tests'},
#  {'id': 'big data and forecasting->identify and prevent->fraud or human error quickly',
#   'text': 'big data and forecasting->identify and prevent->fraud or human error quickly'},
#  {'id': 'OTP->undergoing->class-action lawsuit',
#   'text': 'OTP->undergoing->class-action lawsuit'},
#  {'id': 'drug costs->claims denial rates->reimbursement rates->financial indicators->unique to healthcare sector',
#   'text': 'drug costs->claims denial rates->reimbursement rates->financial indicators->unique to healthcare sector'},
#  {'id': 'massive data sets->diverse sources->medical records->individual human behaviors',
#   'text': 'massive data sets->diverse sources->medical records->individual human behaviors'},
#  {'id': 'hospitals->save->up to $10 million per year',
#   'text': 'hospitals->save->up to $10 million per year'},
#  {'id': 'HCA Healthcare->reported->breach to OCR in July',
#   'text': 'HCA Healthcare->reported->breach to OCR in July'},
#  {'id': 'digital data protection rights bill->is being progressed through->the UK Parliament',
#   'text': 'digital data protection rights bill->is being progressed through->the UK Parliament'},
#  {'id': 'healthcare institutions->use->healthcare data analysis to gain insight into who needs support or training',
#   'text': 'healthcare institutions->use->healthcare data analysis to gain insight into who needs support or training'},
#  {'id': 'MASTER trial->illustrated as->an example of a highly successful programme addressing the molecular profiling in cancer patients',
#   'text': 'MASTER trial->illustrated as->an example of a highly successful programme addressing the molecular profiling in cancer patients'},
#  {'id': 'predictive analytics technologies->provide->relevant information regarding admission rates',
#   'text': 'predictive analytics technologies->provide->relevant information regarding admission rates'},
#  {'id': 'Box->integrates with->the apps your organization is already using',
#   'text': 'Box->integrates with->the apps your organization is already using'},
#  {'id': 'obstacles->in the way->patient confidentiality issues',
#   'text': 'obstacles->in the way->patient confidentiality issues'},
#  {'id': 'data-driven analytics->predict->when staff might be needed in particular departments',
#   'text': 'data-driven analytics->predict->when staff might be needed in particular departments'},
#  {'id': "Cassie->spoke directly to->US consumers->in order to delve into the heart of consumer trust and confidence in the healthcare system's ability to protect and uphold data",
#   'text': "Cassie->spoke directly to->US consumers->in order to delve into the heart of consumer trust and confidence in the healthcare system's ability to protect and uphold data"},
#  {'id': 'noncompliance penalties->vary based on->extent of the issue',
#   'text': 'noncompliance penalties->vary based on->extent of the issue'},
#  {'id': 'top administrators->use->holistic view to identify potential bottlenecks->spot trends and patterns->and assess the situation',
#   'text': 'top administrators->use->holistic view to identify potential bottlenecks->spot trends and patterns->and assess the situation'},
#  {'id': 'data breaches->affect->covered entities',
#   'text': 'data breaches->affect->covered entities'},
#  {'id': 'big data->helping to solve->staffing problem in hospitals',
#   'text': 'big data->helping to solve->staffing problem in hospitals'},
#  {'id': 'HIPAA->overrides->other privacy laws that are less protective',
#   'text': 'HIPAA->overrides->other privacy laws that are less protective'},
#  {'id': 'Business and management->increase in->profitability by detecting patients generating high costs or identifying doctors whose work->procedures and treatment methods cost the most and offering them solutions that reduce the amount of money spent',
#   'text': 'Business and management->increase in->profitability by detecting patients generating high costs or identifying doctors whose work->procedures and treatment methods cost the most and offering them solutions that reduce the amount of money spent'},
#  {'id': 'data breach->occurred in->Trinity Health',
#   'text': 'data breach->occurred in->Trinity Health'},
#  {'id': 'healthcare providers->have a financial incentive->to share data that can be used to improve the lives of patients while cutting costs for insurance companies',
#   'text': 'healthcare providers->have a financial incentive->to share data that can be used to improve the lives of patients while cutting costs for insurance companies'},
#  {'id': 'provider->should make every effort to limit->the potential disclosure of private information',
#   'text': 'provider->should make every effort to limit->the potential disclosure of private information'},
#  {'id': 'Big Data->offering solutions->improvement of patient care and generation of value in healthcare organizations',
#   'text': 'Big Data->offering solutions->improvement of patient care and generation of value in healthcare organizations'},
#  {'id': 'researchers->examine tumor samples in biobanks->linked up with patient treatment records',
#   'text': 'researchers->examine tumor samples in biobanks->linked up with patient treatment records'},
#  {'id': 'HITECH Act->covers->vendors of personal health records and third-party service providers not covered by HIPAA',
#   'text': 'HITECH Act->covers->vendors of personal health records and third-party service providers not covered by HIPAA'},
#  {'id': 'organization->use->data and analytical systems to support clinical decisions',
#   'text': 'organization->use->data and analytical systems to support clinical decisions'},
#  {'id': "EHRs->help increase efficiency by->making it easier for authorized providers to access patients' medical records",
#   'text': "EHRs->help increase efficiency by->making it easier for authorized providers to access patients' medical records"},
#  {'id': 'Big Data Analytics->can benefit->healthcare stakeholders',
#   'text': 'Big Data Analytics->can benefit->healthcare stakeholders'},
#  {'id': 'Big Data->needs data bases for data to be stored in->programs and tools to be managed->as well as expertise and personnel able to retrieve useful information and visualization to be understood',
#   'text': 'Big Data->needs data bases for data to be stored in->programs and tools to be managed->as well as expertise and personnel able to retrieve useful information and visualization to be understood'},
#  {'id': 'CareSource->mentioned->Clop ransomware group in its breach notification',
#   'text': 'CareSource->mentioned->Clop ransomware group in its breach notification'},
#  {'id': 'HIPAA->covers->several areas relating to health data',
#   'text': 'HIPAA->covers->several areas relating to health data'},
#  {'id': 'medical data analysis->empower->senior staff or operatives to offer support',
#   'text': 'medical data analysis->empower->senior staff or operatives to offer support'},
#  {'id': 'The following data was compromised in the Morley Companies data breach:',
#   'text': 'The following data was compromised in the Morley Companies data breach:'},
#  {'id': 'data->lead to->finding that Desipramine has the ability to help cure certain types of lung cancer',
#   'text': 'data->lead to->finding that Desipramine has the ability to help cure certain types of lung cancer'},
#  {'id': 'form of ownership of medical facility->does not affect->data collection',
#   'text': 'form of ownership of medical facility->does not affect->data collection'},
#  {'id': 'HCA Healthcare->breach occurred->when unauthorized party stole a list of information',
#   'text': 'HCA Healthcare->breach occurred->when unauthorized party stole a list of information'},
#  {'id': 'Big Data Analytics->has the potential for->positive impact and global implications in healthcare',
#   'text': 'Big Data Analytics->has the potential for->positive impact and global implications in healthcare'},
#  {'id': 'projects on Big Data->implemented in Europe->aimed to support->sustainability of health systems',
#   'text': 'projects on Big Data->implemented in Europe->aimed to support->sustainability of health systems'},
#  {'id': 'data breach->compromised->names->dates of birth->social security numbers->Medicaid->health plan identification numbers->some medical data',
#   'text': 'data breach->compromised->names->dates of birth->social security numbers->Medicaid->health plan identification numbers->some medical data'},
#  {'id': 'patient databases->need to be linked up->from different institutions',
#   'text': 'patient databases->need to be linked up->from different institutions'},
#  {'id': 'analytical tools->help streamline the processing of insurance claims',
#   'text': 'analytical tools->help streamline the processing of insurance claims'},
#  {'id': 'data breach->compromised->names->addresses->dates of birth->credit card numbers with expiration dates->demographic information->clinical information->health insurance information',
#   'text': 'data breach->compromised->names->addresses->dates of birth->credit card numbers with expiration dates->demographic information->clinical information->health insurance information'},
#  {'id': 'healthcare organizations->opportunity to grow through->investments in Big Data Analytics',
#   'text': 'healthcare organizations->opportunity to grow through->investments in Big Data Analytics'},
#  {'id': 'Wearables->send->data to the cloud',
#   'text': 'Wearables->send->data to the cloud'},
#  {'id': 'telemedicine->refers to->the delivery of remote clinical services using technology',
#   'text': 'telemedicine->refers to->the delivery of remote clinical services using technology'},
#  {'id': 'Regularly monitor and update security measures to prevent unauthorized access to sensitive data.',
#   'text': 'Regularly monitor and update security measures to prevent unauthorized access to sensitive data.'},
#  {'id': 'big data in healthcare->can help->avoid preventable diseases',
#   'text': 'big data in healthcare->can help->avoid preventable diseases'},
#  {'id': 'MHMDA->goes into effect->March 31->2024',
#   'text': 'MHMDA->goes into effect->March 31->2024'},
#  {'id': 'telehealth visits->can be in the form of->a video call->telephone call->or text messages exchanged between a patient and provider',
#   'text': 'telehealth visits->can be in the form of->a video call->telephone call->or text messages exchanged between a patient and provider'},
#  {'id': 'Big Data->can reveal->new approaches to improve health',
#   'text': 'Big Data->can reveal->new approaches to improve health'},
#  {'id': 'cyber resilience->strengthen->healthcare entities',
#   'text': 'cyber resilience->strengthen->healthcare entities'},
#  {'id': 'Bank account information', 'text': 'Bank account information'},
#  {'id': 'training areas->to focus on->creating strong passwords->securing personal and work-related mobile devices->identifying scams->adopting security measures',
#   'text': 'training areas->to focus on->creating strong passwords->securing personal and work-related mobile devices->identifying scams->adopting security measures'},
#  {'id': 'size of medical facility->has an impact on->collection and use of structured data',
#   'text': 'size of medical facility->has an impact on->collection and use of structured data'},
#  {'id': 'Big Data Analytics->improve decision making->competitive advantage or business performance',
#   'text': 'Big Data Analytics->improve decision making->competitive advantage or business performance'},
#  {'id': 'personal information->included->names->demographic information->health insurance numbers->Social Security numbers->dates of service->phone numbers->and provider names',
#   'text': 'personal information->included->names->demographic information->health insurance numbers->Social Security numbers->dates of service->phone numbers->and provider names'},
#  {'id': 'Optum Labs->collected EHRs of over 30 million patients->to create a database for predictive analysis tools',
#   'text': 'Optum Labs->collected EHRs of over 30 million patients->to create a database for predictive analysis tools'},
#  {'id': 'Cerebral->notified->data breach',
#   'text': 'Cerebral->notified->data breach'},
#  {'id': "EHRs->make it easier for providers to share->patients' records with authorized providers",
#   'text': "EHRs->make it easier for providers to share->patients' records with authorized providers"},
#  {'id': 'Big Data analysis->aims to->improve health and condition of patients',
#   'text': 'Big Data analysis->aims to->improve health and condition of patients'},
#  {'id': 'German Cancer Research Center->develop tools to->grant ways to access and analyse own data together with data from partners',
#   'text': 'German Cancer Research Center->develop tools to->grant ways to access and analyse own data together with data from partners'},
#  {'id': 'analytical systems->enable the compilation of->health services',
#   'text': 'analytical systems->enable the compilation of->health services'},
#  {'id': 'healthcare providers->reported->data breaches of medical and patient records',
#   'text': 'healthcare providers->reported->data breaches of medical and patient records'}]

# %%
import re
for n in _unique_nodes:
    # if the n['text'] is a triplet has a $ replace it with USD, do the same with id
    if re.search(r'\$', n['text']):
        n['text'] = re.sub(r'\$', 'USD', n['text'])
        n['id'] = re.sub(r'\$', 'USD', n['id'])
    # if the n['text'] is a triplet has a % replace it with percent, do the same with id
    if re.search(r'\%', n['text']):
        n['text'] = re.sub(r'\%', 'percent', n['text'])
        n['id'] = re.sub(r'\%', 'percent', n['id'])
    # if the n['text'] is a triplet has a # replace it with number, do the same with id
    if re.search(r'\#', n['text']):
        n['text'] = re.sub(r'\#', 'number', n['text'])
        n['id'] = re.sub(r'\#', 'number', n['id'])

# %%
import pickle
state = {
    n['text']: False for n in _unique_nodes
}
state
# save pickle
with open(f"data/{topic}/state_01.pkl", "wb") as f:
    pickle.dump(state, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pickle
#       2 state = {
# ----> 3     n['text']: False for n in _unique_nodes
#       4 }
#       5 state
#       6 # save pickle
#
# NameError: name '_unique_nodes' is not defined

# %%
import pickle

# open the pickle file
with open(f"data/{topic}/state_01.pkl", "rb") as f:
    state = pickle.load(f)

_unique_nodes = [{
    'id': n,
    'text': n,
} for n in state.keys()]

# %%
import re
# if there is a weird character in the triplet, print it out
for n in _unique_nodes:
    if re.search(r'[^a-zA-Z0-9\-\>\,\(\)\s]', n['text']):
        print(n['text'])
# Out:
# data breach->violated->HIPAA security rule 45 CFR § 164308

# %%
from langchain.embeddings import OpenAIEmbeddings

embeddings_model = OpenAIEmbeddings(openai_api_key="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")

# %%
def get_embedding(text):
    embeddings = embeddings_model.embed_documents(
        [
            text
        ]
    )
    print(len(embeddings))
    print(len(embeddings[0]))
    return embeddings[0]
get_embedding("DPDP Act, passed by, Indian Parliament")
# Out:
# 1
# 1536
# [-0.018329036788204585,
#  -0.002828452183260221,
#  -0.010973392647387037,
#  -0.0031438371128479866,
#  -0.032145901523210806,
#  0.02386913188705095,
#  -0.0015527284225351423,
#  -0.0169406751534885,
#  -0.009511609268442588,
#  -0.016046251606859616,
#  0.027273287155654153,
#  -0.00036753189082360394,
#  0.009491583971060704,
#  -0.004779166394623856,
#  -0.02145284906933196,
#  0.03083763735273207,
#  0.014657889972143531,
#  -0.022867909858793833,
#  0.029903163211339418,
#  0.028354606648148623,
#  0.006237612844886354,
#  0.008029800592116254,
#  0.01987759335139538,
#  0.025711381015090466,
#  0.003375786718193902,
#  0.012134810535441406,
#  0.01954385391707307,
#  -0.03615078963623926,
#  0.008036475380802701,
#  0.0013783488696098257,
#  -0.008917550281381238,
#  -0.02134605245034882,
#  -0.01775500309852512,
#  -0.0355901036612876,
#  0.005596830802681153,
#  -0.011600825577880617,
#  -0.0227477636624378,
#  0.009237941069653201,
#  0.025764779324582036,
#  0.002903543788813377,
#  0.020478326195820632,
#  0.007162074803249337,
#  -0.0067715978024471424,
#  -0.012114786169382066,
#  0.025003849689036985,
#  0.000800143262378354,
#  0.015579013604840744,
#  -0.02346864270321908,
#  -0.029636169801236477,
#  0.013282877914800336,
#  0.020825417070160925,
#  0.0006349416021045601,
#  -0.028301208338657055,
#  -0.012441851746340478,
#  -0.002991984971739426,
#  -0.012815641775426555,
#  -0.00047057431952040154,
#  0.00305372699991969,
#  -0.010559554817504825,
#  -0.0062442876335728,
#  0.013049259379452173,
#  0.002815102373056692,
#  -0.013556545182267177,
#  0.014924882450923924,
#  -0.04055616507045449,
#  -0.0147112882816351,
#  -0.00465901973260655,
#  0.02134605245034882,
#  0.012301681183925106,
#  0.021813289521045148,
#  0.05585483661914195,
#  0.025137347325411,
#  -0.011614175155253509,
#  -0.009184542760161632,
#  0.042638706591206076,
#  -0.020545075945330185,
#  -0.022400672788097507,
#  -0.024616711945223104,
#  -0.02278781239455648,
#  0.0005081201514008092,
#  0.031024531435952563,
#  -0.04528193408690932,
#  -0.00920456712622097,
#  0.0027183177042725856,
#  0.01373676540812377,
#  -0.024189523606645457,
#  -0.03767264518203918,
#  0.013362976310360236,
#  -0.012628746760883516,
#  -0.03601729386251034,
#  0.01045275726719914,
#  0.013349626732987344,
#  0.0061842145353947844,
#  0.007348969352131104,
#  -0.0008401921109123494,
#  0.011360532253846008,
#  0.0037512449787903196,
#  0.023001405632522755,
#  0.032306096451685515,
#  -0.022227128282249906,
#  0.006724874281642018,
#  0.00849703766281258,
#  -0.01300253585864705,
#  -0.01423070163356588,
#  -0.008477012365430697,
#  -0.012254956731797438,
#  -0.017608157747423303,
#  0.016059601184232507,
#  0.009111120084610723,
#  0.01379016371761534,
#  -0.006651451140429838,
#  0.03017015662144236,
#  0.008363540957761111,
#  -0.052143639208317126,
#  0.01505837822465285,
#  -0.002511398556500844,
#  -0.008750680564220082,
#  -0.015886054815739816,
#  -0.0046223079291698235,
#  -0.009678478985603743,
#  0.04151733836659293,
#  0.023935879773915408,
#  0.04990090275909083,
#  0.006060730479034256,
#  0.00579040060591064,
#  -0.012828991352799449,
#  0.008757355352906528,
#  -0.027660426762113124,
#  0.01921011262010567,
#  0.018382435097696156,
#  0.031024531435952563,
#  -0.012141485324127852,
#  0.004525523493216354,
#  -0.009271315944407978,
#  -0.011126913718497845,
#  -0.0091511688167294,
#  0.005359874872989767,
#  0.0006795794260681464,
#  -0.02225382743699569,
#  -0.03201240574948188,
#  0.015645762423027752,
#  0.013623294000454185,
#  -0.018756225126782235,
#  -0.022454071097589075,
#  -0.0031655301760789368,
#  0.031798808786225416,
#  0.03452213374616602,
#  0.028274509183911268,
#  -0.0003435442816701992,
#  0.01678048022501379,
#  0.012141485324127852,
#  -0.0025230794367021247,
#  0.019023218536885177,
#  0.0033540936549629518,
#  -0.020117887606752538,
#  0.022694365352946232,
#  0.010539530451445487,
#  0.010846571662344559,
#  0.014083856282464065,
#  0.0033290631973887782,
#  -0.0011322152218898943,
#  0.006671475972150449,
#  -0.006618077196997607,
#  0.001186447996382588,
#  0.029155585015812353,
#  0.020972262421262742,
#  -0.016913975998742715,
#  -0.01736786349206615,
#  -0.014831435409313677,
#  0.004061623816863251,
#  0.02067857171905911,
#  0.0017771690070241236,
#  -0.017407912224184825,
#  0.012822316564113003,
#  0.01291576360572325,
#  0.02795411746431676,
#  0.0017154269788438596,
#  0.006915106690528281,
#  -0.024029326815525654,
#  0.0030503896055764667,
#  -0.010359310225588893,
#  0.004488811689779626,
#  0.01595280270260428,
#  0.028408004957640193,
#  -0.01786179971750826,
#  -0.009424836084196241,
#  -0.011967939886957704,
#  -0.00952495884581548,
#  -0.010225813520537424,
#  -0.00033061184948638013,
#  0.02127930456348436,
#  0.001151405239363427,
#  -0.011013441379505714,
#  -0.01959725222656464,
#  -0.6574424302505659,
#  -0.03724545870610662,
#  -0.0013825207289541728,
#  -0.017407912224184825,
#  0.00985202442277389,
#  0.0021442837817624836,
#  0.009845349634087444,
#  -0.007635986196970836,
#  -0.018529282311443063,
#  -0.0047057432534116745,
#  0.009585031943993495,
#  0.023268399042625697,
#  0.008156621577158732,
#  -0.009691828562976635,
#  -0.0004082065590046129,
#  -0.011987964253017043,
#  0.030196855776188143,
#  -0.031398321465038646,
#  0.03572359943501652,
#  -0.00808987369029427,
#  -0.01726106687308301,
#  0.019637300958683317,
#  -0.035296412959083964,
#  -0.004989422703908184,
#  -0.013409699831165361,
#  -0.01883632259101959,
#  0.025924974253056746,
#  0.02725993757828126,
#  -0.00030787576321168405,
#  0.013663342732572862,
#  -0.01629989357694457,
#  0.014911532873551032,
#  0.003854704669091509,
#  0.023094854536778096,
#  0.03318717228358659,
#  0.01644673892804639,
#  0.003968176309591731,
#  0.0028034214928554114,
#  0.011013441379505714,
#  0.03700516258810437,
#  -0.02947597487276177,
#  0.012121460958068512,
#  -0.009625080676112173,
#  0.007375668506876889,
#  -0.011006766590819268,
#  0.008183320731904517,
#  0.01646008850541928,
#  -0.013803513294988232,
#  0.019637300958683317,
#  0.0010162403028016185,
#  0.0013958703063270653,
#  0.0019306897288889776,
#  -0.010766473266784657,
#  0.009932121887011244,
#  -0.0026916183166961643,
#  0.0003508448608998293,
#  -0.010566229606191272,
#  -0.002488036563267646,
#  0.016379991041181926,
#  -0.001182276253453559,
#  0.015245273239195889,
#  0.010105667324181392,
#  0.0019924316406539234,
#  -0.013436398985911145,
#  -0.0026115206196281734,
#  -0.02388248146442384,
#  0.007469116014148409,
#  -0.0022260501760020864,
#  0.007068627295977817,
#  -0.023735636113322023,
#  -0.02742013250675597,
#  0.02416282445189967,
#  0.017314465182574578,
#  -0.01533872121212868,
#  0.019183413465359882,
#  -0.004875950830577325,
#  0.02041157830895617,
#  -0.009758576449841096,
#  -0.023028104787268543,
#  0.013095983831579843,
#  -0.016740431492895114,
#  -0.014070506705091173,
#  -0.008757355352906528,
#  0.011981289464330597,
#  0.01775500309852512,
#  -0.0012356747957757651,
#  0.001454274940164106,
#  0.002775053640938015,
#  0.020932213689144066,
#  0.0003616914507229635,
#  0.015418818676366035,
#  0.008083198901607825,
#  0.009705178140349527,
#  -0.0006633095704372747,
#  0.004058286422520027,
#  0.005496708506723187,
#  0.001825561457831495,
#  -0.01221490799967876,
#  0.012889064450977464,
#  0.013449748563284037,
#  -0.009945471464384136,
#  0.0031655301760789368,
#  -0.005066183239463588,
#  -0.011433954929396917,
#  0.04450765487399138,
#  0.013282877914800336,
#  -0.012768917323298887,
#  0.016393340618554818,
#  0.021372751605094605,
#  -0.002950267542449137,
#  0.015472216985857604,
#  -0.01844918298456062,
#  -0.0225742191565902,
#  -0.00754253915536059,
#  -0.002808427584370246,
#  -0.03636438287420554,
#  0.009771926958536535,
#  -0.00021880871698287758,
#  -0.006744898647701357,
#  -0.00033290630809734603,
#  0.005580143830965038,
#  -0.03636438287420554,
#  0.03284007954660121,
#  -0.021092410480263866,
#  -0.015699160732519323,
#  0.030383749859408636,
#  -0.015298671548687458,
#  -0.01708752236723541,
#  -0.002494711351954092,
#  -0.003617748739400123,
#  -0.0033006951126407454,
#  0.004315266718270753,
#  0.000849787177856775,
#  0.004018237690401351,
#  0.03919450445312928,
#  0.011106889352438505,
#  0.0016061269648573484,
#  -0.0015760902993530222,
#  -0.009805300901968766,
#  -0.018395784675069048,
#  -0.024443165576730413,
#  -0.003971513703934954,
#  0.004552222647962139,
#  -0.006674813366493672,
#  -0.015579013604840744,
#  -0.03452213374616602,
#  -0.023388545238981727,
#  -0.011574126423134832,
#  -0.015271972393941673,
#  -0.006210913690140569,
#  -0.010552880028818379,
#  0.00012588280854471936,
#  -0.02508394715327434,
#  0.016059601184232507,
#  0.0005131262429156439,
#  -0.001725439161873529,
#  0.017341164337320365,
#  0.0027566977392196514,
#  -0.00444876295766095,
#  -0.04109015189066037,
#  0.004068298605549697,
#  0.006754910830731027,
#  0.0016128017535437945,
#  -0.014123905014582742,
#  0.0003470902922637033,
#  -0.001878959883738383,
#  0.004815877732399309,
#  0.026952895436059644,
#  -0.013055935099461166,
#  -0.02471015898683335,
#  0.022026882759011428,
#  -0.0004634823565410524,
#  0.007102001239410048,
#  0.01879627385890091,
#  0.014390897493363137,
#  -0.010345960648216001,
#  0.011847793690601672,
#  -0.038126534538007704,
#  0.010339285859529555,
#  0.007662685351716621,
#  -0.01515182619758564,
#  0.00968515377429019,
#  -0.00720879832405446,
#  -0.02313490326889677,
#  0.020518374927939308,
#  0.009658454619544404,
#  0.0018973156690414283,
#  0.015725859887265107,
#  -0.021265954986111467,
#  0.013229479605308767,
#  -0.006354422112560435,
#  0.027059692055042783,
#  0.005176317718451224,
#  0.008123247633726502,
#  0.0011781045105245301,
#  0.015899404393112708,
#  0.022293876169114366,
#  -0.004862601253204433,
#  0.023535390590083544,
#  0.01091331954920902,
#  0.02349534185796487,
#  -0.008830778028457437,
#  0.021519596956196423,
#  -0.008270093916150864,
#  0.008723980478151752,
#  -0.028141013410182346,
#  -0.006110791394182603,
#  -0.028941989915200982,
#  0.012228257577051652,
#  0.039034305799364385,
#  0.0037812817607099643,
#  -0.006908431901841835,
#  -0.014017107464277057,
#  0.007842905577573214,
#  -0.021372751605094605,
#  0.029849764901847847,
#  -0.00987204878883323,
#  0.006921781479214728,
#  -0.0019340271232322005,
#  0.001772162915509289,
#  0.018889720900511157,
#  -0.02127930456348436,
#  0.011781044872414664,
#  -0.005663579155206888,
#  -0.005993982126508522,
#  -0.005323163535214313,
#  -0.001787181190053793,
#  0.022867909858793833,
#  0.01291576360572325,
#  -0.017981945913864292,
#  -0.015725859887265107,
#  -0.01041938332376691,
#  -0.0004526357667179182,
#  0.018929769632629836,
#  0.011861143267974565,
#  -0.022707714930319124,
#  -0.01091331954920902,
#  -0.013710066253377985,
#  0.043946968899039714,
#  -0.0029218994577011044,
#  0.009878723577519675,
#  -0.009698503351663081,
#  0.026846098817076506,
#  -0.014631190817397745,
#  -0.012428502168967584,
#  -0.019250161352224345,
#  0.015886054815739816,
#  0.01975744715503935,
#  -0.02620531724053258,
#  0.010379334591648233,
#  -0.004692393676038782,
#  -0.004675706704322666,
#  -0.008396914901193342,
#  0.0010537861055781965,
#  0.014511043689719168,
#  -0.011120238929811399,
#  0.020772018760669357,
#  0.0371119629323777,
#  -0.0010053937711861434,
#  0.015271972393941673,
#  0.011821094535855888,
#  0.015525615295349175,
#  0.03046384732364599,
#  -0.008610509070482166,
#  0.024776906873697813,
#  -0.0052397282109724625,
#  0.010098992535494945,
#  -0.004682381493009113,
#  -0.012788941689358225,
#  -0.019089966423749636,
#  -0.007288896253953088,
#  -0.00800310143737047,
#  -0.00843696363331202,
#  -0.01226830630917033,
#  0.01416395374670142,
#  0.015765908619383782,
#  -0.00614750319761933,
#  0.005847136309745432,
#  0.007268871422232476,
#  -0.0002613606549300347,
#  -0.014778036168499561,
#  -0.015979503719995153,
#  -0.0007096160915724726,
#  0.03324057059307817,
#  -0.005169642929764778,
#  -0.009264641155721532,
#  -0.030357050704662852,
#  -0.006818321788913538,
#  -0.023922530196542516,
#  0.020731970028550678,
#  -0.020972262421262742,
#  0.04076975830842077,
#  0.008683931746033074,
#  -0.003681159464751998,
#  -0.0024296319294306048,
#  -0.02085211622490671,
#  0.02437641768986595,
#  0.008804078873711652,
#  -0.005066183239463588,
#  0.010466106844572033,
#  0.01279561647804467,
#  0.01226830630917033,
#  0.0005865492095048477,
#  -0.0070018789434520825,
#  0.04832564890379934,
#  -0.004729105013814236,
#  -0.004318604112613976,
#  -0.024937101802172523,
#  0.0074824655915213005,
#  -0.011494028027574932,
#  0.00656801628184926,
#  0.0034875898943531485,
#  0.008123247633726502,
#  0.027166490536671015,
#  -0.006741561253358134,
#  -0.007862929943632553,
#  -0.012822316564113003,
#  0.012935787971782587,
#  0.018062045240746737,
#  -0.016246495267453004,
#  -0.008223369464023194,
#  -0.027927418309570975,
#  -0.0010270868344170936,
#  0.0008785722622747334,
#  0.09889403425682498,
#  0.014537742844464952,
#  -0.006968505000019851,
#  -0.01533872121212868,
#  -0.02838130580289441,
#  0.001519354362687593,
#  -0.017341164337320365,
#  -0.01646008850541928,
#  0.01971739842292067,
#  -0.014070506705091173,
#  -0.0005419113855412614,
#  -0.012668795493002193,
#  -0.00021442837235548245,
#  -0.020104538029379643,
#  0.0056201925630837155,
#  -0.00017646538073408664,
#  -0.0037178710353580886,
#  -0.015418818676366035,
#  -0.015619063268281967,
#  -0.011133588507184291,
#  -0.00224106845054659,
#  0.002571471887509496,
#  0.014030457041649949,
#  0.051636355268147215,
#  -0.0039014284227272687,
#  -0.01549891614060339,
#  0.025377639718123065,
#  0.025858226366192283,
#  0.012461876112399815,
#  0.010566229606191272,
#  -0.0038246678871718645,
#  0.016473438082792172,
#  0.009631755464798619,
#  0.005096219788552596,
#  -0.01736786349206615,
#  0.01654018783230173,
#  0.004578921802707923,
#  -0.005923896845300836,
#  0.003272327260723349,
#  0.023255049465252805,
#  0.030063358139814127,
#  0.01093334391526836,
#  0.00480586554936964,
#  0.0006612236989727603,
#  0.029609470646490693,
#  -0.005807087577626754,
#  -0.004702405859068452,
#  0.021412800337213284,
#  -0.006701512521239457,
#  -0.008730655266838198,
#  0.021439499491959068,
#  -0.0009628418186870715,
#  -0.025911624675683854,
#  0.005012784929972019,
#  0.0022811174154959038,
#  -0.004305254535241083,
#  -0.0003149677552948627,
#  -0.0046556823382633275,
#  0.006491255746293855,
#  -0.015472216985857604,
#  -0.023588790762220205,
#  -0.026685903888601797,
#  -0.000906940230607448,
#  -0.0005777884911462279,
#  -0.011801070169796549,
#  -0.008196670309277409,
#  -0.021199207099247004,
#  -0.00920456712622097,
#  -0.011654223887372186,
#  0.0014642871231937754,
#  -0.001175601464767113,
#  -0.04359987988734451,
#  -0.0181287931276112,
#  -0.007522514323639978,
#  0.014831435409313677,
#  0.006594715436595045,
#  0.040209076058759285,
#  -0.020705270873804894,
#  0.0072421722674866915,
#  -0.003817993098485418,
#  -0.019637300958683317,
#  -0.024336368957747274,
#  0.004495486478466073,
#  -0.006311035986098535,
#  0.0019457080034334816,
#  0.015098427888094072,
#  -0.0013800176831967556,
#  0.004478799506749957,
#  -0.027713825071604695,
#  0.014671239549516423,
#  -0.01132048352172733,
#  -0.01202801298513572,
#  0.01987759335139538,
#  -0.014297449520430343,
#  -0.017007424902998055,
#  0.020932213689144066,
#  0.010018895071257592,
#  0.020731970028550678,
#  -0.010799848141539435,
#  0.020932213689144066,
#  0.02476355729632492,
#  -0.010980067436073482,
#  -0.026298764282142825,
#  0.007916328253124123,
#  0.023695587381203344,
#  0.009518284057129034,
#  0.02328174861999859,
#  0.015605713690909075,
#  0.006968505000019851,
#  -0.007589262676165713,
#  0.020598474254821756,
#  -0.03534981126857553,
#  -0.019116665578495423,
#  -0.015231923661822995,
#  -0.0003975685563279301,
#  0.023068155382032312,
#  -0.006684825549523342,
#  0.0017079178415716077,
#  0.0012607053697652566,
#  -0.0017921873979839457,
#  -0.008543761183617705,
#  -0.0042385061827153485,
#  0.0016470101619771495,
#  0.008069849324234931,
#  -0.02007783887463386,
#  -0.0032706585635517375,
#  -0.005189667295824116,
#  0.011407255774651131,
#  -0.0009937127745695442,
#  0.0007258859472033443,
#  0.009551658000561264,
#  0.013262853548740999,
#  0.017461310533676395,
#  -0.023695587381203344,
#  -0.02599172213992121,
#  0.015125127042839857,
#  -0.0021492898732773185,
#  0.017074172789862514,
#  -0.005596830802681153,
#  -0.022120331663266764,
#  -0.00035001051231402355,
#  -0.01298251149258771,
#  0.007595937464852159,
#  -0.02334849650686305,
#  0.001760482035308008,
#  -0.011740996140295987,
#  0.002262761746608177,
#  -0.01031258670478377,
#  -0.006341072535187543,
#  0.030543944787883345,
#  -0.005793738000253863,
#  -0.0009469891373491025,
#  -0.006084092239436819,
#  0.0015894398767259147,
#  -0.030490546478391778,
#  -0.04506833712365286,
#  -0.01900986709686719,
#  -0.031371622310292856,
#  0.015018329492534172,
#  0.02388248146442384,
#  0.01818219143710277,
#  -0.008196670309277409,
#  -0.0010504487112349735,
#  -0.008977623379559253,
#  0.008477012365430697,
#  -0.007515839534953532,
#  0.015979503719995153,
#  -0.029662870818627354,
#  -0.02528419267651282,
#  -0.004662357126949774,
#  0.01846253256193351,
#  0.00443875077463128,
#  -0.0018772911865667715,
#  -0.0037812817607099643,
#  0.004645670155233659,
#  -0.00966512940823085,
#  0.007015228520824974,
#  -0.005012784929972019,
#  -0.007222147901427353,
#  -0.008176645943218071,
#  -0.0006583034789224401,
#  -0.0036911716477816673,
#  0.006227600661856685,
#  0.015645762423027752,
#  -0.032119202368465015,
#  0.007368993718190443,
#  0.045201836622671965,
#  -0.006217588478827015,
#  0.008350191380388219,
#  0.013509821661462054,
#  0.03163861385775071,
#  -0.00711535081678294,
#  0.03898090748987282,
#  0.007709409338183018,
#  -0.009504933548433596,
#  -0.02258756873396309,
#  -0.0064144956763997245,
#  -0.002224381478830475,
#  0.01903656811425807,
#  0.02449656388622198,
#  0.00033061184948638013,
#  0.01580595735150246,
#  -0.0022060258099427478,
#  -0.008650557802600843,
#  -0.028434704112385977,
#  0.018275638478713017,
#  -0.0047124180420981205,
#  -0.017674905634287766,
#  0.005613517774397269,
#  -0.0359371926729828,
#  -0.022160380395385443,
#  -0.02784732084533362,
#  -0.046216408228301975,
#  -0.0478984587025766,
#  0.006314373380441758,
#  -0.004989422703908184,
#  -0.007842905577573214,
#  0.02063852298694043,
#  0.0033574310493061747,
#  -0.015525615295349175,
#  -0.0006462053662205972,
#  -0.02774052422635048,
#  -0.009024347831686923,
#  -0.0032105852325430852,
#  0.013282877914800336,
#  0.0010621297078515725,
#  -0.002818439767399915,
#  -0.021799939943672256,
#  0.008503712451499027,
#  -0.0294225765632702,
#  -0.016593586141793296,
#  0.02910218484367569,
#  0.0318255079409712,
#  -0.014737987436380886,
#  -0.03449543459142024,
#  0.0007509164629851767,
#  0.028541500731369115,
#  0.006150840591962553,
#  0.005299801774811751,
#  0.023962578928661195,
#  0.003801306126769303,
#  0.0008944249436127022,
#  0.01033261107084311,
#  0.003971513703934954,
#  -0.017020774480370947,
#  0.02154629611094221,
#  0.005169642929764778,
#  0.012181534056246529,
#  -0.004141721746761878,
#  -0.010853246451031005,
#  -0.02688614754919518,
#  -0.01758145859267752,
#  -0.01484478498668657,
#  -0.01245520132371337,
#  0.006955155422646958,
#  -0.0024413130424625223,
#  -0.014951581605669709,
#  -0.015458867408484712,
#  -0.017114221521981193,
#  -0.01460449166265196,
#  -0.026846098817076506,
#  0.004518848704529907,
#  -0.0034341913520309427,
#  0.01655353740967462,
#  -0.008236719041396086,
#  -0.002054173668834187,
#  -0.01786179971750826,
#  0.013583245268335507,
#  -0.006324385563471428,
#  0.02763372760736734,
#  -0.007602612253538606,
#  -0.010459432055885587,
#  0.017501361128440165,
#  0.023762335268067807,
#  0.023481992280591973,
#  -0.008957599013499915,
#  -0.014150604169328528,
#  -0.01703412405774384,
#  -0.0026031771337701156,
#  0.0037812817607099643,
#  -0.007055277718604925,
#  0.007549213944047036,
#  -0.013763464562869554,
#  -0.0041817704788805555,
#  -0.0013383000210758303,
#  -0.016700382760776438,
#  0.0017888498872254044,
#  -0.02042492788632906,
#  0.029395877408524416,
#  0.01354987039358073,
#  -0.010766473266784657,
#  0.0009227929119454168,
#  -0.032973579045620316,
#  0.02404267639289855,
#  0.0073289449860717655,
#  0.02154629611094221,
#  0.0032389530844604817,
#  0.013536520816207839,
#  -0.023001405632522755,
#  0.002588158859225612,
#  0.000592806823898391,
#  0.03465562951989494,
#  -0.022066933353775197,
#  -0.0031238125139580117,
#  -0.01775500309852512,
#  -0.02042492788632906,
#  0.031718711321988065,
#  -0.020157936338871214,
#  -0.05064848281726299,
#  -0.03502942141162611,
#  -0.009464884816314918,
#  -0.0077761572250474795,
#  0.0003149677552948627,
#  -0.007829556000200322,
#  0.013583245268335507,
#  -0.0024279632322589933,
#  0.004151733929791547,
#  -0.02150624737882353,
#  -0.013496472084089162,
#  0.030917734816969425,
#  0.006684825549523342,
#  0.012134810535441406,
#  0.011113564141124953,
#  0.0001990971588836422,
#  0.029182284170558136,
#  -0.005346525295616875,
#  0.006638101563056945,
#  0.010359310225588893,
#  -0.02724658800090837,
#  0.00122482826416029,
#  0.0008105726197009262,
#  0.014964931183042601,
#  -0.030784239043240503,
#  -0.009731877295095313,
#  -0.015645762423027752,
#  -0.004235168788372125,
#  0.001277392341481372,
#  0.025444387604987528,
#  0.00244965652832058,
#  0.012328380338670892,
#  0.026191967663159687,
#  0.018142142704984092,
#  0.0036077365563704535,
#  -0.006975179788706297,
#  -0.006361096901246882,
#  -0.012315030761298,
#  -0.02150624737882353,
#  -0.010085642958122053,
#  -0.020865465802279604,
#  -0.008837452817143883,
#  -0.02768712591685891,
#  0.005159630746735108,
#  0.004572247014021477,
#  -0.005516733338443799,
#  -0.002573140584681108,
#  0.002396257985998374,
#  -0.033534261295281795,
#  0.005977295154792406,
#  -0.008530411606244811,
#  0.024736858141579138,
#  0.014671239549516423,
#  0.011433954929396917,
#  0.0038580420634347318,
#  0.010439407689826248,
#  0.008510387240185473,
#  0.01770160478903355,
#  -0.0195038033223093,
#  -0.02692619628131386,
#  0.012441851746340478,
#  -0.018195541014475663,
#  0.0112070111827352,
#  0.018062045240746737,
#  -0.0026649191619503797,
#  0.003175542359108606,
#  0.02883519329621784,
#  -0.007395692872936227,
#  0.019063267269003852,
#  -0.008316817436955988,
#  0.002751691647704817,
#  -0.025751429747209145,
#  -0.005189667295824116,
#  -0.0014759681198103743,
#  -0.014831435409313677,
#  -0.00754253915536059,
#  -0.00444876295766095,
#  -0.009257966367035086,
#  0.0017421262500049628,
#  -0.007602612253538606,
#  -0.007896303887064785,
#  -0.012722193802493764,
#  -0.016246495267453004,
#  0.008410264478566234,
#  -0.009057721775119154,
#  0.009925447098324798,
#  -0.013009210647333496,
#  -0.011574126423134832,
#  -0.0048893008736114905,
#  -0.03457553205565759,
#  0.017314465182574578,
#  0.00569695309863912,
#  -0.006968505000019851,
#  0.0419178256877797,
#  -0.01953050433970018,
#  0.003631098316773015,
#  -0.010085642958122053,
#  0.022160380395385443,
#  -0.02947597487276177,
#  -0.022480770252334862,
#  0.01060627833830995,
#  -0.01212813574675496,
#  0.04792515785732239,
#  -0.020892164957025387,
#  -0.012949137549155481,
#  -0.023789034422813594,
#  -0.020878815379652495,
#  -0.02030478168997303,
#  0.006367771689933328,
#  -0.018822973013646698,
#  0.03161191470300492,
#  0.010566229606191272,
#  -0.012935787971782587,
#  0.02328174861999859,
#  -0.01364999315519997,
#  0.0064111582820565016,
#  -0.007055277718604925,
#  -0.0018055369753568382,
#  0.015365420366874466,
#  -0.015004979915161278,
#  -0.019971040393005627,
#  0.015071727802025741,
#  -0.02758032743523068,
#  -0.014364198338617351,
#  0.004432075985944834,
#  0.005443310197231618,
#  -0.013696716676005093,
#  0.02083876664753382,
#  0.21957465329201403,
#  -0.01763485690216909,
#  0.009438185661569133,
#  0.018395784675069048,
#  0.0019039904577278744,
#  0.008757355352906528,
#  0.010225813520537424,
#  -0.00800310143737047,
#  0.010239163097910316,
#  -0.0007104504401582784,
#  -0.04125034681913508,
#  0.004645670155233659,
#  -0.019143364733241207,
#  0.006634764168713722,
#  -0.01531202112606035,
#  0.00947823439368781,
#  -0.05959273318471256,
#  -0.01549891614060339,
#  -0.02441646642198463,
#  -0.0050328092960313575,
#  -0.00017271079754604588,
#  -0.01364999315519997,
#  0.0067682604081039195,
#  -0.00042927391900386783,
#  0.01379016371761534,
#  0.00893089985875413,
#  0.02042492788632906,
#  0.0239492293512883,
#  0.01435084876124446,
#  0.02149289780145064,
#  -0.009878723577519675,
#  0.014804735323245347,
#  -0.006791622634167754,
#  -0.0021275968100463684,
#  -0.009378112563391118,
#  0.006751573436387804,
#  0.005953933394389844,
#  -0.02747353081624754,
#  0.005880510253177663,
#  -0.001435084806275255,
#  0.0008627195809367645,
#  0.012828991352799449,
#  -0.0043286162956436445,
#  -0.022160380395385443,
#  -0.014150604169328528,
#  0.034869222757861223,
#  ...]

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
topic_collection.add(
    documents=[str(x['text']) for x in _unique_nodes],
    embeddings = [get_embedding(x['text']) for x in _unique_nodes],
    metadatas=[{
        'topic': topic,
    } for x in _unique_nodes],
    ids=[x['id'] for x in _unique_nodes]
)
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11aac4a40>, 'json_data': {'input': [[23562, 323, 6373, 405, 265, 23985, 315, 405, 16845, 82, 323, 5663, 36022, 11737, 323, 42316, 12659]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=None socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11d765810>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x105c1fc80> server_hostname='api.openai.com' timeout=None
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11d764f10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:37 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'24'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999983'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'18351415bd6790e2f782a7db92c93453'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c350bd58b67283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cd137e0>, 'json_data': {'input': [[69216, 13077, 405, 817, 405, 30265, 2676, 315, 828, 8336]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:37 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'19'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999989'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'46b7485f0dfa1a791bae922944e849bb'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c350be59e87283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cc61120>, 'json_data': {'input': [[61564, 405, 28156, 539, 7373, 17960, 405, 1820, 4860, 5552, 311, 279, 1005, 315, 6295, 2956, 33527, 304, 33084, 18985, 13077]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:38 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'17'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999979'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'ffb4c885aa6e7fbde96f344438428087'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c350bf5b3e7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cd137e0>, 'json_data': {'input': [[33099, 3692, 405, 67643, 11996, 311, 405, 30216, 275, 17524]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:38 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'19'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999990'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'f490a2c019e45d1ac90396a55fbb6cb3'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c350c07d977283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11aac4a40>, 'json_data': {'input': [[9376, 405, 56345, 311, 1440, 405, 5269, 311, 1005, 279, 2262, 6373, 1887, 323, 1148, 311, 656, 311, 6144, 6978, 27285, 2890, 2038]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:44 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'4851'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999977'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'207c2012eb2ae780692ddb23df2bcc1b'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c350c17f687283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cd137e0>, 'json_data': {'input': [[16010, 2956, 6492, 405, 26760, 311, 7417, 405, 12393, 323, 3044, 315, 6978]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:44 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'17'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999986'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'f76d5c29f4ca7a7c456185a68fe57846'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c350e6ebd47283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x105d13c40>, 'json_data': {'input': [[16010, 2956, 33527, 405, 4919, 387, 1511, 369, 405, 265, 1072, 6253, 16515, 323, 18899, 828, 4868]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:48 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'400'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999982'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'205ba9dd2a03df59562ab6f153170449'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c350e7cd237283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cc611c0>, 'json_data': {'input': [[24203, 828, 405, 4919, 3493, 405, 64, 5016, 31206, 5643, 369, 1855, 8893]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'20'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999986'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'43d5a28e144f2fccdc4b256a9ab25079'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c3510458fd7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cc611c0>, 'json_data': {'input': [[695, 53082, 405, 79, 9773, 264, 20893, 369, 405, 17645, 3932]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'32'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999988'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'7aae6f7f6dac62126f9b04c6467fded4'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c351054a6e7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d738e00>, 'json_data': {'input': [[64080, 3831, 828, 26542, 11193, 311, 6144, 16614, 2038, 1778, 439, 3674, 4868, 5219, 323, 6201, 2759, 2038]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'21'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999981'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'701bb20bce80a906d1f714957800950e'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c351065ba37283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d738ea0>, 'json_data': {'input': [[16548, 828, 304, 18985, 405, 4919, 387, 1511, 311, 405, 27369, 6593, 6103, 323, 7417, 279, 12764, 82, 17444]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'17'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999980'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'c1622320b7dec45642a4055de19d1567'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c351075c8e7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11aac4a40>, 'json_data': {'input': [[36, 17526, 82, 405, 6228, 4669, 405, 26189, 2038, 6067]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'21'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999989'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'3ec3063d163813d5ed919ed74098622f'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c351086da77283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x105d13c40>, 'json_data': {'input': [[8332, 6948, 1903, 304, 6593, 13077, 405, 548, 405, 12156, 398, 828, 32505]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:34:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'36'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999986'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'aa7c55d6606a80c5d294e2007e92acfd'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c351095ee77283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cd137e0>, 'json_data': {'input': [[12641, 6108, 2262, 6373, 1887, 405, 4919, 1304, 433, 8831, 405, 2000, 7471, 311, 2567, 709, 311, 2457, 389, 904, 10223, 14640]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'3059'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999978'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'f7d95b44c0f64dfd7499ed701d04d74d'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c3510a685f7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d738b80>, 'json_data': {'input': [[61564, 405, 82, 2509, 311, 15376, 279, 13225, 405, 258, 42118, 279, 13336, 315, 1701, 6295, 2956, 33527, 304, 18985]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'31'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999980'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'd3a50f9a125ea1cde0835192aae5a9ba'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c3514cd9dc7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d739f80>, 'json_data': {'input': [[45, 5230, 11354, 26262, 6401, 2956, 19406, 7658, 405, 59619, 405, 12393, 828, 12625, 2383]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'18'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999985'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'61db65c7ec99298bfa5290373f2b885a'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c3514deb717283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d73a340>, 'json_data': {'input': [[81437, 405, 817, 315, 28975, 555, 405, 68287, 279, 1888, 6593, 13077, 323, 16410, 405, 58954, 279, 27375, 315, 22972, 323, 39653, 11713]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:01 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'20'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999976'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'5284aa3398d5e672a73d57b7008fb100'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c3514eec9f7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d73a840>, 'json_data': {'input': [[70353, 405, 25849, 5603, 405, 359, 52243, 828, 304, 264, 2204, 1648]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:01 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'17'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999987'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'fffce8c7307d36b1117401b17b57dbb4'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c3514ffe027283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d73a660>, 'json_data': {'input': [[16548, 828, 304, 18985, 405, 4919, 1520, 405, 35798, 77871, 315, 28817, 38305]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:01 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'22'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999986'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'66553afe8cc6048820492acf4548b899'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c35150ef327283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11aac4a40>, 'json_data': {'input': [[30679, 2198, 405, 17870, 288, 389, 405, 19493, 8535, 2890, 7576, 469, 17526]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:01 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'16'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999986'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'7302e11f2d538c6ee9bf35ae8b2364e7'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c35151e8887283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cd12e80>, 'json_data': {'input': [[91246, 405, 444, 10391, 405, 46654, 1047, 1027, 38484, 25790]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:01 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'50'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999989'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'2084ee4864035efac387a05fc11d2629'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c35152d9bf7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cd13920>, 'json_data': {'input': [[53390]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:01 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'17'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999999'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'003561bca92570c70c75bee0388194f7'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c351540b347283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x105d13b00>, 'json_data': {'input': [[16010, 2956, 405, 285, 4613, 439, 405, 276, 2038, 9513, 449, 1579, 8286, 405, 14982, 405, 438, 8205]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:35:02 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'17'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999981'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'04bd088370bb761a8db1ea20a57cd2a3'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c351559d6f7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# ...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d739940>, 'json_data': {'input': [[22078, 372, 41740, 405, 2119, 2258, 469, 17526, 82, 315, 927, 220, 966, 3610, 6978, 405, 998, 1893, 264, 4729, 369, 60336, 6492, 7526]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:06 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'18'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999975'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'911ad6d03aaf3f92720c959ea3599796'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c352e6ce5d7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d739ee0>, 'json_data': {'input': [[34, 486, 42743, 405, 1962, 1908, 405, 695, 31471]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:06 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'18'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999991'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'8e20f852f7c149c4bdd6335ecc9d9e2c'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c352e7d8317283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d73afc0>, 'json_data': {'input': [[36, 17526, 82, 405, 7072, 433, 8831, 369, 12850, 311, 4430, 405, 81437, 7576, 449, 19144, 12850]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:06 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'23'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999983'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'8beef63b603b43f065529178bb04b22b'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c352e8d9b97283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d73a980>, 'json_data': {'input': [[16010, 2956, 6492, 405, 26760, 311, 405, 318, 35563, 2890, 323, 3044, 315, 6978]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:06 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'38'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999986'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'6de006e65310dd32e72cad83efda0354'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c352e9cb047283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# 1
# 1536
# 1
# 1536
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x105d137e0>, 'json_data': {'input': [[33179, 26211, 8483, 5955, 405, 16219, 7526, 311, 405, 52727, 5627, 311, 2680, 323, 49586, 1866, 828, 3871, 449, 828, 505, 8717]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:07 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'32'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999977'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'aafee1e9b38c514e5503c14b84b4d1df'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c352eb0ca77283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x105d137e0>, 'json_data': {'input': [[44803, 35758, 6067, 405, 12837, 279, 29772, 315, 405, 12393, 3600]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:07 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'37'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999988'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'0e8cceb7f46ee26c617890ac61877afd'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c352ebfe4c7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11cd13c40>, 'json_data': {'input': [[12393, 10727, 12850, 405, 76833, 405, 695, 69140, 315, 6593, 323, 8893, 7576]], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# 1
# 1536
# 1
# 1536
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:07 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'18'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999986'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'08edabdee51b2dd14d3bbe6ea17d8b69'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c352ed1f7a7283-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:chromadb.config:Starting component PersistentLocalHnswSegment
# 1
# 1536
# DEBUG:urllib3.connectionpool:https://app.posthog.com:443 "POST /batch/ HTTP/1.1" 200 None

# %%
def _query(query, n_results=10):
    return topic_collection.query(query_texts=[query], n_results=n_results)['ids'][0]

# %%
_query('What is healthcare and data?')
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11d73a2a0>, 'json_data': {'input': ['What is healthcare and data?'], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11cc70890>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11a835be0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11d59b1d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:36:56 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'31'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999993'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'5f1434a28fb3a520d32b3d6041cb4973'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=z01CJ03u07uUMSixpzJaXVg6LepRRRTL6dmsFsav1ZU-1703698616-1-AfnLe0ZBEHmfNDSTnPPnTtb8qZNRSxNQXhJtYMs/UyO21ou/r7gT5Q99aaES/Ek1LSvBhuFcjkEShXX7YwQwbJ4=; path=/; expires=Wed, 27-Dec-23 18:06:56 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Set-Cookie', b'_cfuvid=evAItFukSOvD2dlh_QGv72A9wGqkLZBAq8kcXSo.dVI-1703698616595-0-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c35420e89e78d9-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# ['big data->use of->healthcare',
#  'data privacy->important in->healthcare',
#  'medical facilities->are moving towards->data-based healthcare',
#  'big data in healthcare->can help->enhance patient care',
#  'Big Data->can help->healthcare providers meet goals',
#  'Big Data Analytics->use in->healthcare',
#  'big data in healthcare->applied on->a hospital dashboard',
#  'Big Data Analytics->can benefit->healthcare stakeholders',
#  'Big Data Analysis->potential areas of use->healthcare',
#  'big data in healthcare->can help->improve the quality of life']
# DEBUG:urllib3.connectionpool:https://app.posthog.com:443 "POST /batch/ HTTP/1.1" 200 None

# %%
PROMPT_TO_GENERATE_RESPONSES = (
    "Some information on <<topic>> is provided below. The information is of the form (parent_topic, relation_type, topic). "
    "Answer the user query using the information provided.\n"
    "---------------------\n"
    "<<triplets>>\n"
    "---------------------\n"
    "User query: <<query>>\n"
    "Response: "
)
print(PROMPT_TO_GENERATE_RESPONSES)
# Out:
# Some information on <<topic>> is provided below. The information is of the form (parent_topic, relation_type, topic). Answer the user query using the information provided.
# ---------------------
# <<triplets>>
# ---------------------
# User query: <<query>>
# Response:

# %%
user_query = 'What is healthcare and data?'
triplets_prompt = "\n".join(_query(user_query, 40))
prompt = PROMPT_TO_GENERATE_RESPONSES.replace("<<topic>>", topic).replace("<<triplets>>", triplets_prompt).replace("<<query>>", user_query)
resp = llm.complete(prompt).text
print(resp)
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x1217d0220>, 'json_data': {'input': ['What is healthcare and data?'], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11e03d390>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11a835be0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11ebe4d50>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:37:51 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'17'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999993'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'c5ea03662ebe79dc032485af173b56de'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c3557729838ce8-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/chinmayshrivastava/Documents/GitHub/ArticleWriter/venv/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some information on healthanddata is provided below. The information is of the form (parent_topic, relation_type, topic). Answer the user query using the information provided.\n---------------------\nbig data->use of->healthcare\ndata privacy->important in->healthcare\nmedical facilities->are moving towards->data-based healthcare\nbig data in healthcare->can help->enhance patient care\nBig Data->can help->healthcare providers meet goals\nBig Data Analytics->use in->healthcare\nbig data in healthcare->applied on->a hospital dashboard\nBig Data Analytics->can benefit->healthcare stakeholders\nBig Data Analysis->potential areas of use->healthcare\nbig data in healthcare->can help->improve the quality of life\nmedical facilities->moving towards->data-based healthcare\nbig data in healthcare->provide necessary tools and knowledge->ensure finances are in check\nbig data->importance in->healthcare industry\nhealthcare institutions->can use->big data tools\nBig Data analysis->aims to improve->health and condition of patients\nmedical facilities->use->data analytics\nBig Data->can reveal->new approaches to improve health\nBig Data->offering solutions->improvement of patient care and generation of value in healthcare organizations\nBig Data Analytics->has the potential for->positive impact and global implications in healthcare\nBig Data analysis->aims to->improve health and condition of patients\nBig Data->beginning to revolutionize->healthcare in Europe\nhealthcare big data->challenges->difficulties in data capture->data storage->data analysis and data visualization\nhealthcare organizations->opportunity to grow through->investments in Big Data Analytics\nbig data in healthcare->application of->patient dashboard displaying relevant metrics related to patient experience and care\nbig data in healthcare->can help->avoid preventable diseases\nHIPAA->covers->several areas relating to health data\nhealthcare providers->have a financial incentive->to share data that can be used to improve the lives of patients while cutting costs for insurance companies\nbig data in healthcare->applied in the form of->hospital KPI dashboard\nresearch->sought to narrow the gap->in analyzing the possibility of using Big Data Analytics in healthcare\nbig data in healthcare->need for->reducing costs\nbig data in healthcare->can help->reduce costs of treatment\nhealthcare providers->reported->data breaches of medical and patient records\nmedical facilities->use->data analytics in administration and business\nElectronic Health Records->most widespread application of->big data in medicine\nBig Data->offers paths and solutions->to improve the performance and outcomes->of healthcare systems\ndata gathering and management->getting bigger->in healthcare facilities\nbig data analytics for healthcare->could change->how images are read\nImproving the quality of healthcare services->assessment of->diagnoses made by doctors and the manner of treatment of diseases indicated by them based on the decision support system working on Big Data collections\nmedical facilities->use->data analytics in the clinical area\npatient data->securely share between->healthcare providers and other entities providing health services\n---------------------\nUser query: What is healthcare and data?\nResponse: '}], 'model': 'gpt-3.5-turbo', 'stream': False, 'temperature': 0.1}}
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1217dbf90>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11cc88320> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1217f5350>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:37:53 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'Cache-Control', b'no-cache, must-revalidate'), (b'openai-model', b'gpt-3.5-turbo-0613'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'1678'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'160000'), (b'x-ratelimit-limit-tokens_usage_based', b'160000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'159169'), (b'x-ratelimit-remaining-tokens_usage_based', b'159169'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'311ms'), (b'x-ratelimit-reset-tokens_usage_based', b'311ms'), (b'x-request-id', b'f0eca0052d0d8777a8a7bf8c39565025'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=dWW36Ck.uS8U4CRIZva4bsvYI9TngzeM0rHNCS5ca1M-1703698673-1-Ac8cbUyYvsnhLnCoXvsV3PWNgIqWlxavGZySXcs0VIjih7B5hyv+uHfoymYya9XoWoTP8ZGwkibDXdBIvuuRwrY=; path=/; expires=Wed, 27-Dec-23 18:07:53 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Set-Cookie', b'_cfuvid=7FlnjVHGlRkJ_Xf9MwUsRChRzRX3cJcAKc_X3pppcdw-1703698673493-0-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c35578ce4d0f41-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# Healthcare and data refers to the use of data and analytics in the healthcare industry. It involves collecting, analyzing, and utilizing large amounts of data to improve patient care, enhance healthcare operations, and make informed decisions. Big data analytics is applied to various aspects of healthcare, such as patient care, administration, business operations, and research. It can help healthcare providers meet their goals, improve the quality of life, reduce costs, and avoid preventable diseases. Data privacy is also important in healthcare to ensure the secure sharing of patient data between healthcare providers and other entities.

# %%
def ask_query(query, n_results=30):
    triplets_prompt = "\n".join(_query(query, n_results))
    prompt = PROMPT_TO_GENERATE_RESPONSES.replace("<<topic>>", topic).replace("<<triplets>>", triplets_prompt).replace("<<query>>", query)
    resp = llm.complete(prompt).text
    return resp

# %%
print(ask_query('List some major data breaches'))
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x1218105e0>, 'json_data': {'input': ['List some major data breaches'], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1217f7ed0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11a835be0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1217e5dd0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:39:55 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'21'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999993'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'ff4b0c1c3b6a7b45dee5693fc7a7765e'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c358805ebd0f75-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some information on healthanddata is provided below. The information is of the form (parent_topic, relation_type, topic). Answer the user query using the information provided.\n---------------------\nHealthITSecurity->compiled->list of top ten biggest healthcare data breaches\nWhat data was compromised\ndata breach->compromised->names->dates of birth->social security numbers->Medicaid->health plan identification numbers->some medical data\nThe following data was compromised in the Morley Companies data breach\nLearn from this data breach\ndata breach->impacted->millions of individuals\ndata breach->involved->personal information\nhealthcare organizations->experienced a data breach->93\ndata breach->compromised->names->addresses->dates of birth->credit card numbers with expiration dates->demographic information->clinical information->health insurance information\ndata breach->compromised->social security numbers->names->addresses->phone numbers->personal health data->clinical notes->lab tests->prescription information\ndata breaches->following->theft of four personal computers storing unencrypted medical information\ndata breaches->ordered by->degree of impact\nCerebral->notified->data breach\nhealthcare data breaches->impacted->upwards of 112M individuals\nhealthcare providers->reported->data breaches of medical and patient records\ndata breach->included->names->addresses->email addresses->and phone numbers\ndata breach->violated->data protection standards outlined in HIPAA\nHCA Healthcare->breach occurred->when unauthorized party stole a list of information\ndata breach->impacted->healthcare providers and plans\nbreach->involved->unauthorized access to Social Security numbers->names->medical information->and health information\ndata breach->occurred in->Medical Informatics Engineering\nhealthcare providers->began to report->data breaches of medical and patient records\ndata breaches->affect->covered entities\ndata breach->occurred in->Advocate Health Care\ndata breach->fined->555 million->payable to->Health and Human Services Department\ndata breach->occurred in->Trinity Health\ndata breach->occurred in->Morley Companies\ndata breach->occurred in->Banner Health\nsensitive patient data->compromised->names->birth dates->social security numbers->phone numbers->addresses\nPerry Johnson  Associates->disclosed->May data breach\n---------------------\nUser query: List some major data breaches\nResponse: '}], 'model': 'gpt-3.5-turbo', 'stream': False, 'temperature': 0.1}}
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x12059fe50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11cc88320> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x121b6c9d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:39:57 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'Cache-Control', b'no-cache, must-revalidate'), (b'openai-model', b'gpt-3.5-turbo-0613'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'1239'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'160000'), (b'x-ratelimit-limit-tokens_usage_based', b'160000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'159381'), (b'x-ratelimit-remaining-tokens_usage_based', b'159381'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'232ms'), (b'x-ratelimit-reset-tokens_usage_based', b'232ms'), (b'x-request-id', b'c42db1382bb5c6e19fc8051c5417e541'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c35881dfc31912-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# Here are some major data breaches:
#
# 1. Morley Companies data breach
# 2. Cerebral data breach
# 3. HCA Healthcare data breach
# 4. Medical Informatics Engineering data breach
# 5. Advocate Health Care data breach
# 6. Trinity Health data breach
# 7. Banner Health data breach
# 8. Perry Johnson & Associates data breach

# %%
print(ask_query('What was affected by the morley company breach?'))
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x121810860>, 'json_data': {'input': ['What was affected by the morley company breach?'], 'model': 'text-embedding-ada-002', 'encoding_format': 'base64'}}
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x121b6e790>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11a835be0> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11df4f890>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:40:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'19'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999988'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'11207b0e71cc024f138985e1873fcdd6'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c359615b408cbf-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/embeddings "200 OK"
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': <MessageRole.USER: 'user'>, 'content': 'Some information on healthanddata is provided below. The information is of the form (parent_topic, relation_type, topic). Answer the user query using the information provided.\n---------------------\nThe following data was compromised in the Morley Companies data breach\ndata breach->occurred in->Morley Companies\nMorley Companies->impacted->521->046 individuals\ndata breach->impacted->millions of individuals\nWhat data was compromised\ndata breaches->affect->covered entities\nbreach->impacted->more than 3 million individuals\ndata breach->impacted->healthcare providers and plans\nRegal Medical Group->disclosed->breach\ndata breach->occurred in->Newkirk Products\nPerry Johnson  Associates->disclosed->May data breach\ndata breach->involved->personal information\nTrinity Health->affected by->ransomware attack attempt\nOneTouchPoint->concluded->systems had been illegally accessed in the months prior\ndata breaches->following->theft of four personal computers storing unencrypted medical information\ndata breaches->ordered by->degree of impact\nhealthcare organizations->experienced a data breach->93\nOTP->concluded->systems had been illegally accessed\nCerebral->notified->data breach\nNationsBenefits->determined->certain members personal information impacted\ndata breach->occurred in->Advocate Health Care\nhealthcare data breaches->impacted->upwards of 112M individuals\nOTP->undergoing->class-action lawsuit\ndata breach->occurred in->Trinity Health\nHCA Healthcare->breach occurred->when unauthorized party stole a list of information\nLearn from this data breach\ndata breach->occurred in->Medical Informatics Engineering\nbreach->involved->unauthorized access to Social Security numbers->names->medical information->and health information\nNationsBenefits->reported->breach\ndata breach->occurred in->Banner Health\n---------------------\nUser query: What was affected by the morley company breach?\nResponse: '}], 'model': 'gpt-3.5-turbo', 'stream': False, 'temperature': 0.1}}
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11ecfded0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11cc88320> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x121b6d250>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 27 Dec 2023 17:40:32 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'Cache-Control', b'no-cache, must-revalidate'), (b'openai-model', b'gpt-3.5-turbo-0613'), (b'openai-organization', b'user-0syiyru7cdolpuzdwzjqibxn'), (b'openai-processing-ms', b'321'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15724800; includeSubDomains'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'160000'), (b'x-ratelimit-limit-tokens_usage_based', b'160000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'159508'), (b'x-ratelimit-remaining-tokens_usage_based', b'159508'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'184ms'), (b'x-ratelimit-reset-tokens_usage_based', b'184ms'), (b'x-request-id', b'9ce9015bb5367ec0bb5ce832aa1ffd31'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Server', b'cloudflare'), (b'CF-RAY', b'83c359629ad27289-EWR'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# 521,046 individuals were impacted by the Morley Companies data breach.

# %%
print(ask_query('I am writing an article on DPDP Act listing the top 5 things that businesses need to do to ensure compliance. Can you help me with that?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Based on the information provided, here are the top 5 things that businesses need to do to ensure compliance with the DPDP Act:
#
# 1. Inform Consumers and DPB about Data Breaches: Businesses should promptly inform both consumers and the Data Protection Board (DPB) about any data breaches that occur.
#
# 2. Comply with DPB Directions: The DPB has the power to issue directions to businesses requiring them to comply with the law. Businesses should ensure they follow these directions and take the necessary remedial actions.
#
# 3. Observe Procedural Rules: The DPDP Act requires the DPB to observe certain specified procedural rules while conducting inquiries and issuing penalties. Businesses should ensure they are aware of and comply with these rules.
#
# 4. Create Checks and Balances: The board should create certain checks and balances for issuing directions. This means that businesses should establish internal processes and mechanisms to ensure that the directions issued by the DPB are properly reviewed and implemented.
#
# 5. Protect Personal Data Adequately: The DPDP Act aims to protect personal data adequately. Businesses should take appropriate measures to ensure the security and protection of personal data they handle, in line with the requirements of the Act.
#
# Please note that this information is based on the provided data and may not cover all aspects of compliance with the DPDP Act. It is recommended to refer to the actual legislation and consult legal experts for a comprehensive understanding of compliance requirements.

# %%
# Inform Consumers and DPB about Data Breaches
print(ask_query('tell me more about DPDP aspect of informing consumers and DPB about data breaches'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# According to the information provided, businesses are responsible for informing consumers and the DPB (Data Protection Board) about data breaches. This means that if a business experiences a data breach, they are required to notify both the affected consumers and the DPB. This is an important aspect of the DPDP (Data Protection and Privacy Act) as it ensures that consumers are made aware of any breaches that may have compromised their personal data.

# %%
# Comply with DPB Directions
print(ask_query('What are the DPB directions that businesses need to comply with?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The DPB directions that businesses need to comply with include ensuring remedial actions against any data breaches and complying with the law.

# %%
# Observe Procedural Rules
print(ask_query('What are the procedural rules that businesses need to observe?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Businesses need to observe certain specified procedural rules while conducting inquiries and issuing penalties as required by the DPDP Act.

# %%
# Create Checks and Balances
print(ask_query('What are the checks and balances that businesses need to create?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Businesses need to create certain checks and balances for issuing directions, as stated in the information provided.

# %%
requirements = "info on specific actions that the data fiduciaries need to take to ensure compliance - include DPB directions, procedural rules, checks and balances, etc."
# Extract more triplets
prompt = PROMPT_TO_EXTRACT_TRIPLETS.replace("<<topic>>", topic).replace("<<requirement>>", requirements).replace("<<FIRST_CHUNK_EX>>", first_chunk).replace("<<FIRST_CHUNK_TRIPLETS>>", first_triplets).replace("<<SECOND_CHUNK_EX>>", second_chunk).replace("<<SECOND_CHUNK_TRIPLETS>>", second_triplets).replace("<<num_triplets>>", str(num_triplets))
print(prompt)
# Out:
# Some text is provided below related to DPDP. Given the text, to better understand info on specific actions that the data fiduciaries need to take to ensure compliance - incoude DPB directions, procedural rules, checks and balances, etc., extract up to 5 knowledge triplets in the form of (parent_topic, relation_type, topic). Avoid stopwords.
# ---------------------
# Example:Text: The bill grouped personal data into different categories and required elevated levels of protection for “sensitive” and “critical” personal data. Certain businesses were also to be categorized as “significant data fiduciaries,” and additional obligations were proposed for them—registration in India, data audits, and data impact assessments.Triplets:
# (personal data, grouped into, different categories - sensitive and critical)
# (certain businesses, to be categorized as, significant data fiduciaries)
# (significant data fiduciaries, to require, additional obligations - registration in India, data audits, and data impact assessments)
#
# Text: The DPDP Act applies to Indian residents and businesses collecting the data of Indian residents. Interestingly, it also applies to non-citizens living in India whose data processing “in connection with any activity related to offering of goods or services” happens outside India.Triplets:
# (DPDP Act, applies to, Indian residents and businesses collecting the data of Indian residents)
# (DPDP Act, applies to, non-citizens living in India whose data processing in connection with any activity related to offering of goods or services happens outside India)
#
# ---------------------
# Text: {text}
# Triplets:

# %%
for chunk in chunks:
    resp = llm.complete(prompt.replace("{text}", chunk))
    triplets.extend(resp.text.split("\n"))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
new_triplets = set(t.replace('(', '').replace(')', '') for t in triplets)  # Remove parentheses
new_triplets = [tuple(map(str.strip, t.split(','))) for t in new_triplets]  # Split by comma and convert to tuple
new_triplets
# Out:
# [('board',
#   'should provide',
#   'regulated entity with a formal opportunity to furnish their response to a draft direction before such a direction is formally issued to them'),
#  ('entity processing data',
#   'can do so',
#   "by taking the concerned individual's consent"),
#  ('reductions in rights and obligations',
#   'have been recast to - right to "erasure"'),
#  ("DPB's limited mandate",
#   'will create less frequent touchpoints with the economy'),
#  ('2023 law',
#   'states that',
#   'government may restrict data flows to certain countries by notification'),
#  ('central government', 'framed', 'rules to implement the law'),
#  ('significant data fiduciaries',
#   'additional obligations',
#   'appointing a data protection officer based in India who will be answerable to the board of directors or the governing body of the SDF and will also serve as the point of contact for grievance redressal'),
#  ('right to be forgotten', 'recast to', 'right to "erasure"'),
#  ('exceptions carved out for consent', 'empower', 'state significantly'),
#  ('rules',
#   'include',
#   'the manner in which notices will be given to consumers'),
#  ('DPDP Act', 'passed by', 'Indian Parliament'),
#  ('detailed prescriptions',
#   'have been discarded - notices and privacy by design requirements'),
#  ('law', 'does not contain', 'adequate checks and balances'),
#  ('reduction in prescriptive requirements and overall compliance',
#   'should also be seen in',
#   'context of the shift away from criminalization'),
#  ('DPDP Act',
#   'applies to',
#   'non-citizens living in India whose data processing in connection with any activity related to offering of goods or services happens outside India'),
#  ('2018 and 2019 bills',
#   'provided a full-fledged independent regulator',
#   'the DPA'),
#  ('regulatory structure',
#   'based on',
#   '2018 draft bill proposed by the Srikrishna Committee'),
#  ('2023 law',
#   'exempts',
#   'certain purposes and entities completely from its purview'),
#  ('DPDP Act',
#   'does away with',
#   'idea of an independent regulator like the DPA'),
#  ('detailed prescriptions regarding',
#   'have been discarded',
#   'notices and privacy by design requirements'),
#  ('rules', 'include', 'the manner in which consent managers will function'),
#  ('2019 bill',
#   'exempted',
#   'certain entities and businesses from notice and consent requirements'),
#  ('data fiduciaries',
#   'obligations',
#   'intimation of data breach in a prescribed manner to the Data Protection Board of India DPB'),
#  ('DPDP Act',
#   'first cross-sectoral law on',
#   'personal data protection in India'),
#  ('2018 and 2019 bills', 'provided for - monetary penalties'),
#  ('DPB',
#   'can pass orders',
#   'issuing penalties or imposing voluntary settlements for noncompliance with the law'),
#  ('DPDP Act', 'creates', 'rights and obligations for individuals'),
#  ('consent',
#   'must be',
#   'free',
#   'specific',
#   'informed',
#   'unconditional and unambiguous with a clear affirmative action'),
#  ('2023 law', 'establishes', 'the DPB as a regulatory entity'),
#  ('DPDP Act',
#   'requires',
#   'board to observe certain specified procedural rules while conducting inquiries and issuing penalties'),
#  ('2019 bill', 'reduced this to', 'just one - deanonymization'),
#  ('consent managers', 'will function'),
#  ('DPB',
#   'powers are limited to',
#   'ensuring remedial actions against any data breaches'),
#  ('rules',
#   'include',
#   'the manner in which businesses will inform their consumers and the DPB about data breaches'),
#  ('2018 bill', 'created a number of', 'criminal offenses'),
#  ('2019 bill',
#   'proposed a comprehensive',
#   'cross-sectoral framework',
#   'based on preventive requirements for businesses and rights for individuals'),
#  ('DPDP Act',
#   'provides',
#   'significant rule-making powers to the central government'),
#  ('2018 and 2019 bills',
#   'created a legislative framework',
#   'had a high degree of regulatory intensity'),
#  ('2022 draft and the 2023 version',
#   'do not provide for',
#   'any criminal offenses'),
#  ('reduction in prescriptive requirements and overall compliance',
#   'should also be seen in the context of - shift away from criminalization'),
#  ('notices', 'will be given to', 'consumers'),
#  ('data fiduciaries',
#   'obligations',
#   'ensuring completeness',
#   'accuracy',
#   'and consistency of personal data'),
#  ('exemptions to the state',
#   'for investigative',
#   'prosecutorial',
#   'and national security purposes'),
#  ('2022 draft and the 2023 version', 'stipulate only', 'monetary penalties'),
#  ('2018 bill', 'proposed an expansive law', 'based closely on the GDPR'),
#  ('data fiduciaries',
#   'defined as',
#   'entities responsible for collecting',
#   'storing',
#   'and processing digital personal data'),
#  ('DPA', 'would have had powers', 'to impose penalties for noncompliance'),
#  ('businesses', 'will inform', 'consumers and the DPB about data breaches'),
#  ('DPB',
#   'has limited powers',
#   'ensuring remedial actions against any data breaches and issuing directions to businesses requiring them to comply with the law'),
#  ('Section 37 of the law',
#   'enables',
#   'central government to block access to any information that can be communicated by a data fiduciary'),
#  ('reductions in rights and obligations',
#   'have been recast to',
#   'right to "erasure"'),
#  ('2023 law', 'reverses course on', 'data localization requirements'),
#  ('central government',
#   'to ensure',
#   'best practices in administrative law and decisionmaking are incorporated via the procedural rules that the DPDP Act empowers it to make'),
#  ('DPDP Act', 'based on', 'draft proposed by the government in November 2022'),
#  ('2019 bill',
#   'rationalized some provisions',
#   'while retaining most of them and adding to the regulatory expanse'),
#  ('discretionary rule-making powers',
#   'could undermine',
#   'protections provided in the law'),
#  ('DPB', 'does not have', 'many regulation-making powers under this law'),
#  ('DPB',
#   'can pass orders issuing penalties or imposing voluntary settlements',
#   'for noncompliance with the law'),
#  ('2018 and 2019 drafts',
#   'included several provisions - only tangentially related to data privacy'),
#  ('2018 draft',
#   'included several provisions',
#   'only tangentially related to data privacy'),
#  ('notices and privacy by design requirements', 'discarded'),
#  ('legitimate uses',
#   'defined as',
#   'a situation where an individual has voluntarily provided personal data for a specified purpose'),
#  ('DPDP Act', 'enacted after', 'more than half a decade of deliberations'),
#  ('larger imperatives',
#   'will shape',
#   'development of data protection regulation'),
#  ('DPA',
#   'would have had powers',
#   'to collect information necessary for ensuring compliance with the law'),
#  ('reductions in rights and obligations',
#   'have been either diluted or discarded - data portability'),
#  ('2018 and 2019 bills',
#   'created a legislative framework - high degree of regulatory intensity'),
#  ('DPDP Act',
#   'balances',
#   'the right of individuals to protect their personal data and the need to process such personal data for lawful purposes'),
#  ('2019 bill', 'empowered', 'government to regulate nonpersonal data'),
#  ('discretionary rule-making powers', 'government has', 'under the law'),
#  ('DPB',
#   'powers are limited to',
#   'issuing directions to businesses requiring them to comply with the law'),
#  ('DPDP Act', 'does away with - independent regulator like the DPA'),
#  ('2023 act',
#   'allows personal data to be processed',
#   'for any lawful purpose'),
#  ('2019 bill', 'required', 'SDFs to register in India'),
#  ('2018 and 2019 versions of the bill',
#   'adopted',
#   'expansive and all-encompassing framework toward data protection'),
#  ('2018 and 2019 bills',
#   'created a number of criminal offenses - deanonymization'),
#  ('2019 bill',
#   'proposed',
#   'comprehensive cross-sectoral framework based on preventive requirements for businesses and rights for individuals or consumers'),
#  ('entities responsible for collecting',
#   'storing',
#   'and processing digital personal data',
#   'defined as',
#   'data fiduciaries'),
#  ('data portability', 'removed'),
#  ('consumers', 'will exercise', 'their rights against data fiduciaries'),
#  ('DPDP Act', 'protects', 'personal data adequately'),
#  ('data fiduciaries', 'obligations', 'maintaining security safeguards'),
#  ('board',
#   'should create',
#   'certain checks and balances for issuing directions'),
#  ('parental consent',
#   'will be sought for',
#   "processing children's data and related exemptions"),
#  ('entity processing data', 'can do so', 'for legitimate uses'),
#  ('2019 draft',
#   'included several provisions',
#   'only tangentially related to data privacy'),
#  ('reductions in rights and obligations',
#   'have been either diluted or discarded',
#   'data portability')]

# %%
_unique_nodes = [{
    'id': "->".join(n),
    'text': f'{"->".join(n)}'
    } for n in new_triplets]
_unique_nodes, len(_unique_nodes)
# Out:
# ([{'id': 'board->should provide->regulated entity with a formal opportunity to furnish their response to a draft direction before such a direction is formally issued to them',
#    'text': 'board->should provide->regulated entity with a formal opportunity to furnish their response to a draft direction before such a direction is formally issued to them'},
#   {'id': "entity processing data->can do so->by taking the concerned individual's consent",
#    'text': "entity processing data->can do so->by taking the concerned individual's consent"},
#   {'id': 'reductions in rights and obligations->have been recast to - right to "erasure"',
#    'text': 'reductions in rights and obligations->have been recast to - right to "erasure"'},
#   {'id': "DPB's limited mandate->will create less frequent touchpoints with the economy",
#    'text': "DPB's limited mandate->will create less frequent touchpoints with the economy"},
#   {'id': '2023 law->states that->government may restrict data flows to certain countries by notification',
#    'text': '2023 law->states that->government may restrict data flows to certain countries by notification'},
#   {'id': 'central government->framed->rules to implement the law',
#    'text': 'central government->framed->rules to implement the law'},
#   {'id': 'significant data fiduciaries->additional obligations->appointing a data protection officer based in India who will be answerable to the board of directors or the governing body of the SDF and will also serve as the point of contact for grievance redressal',
#    'text': 'significant data fiduciaries->additional obligations->appointing a data protection officer based in India who will be answerable to the board of directors or the governing body of the SDF and will also serve as the point of contact for grievance redressal'},
#   {'id': 'right to be forgotten->recast to->right to "erasure"',
#    'text': 'right to be forgotten->recast to->right to "erasure"'},
#   {'id': 'exceptions carved out for consent->empower->state significantly',
#    'text': 'exceptions carved out for consent->empower->state significantly'},
#   {'id': 'rules->include->the manner in which notices will be given to consumers',
#    'text': 'rules->include->the manner in which notices will be given to consumers'},
#   {'id': 'DPDP Act->passed by->Indian Parliament',
#    'text': 'DPDP Act->passed by->Indian Parliament'},
#   {'id': 'detailed prescriptions->have been discarded - notices and privacy by design requirements',
#    'text': 'detailed prescriptions->have been discarded - notices and privacy by design requirements'},
#   {'id': 'law->does not contain->adequate checks and balances',
#    'text': 'law->does not contain->adequate checks and balances'},
#   {'id': 'reduction in prescriptive requirements and overall compliance->should also be seen in->context of the shift away from criminalization',
#    'text': 'reduction in prescriptive requirements and overall compliance->should also be seen in->context of the shift away from criminalization'},
#   {'id': 'DPDP Act->applies to->non-citizens living in India whose data processing in connection with any activity related to offering of goods or services happens outside India',
#    'text': 'DPDP Act->applies to->non-citizens living in India whose data processing in connection with any activity related to offering of goods or services happens outside India'},
#   {'id': '2018 and 2019 bills->provided a full-fledged independent regulator->the DPA',
#    'text': '2018 and 2019 bills->provided a full-fledged independent regulator->the DPA'},
#   {'id': 'regulatory structure->based on->2018 draft bill proposed by the Srikrishna Committee',
#    'text': 'regulatory structure->based on->2018 draft bill proposed by the Srikrishna Committee'},
#   {'id': '2023 law->exempts->certain purposes and entities completely from its purview',
#    'text': '2023 law->exempts->certain purposes and entities completely from its purview'},
#   {'id': 'DPDP Act->does away with->idea of an independent regulator like the DPA',
#    'text': 'DPDP Act->does away with->idea of an independent regulator like the DPA'},
#   {'id': 'detailed prescriptions regarding->have been discarded->notices and privacy by design requirements',
#    'text': 'detailed prescriptions regarding->have been discarded->notices and privacy by design requirements'},
#   {'id': 'rules->include->the manner in which consent managers will function',
#    'text': 'rules->include->the manner in which consent managers will function'},
#   {'id': '2019 bill->exempted->certain entities and businesses from notice and consent requirements',
#    'text': '2019 bill->exempted->certain entities and businesses from notice and consent requirements'},
#   {'id': 'data fiduciaries->obligations->intimation of data breach in a prescribed manner to the Data Protection Board of India DPB',
#    'text': 'data fiduciaries->obligations->intimation of data breach in a prescribed manner to the Data Protection Board of India DPB'},
#   {'id': 'DPDP Act->first cross-sectoral law on->personal data protection in India',
#    'text': 'DPDP Act->first cross-sectoral law on->personal data protection in India'},
#   {'id': '2018 and 2019 bills->provided for - monetary penalties',
#    'text': '2018 and 2019 bills->provided for - monetary penalties'},
#   {'id': 'DPB->can pass orders->issuing penalties or imposing voluntary settlements for noncompliance with the law',
#    'text': 'DPB->can pass orders->issuing penalties or imposing voluntary settlements for noncompliance with the law'},
#   {'id': 'DPDP Act->creates->rights and obligations for individuals',
#    'text': 'DPDP Act->creates->rights and obligations for individuals'},
#   {'id': 'consent->must be->free->specific->informed->unconditional and unambiguous with a clear affirmative action',
#    'text': 'consent->must be->free->specific->informed->unconditional and unambiguous with a clear affirmative action'},
#   {'id': '2023 law->establishes->the DPB as a regulatory entity',
#    'text': '2023 law->establishes->the DPB as a regulatory entity'},
#   {'id': 'DPDP Act->requires->board to observe certain specified procedural rules while conducting inquiries and issuing penalties',
#    'text': 'DPDP Act->requires->board to observe certain specified procedural rules while conducting inquiries and issuing penalties'},
#   {'id': '2019 bill->reduced this to->just one - deanonymization',
#    'text': '2019 bill->reduced this to->just one - deanonymization'},
#   {'id': 'consent managers->will function',
#    'text': 'consent managers->will function'},
#   {'id': 'DPB->powers are limited to->ensuring remedial actions against any data breaches',
#    'text': 'DPB->powers are limited to->ensuring remedial actions against any data breaches'},
#   {'id': 'rules->include->the manner in which businesses will inform their consumers and the DPB about data breaches',
#    'text': 'rules->include->the manner in which businesses will inform their consumers and the DPB about data breaches'},
#   {'id': '2018 bill->created a number of->criminal offenses',
#    'text': '2018 bill->created a number of->criminal offenses'},
#   {'id': '2019 bill->proposed a comprehensive->cross-sectoral framework->based on preventive requirements for businesses and rights for individuals',
#    'text': '2019 bill->proposed a comprehensive->cross-sectoral framework->based on preventive requirements for businesses and rights for individuals'},
#   {'id': 'DPDP Act->provides->significant rule-making powers to the central government',
#    'text': 'DPDP Act->provides->significant rule-making powers to the central government'},
#   {'id': '2018 and 2019 bills->created a legislative framework->had a high degree of regulatory intensity',
#    'text': '2018 and 2019 bills->created a legislative framework->had a high degree of regulatory intensity'},
#   {'id': '2022 draft and the 2023 version->do not provide for->any criminal offenses',
#    'text': '2022 draft and the 2023 version->do not provide for->any criminal offenses'},
#   {'id': 'reduction in prescriptive requirements and overall compliance->should also be seen in the context of - shift away from criminalization',
#    'text': 'reduction in prescriptive requirements and overall compliance->should also be seen in the context of - shift away from criminalization'},
#   {'id': 'notices->will be given to->consumers',
#    'text': 'notices->will be given to->consumers'},
#   {'id': 'data fiduciaries->obligations->ensuring completeness->accuracy->and consistency of personal data',
#    'text': 'data fiduciaries->obligations->ensuring completeness->accuracy->and consistency of personal data'},
#   {'id': 'exemptions to the state->for investigative->prosecutorial->and national security purposes',
#    'text': 'exemptions to the state->for investigative->prosecutorial->and national security purposes'},
#   {'id': '2022 draft and the 2023 version->stipulate only->monetary penalties',
#    'text': '2022 draft and the 2023 version->stipulate only->monetary penalties'},
#   {'id': '2018 bill->proposed an expansive law->based closely on the GDPR',
#    'text': '2018 bill->proposed an expansive law->based closely on the GDPR'},
#   {'id': 'data fiduciaries->defined as->entities responsible for collecting->storing->and processing digital personal data',
#    'text': 'data fiduciaries->defined as->entities responsible for collecting->storing->and processing digital personal data'},
#   {'id': 'DPA->would have had powers->to impose penalties for noncompliance',
#    'text': 'DPA->would have had powers->to impose penalties for noncompliance'},
#   {'id': 'businesses->will inform->consumers and the DPB about data breaches',
#    'text': 'businesses->will inform->consumers and the DPB about data breaches'},
#   {'id': 'DPB->has limited powers->ensuring remedial actions against any data breaches and issuing directions to businesses requiring them to comply with the law',
#    'text': 'DPB->has limited powers->ensuring remedial actions against any data breaches and issuing directions to businesses requiring them to comply with the law'},
#   {'id': 'Section 37 of the law->enables->central government to block access to any information that can be communicated by a data fiduciary',
#    'text': 'Section 37 of the law->enables->central government to block access to any information that can be communicated by a data fiduciary'},
#   {'id': 'reductions in rights and obligations->have been recast to->right to "erasure"',
#    'text': 'reductions in rights and obligations->have been recast to->right to "erasure"'},
#   {'id': '2023 law->reverses course on->data localization requirements',
#    'text': '2023 law->reverses course on->data localization requirements'},
#   {'id': 'central government->to ensure->best practices in administrative law and decisionmaking are incorporated via the procedural rules that the DPDP Act empowers it to make',
#    'text': 'central government->to ensure->best practices in administrative law and decisionmaking are incorporated via the procedural rules that the DPDP Act empowers it to make'},
#   {'id': 'DPDP Act->based on->draft proposed by the government in November 2022',
#    'text': 'DPDP Act->based on->draft proposed by the government in November 2022'},
#   {'id': '2019 bill->rationalized some provisions->while retaining most of them and adding to the regulatory expanse',
#    'text': '2019 bill->rationalized some provisions->while retaining most of them and adding to the regulatory expanse'},
#   {'id': 'discretionary rule-making powers->could undermine->protections provided in the law',
#    'text': 'discretionary rule-making powers->could undermine->protections provided in the law'},
#   {'id': 'DPB->does not have->many regulation-making powers under this law',
#    'text': 'DPB->does not have->many regulation-making powers under this law'},
#   {'id': 'DPB->can pass orders issuing penalties or imposing voluntary settlements->for noncompliance with the law',
#    'text': 'DPB->can pass orders issuing penalties or imposing voluntary settlements->for noncompliance with the law'},
#   {'id': '2018 and 2019 drafts->included several provisions - only tangentially related to data privacy',
#    'text': '2018 and 2019 drafts->included several provisions - only tangentially related to data privacy'},
#   {'id': '2018 draft->included several provisions->only tangentially related to data privacy',
#    'text': '2018 draft->included several provisions->only tangentially related to data privacy'},
#   {'id': 'notices and privacy by design requirements->discarded',
#    'text': 'notices and privacy by design requirements->discarded'},
#   {'id': 'legitimate uses->defined as->a situation where an individual has voluntarily provided personal data for a specified purpose',
#    'text': 'legitimate uses->defined as->a situation where an individual has voluntarily provided personal data for a specified purpose'},
#   {'id': 'DPDP Act->enacted after->more than half a decade of deliberations',
#    'text': 'DPDP Act->enacted after->more than half a decade of deliberations'},
#   {'id': 'larger imperatives->will shape->development of data protection regulation',
#    'text': 'larger imperatives->will shape->development of data protection regulation'},
#   {'id': 'DPA->would have had powers->to collect information necessary for ensuring compliance with the law',
#    'text': 'DPA->would have had powers->to collect information necessary for ensuring compliance with the law'},
#   {'id': 'reductions in rights and obligations->have been either diluted or discarded - data portability',
#    'text': 'reductions in rights and obligations->have been either diluted or discarded - data portability'},
#   {'id': '2018 and 2019 bills->created a legislative framework - high degree of regulatory intensity',
#    'text': '2018 and 2019 bills->created a legislative framework - high degree of regulatory intensity'},
#   {'id': 'DPDP Act->balances->the right of individuals to protect their personal data and the need to process such personal data for lawful purposes',
#    'text': 'DPDP Act->balances->the right of individuals to protect their personal data and the need to process such personal data for lawful purposes'},
#   {'id': '2019 bill->empowered->government to regulate nonpersonal data',
#    'text': '2019 bill->empowered->government to regulate nonpersonal data'},
#   {'id': 'discretionary rule-making powers->government has->under the law',
#    'text': 'discretionary rule-making powers->government has->under the law'},
#   {'id': 'DPB->powers are limited to->issuing directions to businesses requiring them to comply with the law',
#    'text': 'DPB->powers are limited to->issuing directions to businesses requiring them to comply with the law'},
#   {'id': 'DPDP Act->does away with - independent regulator like the DPA',
#    'text': 'DPDP Act->does away with - independent regulator like the DPA'},
#   {'id': '2023 act->allows personal data to be processed->for any lawful purpose',
#    'text': '2023 act->allows personal data to be processed->for any lawful purpose'},
#   {'id': '2019 bill->required->SDFs to register in India',
#    'text': '2019 bill->required->SDFs to register in India'},
#   {'id': '2018 and 2019 versions of the bill->adopted->expansive and all-encompassing framework toward data protection',
#    'text': '2018 and 2019 versions of the bill->adopted->expansive and all-encompassing framework toward data protection'},
#   {'id': '2018 and 2019 bills->created a number of criminal offenses - deanonymization',
#    'text': '2018 and 2019 bills->created a number of criminal offenses - deanonymization'},
#   {'id': '2019 bill->proposed->comprehensive cross-sectoral framework based on preventive requirements for businesses and rights for individuals or consumers',
#    'text': '2019 bill->proposed->comprehensive cross-sectoral framework based on preventive requirements for businesses and rights for individuals or consumers'},
#   {'id': 'entities responsible for collecting->storing->and processing digital personal data->defined as->data fiduciaries',
#    'text': 'entities responsible for collecting->storing->and processing digital personal data->defined as->data fiduciaries'},
#   {'id': 'data portability->removed', 'text': 'data portability->removed'},
#   {'id': 'consumers->will exercise->their rights against data fiduciaries',
#    'text': 'consumers->will exercise->their rights against data fiduciaries'},
#   {'id': 'DPDP Act->protects->personal data adequately',
#    'text': 'DPDP Act->protects->personal data adequately'},
#   {'id': 'data fiduciaries->obligations->maintaining security safeguards',
#    'text': 'data fiduciaries->obligations->maintaining security safeguards'},
#   {'id': 'board->should create->certain checks and balances for issuing directions',
#    'text': 'board->should create->certain checks and balances for issuing directions'},
#   {'id': "parental consent->will be sought for->processing children's data and related exemptions",
#    'text': "parental consent->will be sought for->processing children's data and related exemptions"},
#   {'id': 'entity processing data->can do so->for legitimate uses',
#    'text': 'entity processing data->can do so->for legitimate uses'},
#   {'id': '2019 draft->included several provisions->only tangentially related to data privacy',
#    'text': '2019 draft->included several provisions->only tangentially related to data privacy'},
#   {'id': 'reductions in rights and obligations->have been either diluted or discarded->data portability',
#    'text': 'reductions in rights and obligations->have been either diluted or discarded->data portability'}],
#  87)

# %%
topic_collection.add(
    documents=[x['text'] for x in _unique_nodes],
    metadatas=[{
        'topic': topic,
    } for x in _unique_nodes],
    ids=[x['id'] for x in _unique_nodes]
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: board->should provide->regulated entity with a formal opportunity to furnish their response to a draft direction before such a direction is formally issued to them
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: entity processing data->can do so->by taking the concerned individual's consent
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: reductions in rights and obligations->have been recast to - right to "erasure"
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPB's limited mandate->will create less frequent touchpoints with the economy
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2023 law->states that->government may restrict data flows to certain countries by notification
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: right to be forgotten->recast to->right to "erasure"
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: exceptions carved out for consent->empower->state significantly
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->passed by->Indian Parliament
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: detailed prescriptions->have been discarded - notices and privacy by design requirements
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: regulatory structure->based on->2018 draft bill proposed by the Srikrishna Committee
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2023 law->exempts->certain purposes and entities completely from its purview
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->does away with->idea of an independent regulator like the DPA
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2019 bill->exempted->certain entities and businesses from notice and consent requirements
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->first cross-sectoral law on->personal data protection in India
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2018 and 2019 bills->provided for - monetary penalties
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPB->can pass orders->issuing penalties or imposing voluntary settlements for noncompliance with the law
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->creates->rights and obligations for individuals
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2023 law->establishes->the DPB as a regulatory entity
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->requires->board to observe certain specified procedural rules while conducting inquiries and issuing penalties
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: consent managers->will function
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: reduction in prescriptive requirements and overall compliance->should also be seen in the context of - shift away from criminalization
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: notices->will be given to->consumers
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: exemptions to the state->for investigative->prosecutorial->and national security purposes
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2018 bill->proposed an expansive law->based closely on the GDPR
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: businesses->will inform->consumers and the DPB about data breaches
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPB->has limited powers->ensuring remedial actions against any data breaches and issuing directions to businesses requiring them to comply with the law
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Section 37 of the law->enables->central government to block access to any information that can be communicated by a data fiduciary
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2023 law->reverses course on->data localization requirements
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->based on->draft proposed by the government in November 2022
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2019 bill->rationalized some provisions->while retaining most of them and adding to the regulatory expanse
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2018 and 2019 drafts->included several provisions - only tangentially related to data privacy
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: notices and privacy by design requirements->discarded
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: legitimate uses->defined as->a situation where an individual has voluntarily provided personal data for a specified purpose
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->enacted after->more than half a decade of deliberations
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: larger imperatives->will shape->development of data protection regulation
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: reductions in rights and obligations->have been either diluted or discarded - data portability
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2018 and 2019 bills->created a legislative framework - high degree of regulatory intensity
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->balances->the right of individuals to protect their personal data and the need to process such personal data for lawful purposes
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2019 bill->empowered->government to regulate nonpersonal data
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: discretionary rule-making powers->government has->under the law
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->does away with - independent regulator like the DPA
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2019 bill->required->SDFs to register in India
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2018 and 2019 versions of the bill->adopted->expansive and all-encompassing framework toward data protection
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2018 and 2019 bills->created a number of criminal offenses - deanonymization
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2019 bill->proposed->comprehensive cross-sectoral framework based on preventive requirements for businesses and rights for individuals or consumers
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: entities responsible for collecting->storing->and processing digital personal data->defined as->data fiduciaries
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: data portability->removed
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: consumers->will exercise->their rights against data fiduciaries
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: DPDP Act->protects->personal data adequately
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: board->should create->certain checks and balances for issuing directions
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: parental consent->will be sought for->processing children's data and related exemptions
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: entity processing data->can do so->for legitimate uses
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: board->should provide->regulated entity with a formal opportunity to furnish their response to a draft direction before such a direction is formally issued to them
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: entity processing data->can do so->by taking the concerned individual's consent
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: reductions in rights and obligations->have been recast to - right to "erasure"
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPB's limited mandate->will create less frequent touchpoints with the economy
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2023 law->states that->government may restrict data flows to certain countries by notification
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: right to be forgotten->recast to->right to "erasure"
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: exceptions carved out for consent->empower->state significantly
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->passed by->Indian Parliament
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: detailed prescriptions->have been discarded - notices and privacy by design requirements
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: regulatory structure->based on->2018 draft bill proposed by the Srikrishna Committee
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2023 law->exempts->certain purposes and entities completely from its purview
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->does away with->idea of an independent regulator like the DPA
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2019 bill->exempted->certain entities and businesses from notice and consent requirements
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->first cross-sectoral law on->personal data protection in India
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2018 and 2019 bills->provided for - monetary penalties
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPB->can pass orders->issuing penalties or imposing voluntary settlements for noncompliance with the law
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->creates->rights and obligations for individuals
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2023 law->establishes->the DPB as a regulatory entity
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->requires->board to observe certain specified procedural rules while conducting inquiries and issuing penalties
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: consent managers->will function
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: reduction in prescriptive requirements and overall compliance->should also be seen in the context of - shift away from criminalization
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: notices->will be given to->consumers
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: exemptions to the state->for investigative->prosecutorial->and national security purposes
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2018 bill->proposed an expansive law->based closely on the GDPR
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: businesses->will inform->consumers and the DPB about data breaches
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPB->has limited powers->ensuring remedial actions against any data breaches and issuing directions to businesses requiring them to comply with the law
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Section 37 of the law->enables->central government to block access to any information that can be communicated by a data fiduciary
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2023 law->reverses course on->data localization requirements
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->based on->draft proposed by the government in November 2022
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2019 bill->rationalized some provisions->while retaining most of them and adding to the regulatory expanse
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2018 and 2019 drafts->included several provisions - only tangentially related to data privacy
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: notices and privacy by design requirements->discarded
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: legitimate uses->defined as->a situation where an individual has voluntarily provided personal data for a specified purpose
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->enacted after->more than half a decade of deliberations
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: larger imperatives->will shape->development of data protection regulation
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: reductions in rights and obligations->have been either diluted or discarded - data portability
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2018 and 2019 bills->created a legislative framework - high degree of regulatory intensity
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->balances->the right of individuals to protect their personal data and the need to process such personal data for lawful purposes
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2019 bill->empowered->government to regulate nonpersonal data
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: discretionary rule-making powers->government has->under the law
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->does away with - independent regulator like the DPA
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2019 bill->required->SDFs to register in India
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2018 and 2019 versions of the bill->adopted->expansive and all-encompassing framework toward data protection
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2018 and 2019 bills->created a number of criminal offenses - deanonymization
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2019 bill->proposed->comprehensive cross-sectoral framework based on preventive requirements for businesses and rights for individuals or consumers
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: entities responsible for collecting->storing->and processing digital personal data->defined as->data fiduciaries
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: data portability->removed
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: consumers->will exercise->their rights against data fiduciaries
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: DPDP Act->protects->personal data adequately
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: board->should create->certain checks and balances for issuing directions
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: parental consent->will be sought for->processing children's data and related exemptions
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: entity processing data->can do so->for legitimate uses

# %%
topic_collection.count()
# Out:
# 87

# %%
print(ask_query('What are the procedural rules that businesses need to observe?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The procedural rules that businesses need to observe include the manner in which notices will be given to consumers, the manner in which businesses will inform their consumers and the DPB about data breaches, and the manner in which consent managers will function.

# %%
print(ask_query('What are the DPB directions that businesses need to comply with?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The DPB (Data Protection Board) can issue directions to businesses requiring them to comply with the law. The specific directions that businesses need to comply with are not mentioned in the provided information.

# %%
print(ask_query('What are the checks and balances that businesses need to create?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Businesses need to create certain checks and balances for issuing directions, as stated in the information provided.

# %%
print(ask_query('What is DPB?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DPB stands for Data Protection Board. It is a regulatory entity established by the 2023 law. The DPB has limited powers, including issuing directions to businesses requiring them to comply with the law, ensuring remedial actions against any data breaches, and passing orders issuing penalties or imposing voluntary settlements for noncompliance with the law.

# %%
print(ask_query('Obligations on Data Fiduciaries'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The obligations on data fiduciaries include maintaining security safeguards, ensuring the completeness, accuracy, and consistency of personal data, and intimating data breaches to the Data Protection Board of India (DPB) in a prescribed manner. Additionally, significant data fiduciaries have the additional obligation of appointing a data protection officer based in India who will be answerable to the board of directors or the governing body of the organization and will also serve as the point of contact for grievance redressal.

# %%
print(ask_query('What is the role of the DPB?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The role of the DPB (Data Protection Board) is to issue directions to businesses requiring them to comply with the law, ensure remedial actions against any data breaches, and pass orders issuing penalties or imposing voluntary settlements for noncompliance with the law. The DPB's powers are limited to these functions, and it is established as a regulatory entity under the 2023 law.

# %%
print(ask_query('List the categories DPDP defines?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The DPDP defines the following categories:
#
# 1. Data fiduciaries: Entities responsible for collecting, storing, and processing digital personal data.
#
# 2. Consumers: Individuals who have rights against data fiduciaries.
#
# 3. Individuals: The DPDP Act creates rights and obligations for individuals.
#
# 4. Businesses: The DPB can pass orders and issue penalties or impose voluntary settlements for noncompliance with the law.
#
# 5. Regulatory entity: The 2023 law establishes the DPB as a regulatory entity.
#
# 6. Purposes and entities exempted: The 2023 law exempts certain purposes and entities completely from its purview.
#
# Please note that these categories are based on the information provided and may not be exhaustive.

# %%
print(ask_query('What are the different aspects of DPDP?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The different aspects of DPDP include:
# - The DPDP Act is the first cross-sectoral law on personal data protection in India.
# - The Act requires the DPB (Data Protection Board) to observe certain specified procedural rules while conducting inquiries and issuing penalties.
# - The DPB has limited powers, including ensuring remedial actions against data breaches and issuing directions to businesses to comply with the law.
# - The DPDP Act creates rights and obligations for individuals, balancing their right to protect personal data with the need for lawful processing.
# - The Act does away with the idea of an independent regulator like the DPA (Data Protection Authority).
# - The 2018 and 2019 versions of the bill adopted an expansive and all-encompassing framework toward data protection.
# - The 2018 and 2019 drafts included provisions tangentially related to data privacy.
# - The 2019 bill proposed a comprehensive cross-sectoral framework based on preventive requirements for businesses and rights for individuals or consumers.
# - The DPDP Act protects personal data adequately.
# - The DPB's limited mandate will create less frequent touchpoints with the economy.
# - The 2023 law establishes the DPB as a regulatory entity.
# - Reductions in rights and obligations, such as data portability, have been either diluted or discarded.
# - The development of data protection regulation will be shaped by larger imperatives.
# - The 2018 bill proposed an expansive law based closely on the GDPR.
# - Reduction in prescriptive requirements and overall compliance should be seen in the context of a shift away from criminalization.
# - The 2019 bill rationalized some provisions while retaining most of them and adding to the regulatory expanse.
# - The regulatory structure is based on the 2018 draft bill proposed by the Srikrishna Committee.
# - The 2018 and 2019 bills provided for monetary penalties.
# - The board should create certain checks and balances for issuing directions.
# - The DPDP Act is based on a draft proposed by the government in November 2022.
# - Notices will be given to consumers.
# - Entities processing data can do so by taking the concerned individual's consent.
# - Businesses will inform consumers and the DPB about data breaches.

# %%
topic = "DPDP-chunks"
desc = {
    'fullform': 'Digital Privacy Data Protection Act; but with chunks',
}
topic_2_collection = chroma_client.get_or_create_collection(name=topic, embedding_function=emb_fn, metadata={"hnsw:space": "cosine"})

# %%
chunks
# Out:
# ['Understanding India’s New Data Protection Law\nANIRUDH BURMAN\nOCTOBER 03, 2023\nPAPER\nSource: Getty\nSummary:  In early August 2023, the Indian Parliament passed the Digital Personal Data Protection (DPDP) Act, 2023. This working paper analyzes the law and evaluates its development over more than half a decade of deliberations.\nRelated Media and Tools\nPrint Page\nINTRODUCTION\nIn early August 2023, the Indian Parliament passed the Digital Personal Data Protection (DPDP) Act, 2023.1 The new law is the first cross-sectoral law on personal data protection in India and has been enacted after more than half a decade of deliberations.2 The key question this paper discusses is whether this seemingly interminable period of deliberations resulted in a “good” law—whether the law protects personal data adequately, and in addition, whether it properly balances, as the preamble to the law states, “the right of individuals to protect their personal data” on one hand and “the need to process such personal data for lawful purposes” on the other.\n\nTo answer this question, the paper first details the key features of the law and compares it to earlier versions, especially the previous official bill introduced by the government in Parliament in 2019.3 The second part of the paper then examines the DPDP Act from two perspectives. First, it highlights certain potentially problematic features of this law to understand its consequences for consumers and businesses as well as the Indian state. Second, it places the act in context of the developments and deliberations that have taken place over the last five years or so. The third part speculates on the key factors that will influence the development of data protection regulation in India in the next few years.\n\nThe 2023 act is the second version of the bill introduced in Parliament, and fourth overall. An initial version was prepared by a committee of experts and circulated for public feedback in 2018.4 This was followed by the government’s version of the bill that was introduced in Parliament in 2019—the Personal Data Protection Bill, 2019. This version was studied by a parliamentary committee that published its report in December 2021.5 The government, however, withdrew this bill, and in November 2022, published a fresh draft for public consultations—the draft Digital Personal Data Protection Bill, 2022.6 This draft was quite different compared to the previous versions. The 2023 law is based, in significant part, on this draft. However, it has some new provisions that are consequential for the questions this paper seeks to answer.\n\nAnirudh Burman\nAnirudh Burman is an associate research director and fellow at Carnegie India. He works on key issues relating to public institutions, public administration, the administrative and regulatory state, and state capacity.\nThese four drafts were preceded by a landmark 2017 judgment by India’s Supreme Court in Justice K.S. Puttaswamy and Anr. v. Union of India and Ors.7 The judgment declared that the right to privacy is part of the fundamental right to life in India and that the right to informational privacy is part of this right. The judgment, however, did not describe the specific contours of the right to informational privacy, and it also did not lay down specific mechanisms through which this right was to be protected.\n\nFollowing this, the first government version of the law, the Personal Data Protection Bill, 2019, was introduced in Parliament in December 2019. This version was expansive in scope and proposed cross-sectoral, economy-wide data protection regulation to be overseen by an all-powerful data protection regulator—the Data Protection Authority (DPA). The 2019 bill provided for a preventive framework.8 It imposed a number of obligations on entities collecting personal data—to provide notice and take consent from individuals, to store accurate data in a secure manner, and to use it only for purposes listed in the notice. Businesses w ...
#  'Businesses were also required to delete data once the purpose was satisfied and to provide consumers rights to access, erase, and port their data. Businesses were required to maintain security safeguards and transparency requirements, implement “privacy by design” requirements, and create grievance redress systems. Finally, this bill introduced an entity known as “consent managers,” who were intermediaries for collecting and providing consent to businesses on behalf of individuals.9\n\nThe bill grouped personal data into different categories and required elevated levels of protection for “sensitive” and “critical” personal data. Certain businesses were also to be categorized as “significant data fiduciaries,” and additional obligations were proposed for them—registration in India, data audits, and data impact assessments. In addition, the bill imposed localization restrictions on the cross-border flows of certain categories of data. The DPA was empowered to impose penalties on businesses for violating these requirements. The bill also proposed to criminalize activities related to the deanonymization of individuals from anonymized datasets.\n\nThe 2019 bill exempted certain entities and businesses from notice and consent requirements under certain circumstances—for lawful state functions, medical and health services during emergencies or epidemics, breakdown of public order, employment-related data processing, the prevention and detection of unlawful activity, whistleblowing, and credit recovery, among others.\n\nThe 2019 bill also had a provision to empower the government to regulate nonpersonal data. It allowed the government to require private entities to hand over specific nonpersonal data that the government asked for as per conditions it prescribed. In short, the 2019 bill proposed a comprehensive, cross-sectoral framework based on preventive requirements for businesses (defined as “data fiduciaries”) and rights for individuals or consumers (“data principals”).\n\nThis regulatory structure was based mostly on the 2018 draft bill proposed by the Srikrishna Committee—the committee, chaired by Justice B.N. Srikrishna, a retired Supreme Court judge, was set up by the Ministry of Electronics & Information Technology in July 2017 to help frame data protection norms. The recommendations of this committee, in turn, were based on major regulatory developments that were popular while the work of the committee was proceeding. Primary among these was the European Union’s (EU’s) General Data Protection Regulation (GDPR).10 While the general preventive framework of the 2019 bill was welcome, its expansive scope was problematic. It created a number of significant compliance requirements that would have affected both big and small firms in the economy. It also proposed the creation of a DPA that had significant regulation-making and supervisory powers. These regulations would have further detailed the already significant compliance requirements in the bill. The novelty of the law and the lack of prior experience in implementing a data protection law of this nature would have created serious risks of overregulation or under-regulation.11\n\nThe DPDP Act is based on the draft proposed by the government in November 2022, which adopted a radically different approach to data protection regulation.12 The next section details the key provisions of the act.\n\nKEY FEATURES OF THE DPDP ACT, 2023\nCompared to the 2019 version of the bill, the DPDP Act, 2023 is more modest—it has reduced obligations for businesses and protections for consumers. On the one hand, the regulatory structure is simpler, but on the other, it vests the central government with unguided discretionary powers in some cases.\n\nApplicability to Nonresidents\n\nThe DPDP Act applies to Indian residents and businesses collecting the data of Indian residents. Interestingly, it also applies to non-citizens living in India whose data processing “in connection with any activity rela ...
#  'citizen residing in India being provided digital goods or services within India by a provider based outside India.\n\nPurposes of Data Collection and Processing\n\nThe 2023 act allows personal data to be processed for any lawful purpose.14 The entity processing data can do so either by taking the concerned individual’s consent or for “legitimate uses,” a term that has been explained in the law.\n\nConsent must be “free, specific, informed, unconditional and unambiguous with a clear affirmative action” and for a specific purpose. The data collected has to be limited to that necessary for the specified purpose. A clear notice containing these details has to be provided to consumers, including the rights of the concerned individual and the grievance redress mechanism. Individuals have the right to withdraw consent if consent is the ground on which data is being processed.\n\nLegitimate uses are defined as: (a) a situation where an individual has voluntarily provided personal data for a specified purpose; (b) the provisioning of any subsidy, benefit, service, license, certificate, or permit by any agency or department of the Indian state, if the individual has previously consented to receiving any other such service from the state (this is a potential issue since it enables different government agencies providing these services to access personal data stored with other agencies of the government);15 (c) sovereignty or security; (d) fulfilling a legal obligation to disclose information to the state; (e) compliance with judgments, decrees, or orders; (f) medical emergency or threat to life or epidemics or threat to public health; and (g) disaster or breakdown of public order.16\n\nRights of Users/Consumers of Data-Related Products and Services\n\nThe DPDP Act also creates rights and obligations for individuals.17 These include the right to get a summary of all the collected data and to know the identities of all other data fiduciaries and data processors with whom the personal data has been shared, along with a description of the data shared. Individuals also have the right to correction, completion, updating, and erasure of their data. Besides, they have a right to obtain redress for their grievances and a right to nominate persons who will receive their data.\n\nObligations on Data Fiduciaries\n\nEntities responsible for collecting, storing, and processing digital personal data are defined as data fiduciaries and have defined obligations. These include: (a) maintaining security safeguards; (b) ensuring completeness, accuracy, and consistency of personal data; (c) intimation of data breach in a prescribed manner to the Data Protection Board of India (DPB); (d) data erasure on consent withdrawal or on the expiry of the specified purpose; (e) the data fiduciary having to appoint a data protection officer and set up grievance redress mechanisms; and (f) the consent of the parent/guardian being mandatory in the case of children/minors (those under eighteen years of age). The DPDP Act also states that any processing that is likely to have a detrimental effect on a child is not permitted. The law prohibits tracking, behavioral monitoring, and targeted advertising directed at children.18 The government can prescribe exemptions from these requirements for specified purposes. This is potentially a problem since the powers to exempt are broad and without any guidelines.\n\nWhile the 2023 act retains the broad categories of obligations for the most part, the key difference from the 2019 bill is the absence of the scope for the regulator, the DPA, to make detailed regulations on these obligations. In addition, the substantive requirements under each of these categories have been reduced.\n\nThere is an additional category of data fiduciaries known as significant data fiduciaries (SDFs). The government will designate data fiduciaries as SDFs based on certain criteria—volume and sensitivity of data and risks to data protection rights, sovereig ...
#  'The 2019 bill required that SDFs register in India. This requirement has been removed from the 2023 act.\n\nModeration of Data Localization Requirements\n\nThe 2023 law reverses course on the issue of data localization. While the 2019 bill restricted certain data flows, the 2023 law only states that the government may restrict flows to certain countries by notification. While this is not explicit, the power to restrict data flows seems to be to provide the government necessary legal powers for national security purposes. The law also states that this will not impact measures taken by sector-specific agencies that have or may impose localization requirements. For example, the Reserve Bank of India’s localization requirements will continue to be legally valid.\n\nExemptions From Obligations Under the Law\n\nThe law provides exemptions from consent and notice requirements as well as most obligations of data fiduciaries and related requirements in certain cases: (a) where processing is necessary for enforcing any legal right or claim; (b) personal data has to be processed by courts or tribunals, or for the prevention, detection, investigation, or prosecution of any offenses; (c) where the personal data of non-Indian residents is being processed within India; and so on.20\n\nIn addition, the law exempts certain purposes and entities completely from its purview.21 These include:\n\nProcessing in the interests of the sovereignty and integrity of India, security of the state, friendly relations with foreign states, maintenance of public order, or preventing incitement to any cognizable offense. This will allow investigative and security agencies to remain outside the purview of this law.\nData processing necessary for research, archiving, or statistical purposes if the personal data is not to be used to take any decision specific to a data principal.\nThe government can exempt certain classes of data fiduciaries, including startups, from some provisions—notice, completeness, accuracy, consistency, and erasure.\nOne problematic provision allows the government to, “before expiry of five years from the date of commencement of this Act,” declare that any provision of this law shall not apply to such data fiduciary or classes of data fiduciaries for such period as may be specified in the notification. This is a significant and wide discretionary power and is not circumscribed by any guidance on the basis for such exemption, the categories that may be exempted, and the time period for which such exemptions can operate.\nNew Regulatory Structure for Regulating Data Privacy\n\nThe 2023 law completely changes the proposed regulatory institutional design. The 2019 bill proposed an independent regulatory agency. The DPA was proposed on the lines of similar government agencies in many EU countries that function independently of government and implement the GDPR. The proposed Indian DPA was arguably more powerful since it was proposed to have much more extensive regulation-making powers than DPAs under the GDPR. In addition to framing regulations, the DPA would have been responsible for framing codes of conduct for businesses, investigating cases of noncompliance, collecting supervisory information, and imposing penalties on businesses.\n\nIn contrast, the 2023 law establishes the DPB.22 The board is not a regulatory entity and is very different from the DPA. Compared to the latter, the board has a limited mandate to oversee the prevention of data breaches and direct remedial action and to conduct inquiries and issue penalties for noncompliance with the law.23 The board does not have any powers to frame regulations or codes of conduct or to call for information to supervise the workings of businesses. It can only do so during the process of conducting inquiries.\n\nThe members of the board will be appointed by the government, and the terms and conditions of their service will be prescribed in rules made by the government.24 The law states that t ...
#  'In addition to monetary penalties, the bill allows data fiduciaries to provide voluntary undertakings to the board as a form of settlement of any complaints against them.26 Therefore, the board is a very different institution in design compared to the DPA.\n\nFinally, the 2023 law contains a novel provision not included or discussed in any previous version. This is Section 37, which allows the government, based on a reference from the board, to block the public’s access to any information that enables a data fiduciary to provide goods or services in India. This has to be based on two criteria: (a) the board has imposed penalties against such data fiduciaries on two or more prior occasions, and (b) the board has recommended a blockage. The government has to provide the data fiduciary an opportunity to be heard before taking such action.\n\nANALYZING THE DPDP ACT, 2023\nThis section analyzes the 2023 act from two perspectives. First, it explains the broad structure of the law and highlights its key features and issues. Second, it contextualizes the law in the background of the different drafts proposed before this and elaborates upon the deliberations that have led to it.\n\nHow Well Does the DPDP Act, 2023, Protect Privacy?\n\nThe 2023 act creates, for the first time, a data privacy law in India. It requires consent to be taken before personal data is processed and provides a limited number of exceptions that are clearly enumerated in the law. It provides consumers the right to access, correct, update, and erase their data, in addition to a right to nomination. It creates additional safeguards for the processing of children’s data. For businesses, it creates purpose limitations and obligations to provide notice of data collection and processing and mandates security safeguards. The law requires the creation of grievance redress mechanisms by businesses. The DPB will also handle complaints and grievances and is empowered to issue penalties for noncompliance with the law.\n\nFor the first time, therefore, India has a statutory framework for data protection. The presence of the law will gradually lead to the development of minimal standards of behavior and compliance among businesses that collect data. In this regard, the approach of the government toward implementing and enforcing the law will be the critical variable—for example, whether implementation will be focused on data-heavy businesses or across the economy would be an important factor.\n\nHowever, other than open questions related to implementation, there are some concerns with different provisions of the law and their potential for undermining the protections seemingly accorded in it.\n\nFirst, the exceptions carved out for consent empower the state significantly and place state imperatives on a different pedestal compared to private entities. While this may be truly legitimate in some circumstances, like disasters or emergencies, the law enlarges the scope of such circumstances. For example, Section 7(b) of the law enables the government to sidestep consent requirements where a government service beneficiary has previously consented to receiving any other benefit from the state. While this may allow easier access to personal data of beneficiaries for receiving government services, it also creates a potential for the government to aggregate databases. This is because making true use of the potential of this provision would mean that government agencies would have to be exempted from purpose limitations that require personal data to be deleted after the purpose of the data has been satisfied.\n\nAnother example of this is the set of exemptions to the state for investigative, prosecutorial, and national security purposes. In Section 17(1)(c), the law exempts the requirements of notice and consent, among others, for the purposes of processing for “prevention, detection, investigation or prosecution of any offence or contravention of any law.”27 While this is understandab ...
#  'Given the fact that Section 17(1)(c) already exists, Section 17(2)(a) only indicates the desire of Parliament to ensure a complete non-application of the data protection law to certain state agencies.\n\nProvisions like these create a separate category of activity that is beyond the purview of data privacy requirements. It is problematic that the Indian state is not subject to many of the constraints that private entities are, especially in cases where there is no pressing requirement for such an exception.\n\nSecond, the discretionary rule-making powers that the government has under the law could, in some cases, undermine the protections provided in the law. For example, under Section 17(5), the government has the power to declare that any provisions of this law will not apply to any business or class of businesses within five years of the commencement of the law. There is no time frame for the operation of this exemption or any guidance on how this provision is to be used. An optimistic interpretation of this provision would suggest that this could be used to allow sunrise industries or startups some time to comply with the law. However, provision for this has already been made in Section 17(3), which provides limited exemptions to startups and other industries the government may notify. Therefore, Section 17(5) could potentially be used in a manner that defeats the purpose of the law. It is worth reiterating that the law only limits the government’s power to give these exemptions for an initial period of five years. It does not provide any limit on how long these exemptions can last for.\n\nSimilarly, the government has some unguided rule-making powers for exempting businesses from certain requirements regarding the processing of children’s data. Sections 9(1) to 9(3) specify certain requirements for the same—they require parental consent and prohibit profiling, among others. Section 9(4) allows the government to exempt any business or class of businesses from Sections 9(1) to 9(3) “subject to such conditions, as may be prescribed.” This provision, again, fails to indicate on what grounds this exemption will be given, how the conditions are to be determined, and so on. Since there is a lack of sufficient guidance, this provision is also subject to misuse.\n\nWhile there are other provisions where the government has powers to prescribe conditions and make substantive rules, the examples highlighted above provide almost no guidance. This is also problematic when judged against the tenets of Indian administrative law, which requires that laws should not confer unguided and excessive discretion on the implementing authority.28 If improperly used, such legal provisions are potentially in violation of the Indian Constitution.\n\nThird, the design of the DPB is problematic. The board is an independent agency with a limited mandate, and the government will create mechanisms for the selection and appointment of its members. While the law sets out qualifications for members, it does not state how many members shall be on the board and requires only one of them to be a legal expert. This last provision is a problem since one of the board’s main functions is to issue penalties and directions for noncompliance.\n\nIn addition, the chairperson of the DPB is empowered to authorize any board member to perform “any of the functions of the board and conduct any of its proceedings.” It is possible that the chairperson may not authorize the legal member of the board to conduct the proceedings leading up to the issuance of a penalty. This design also fails to maintain an internal separation of functions between the members conducting inquiries and the chairperson. Since the chairperson appoints members to conduct inquiries, they may potentially not discharge this function impartially in all cases.\n\nTherefore, while the DPDP Act creates data privacy protections in law for the first time, certain provisions in the law can effectively undermin ...
#  'This shift was most visible in the November 2022 draft bill and has now been enshrined in the 2023 law. There are three major axes on which this shift is visible.\n\n1. Reductions in rights and obligations, and compliance: The 2018 and 2019 versions of the bill adopted a more expansive and all-encompassing framework toward data protection. As the preceding sections of this paper explain, many of these rights and obligations have been either diluted or discarded—data portability, for example, has been completely removed, while others such as the right to be forgotten have been recast to a simpler right to “erasure.”\n\nDetailed prescriptions regarding the contents of notices and privacy by design requirements, among others, have been discarded, and it is now up to businesses to translate these requirements. This is a better and more innovation-friendly approach. Given the lack of prior data protection law and jurisprudence, firms will experiment with different approaches to translate them into business practices. The practices that do not meet the requirements of the DPDP Act will be adjudicated in the DPB, the TDSAT, and the courts. This process will provide for an organic emergence of good practices suited to the Indian context.\n\nThis reduction in prescriptive requirements and overall compliance should also be seen in the context of the shift away from criminalization. The 2018 bill created a number of criminal offenses. The 2019 bill reduced this to just one—deanonymization. The 2022 draft and the 2023 version do not provide for any criminal offenses and stipulate only monetary penalties to be directed by the DPB.\n\n2. A sharper focus on data privacy: The 2018 draft, and more so the 2019 draft, included several provisions that were only tangentially related to data privacy. For example, the provision mandating the sharing of nonpersonal data did not further privacy interests in any way. Similarly, data localization requirements have been shown to have only a tangential relationship to data privacy, and better alternatives exist to achieve the same objectives. Their presence in the 2018 and 2019 bills were a source of uncertainty. In addition, data localization became a proxy for debates on issues such as data sovereignty, something that, again, is not directly related to the issue of privacy.\n\n3. The abandonment of a “regulatory” law: The 2018 and 2019 bills created a legislative framework that had a high degree of regulatory intensity—the bills provided a full-fledged independent regulator, the DPA, with extensive powers to frame regulations and codes of conduct on many provisions within those bills, such as notice and consent requirements, security safeguards, manner of storage of data, and so on. In addition, the DPA would have had powers to collect information necessary for ensuring compliance with the law and impose penalties for noncompliance. The DPA, therefore, was proposed to have many more touchpoints with the economy, and its mandate, by definition, required it to be relatively more interventionist.\n\nThese legislative proposals made the DPA a centerpiece of the regulatory framework, and the agency was expected to function like other Indian independent regulators, such as the Securities and Exchange Board of India and the Telecom Regulatory Authority of India. The DPA was expected to exercise these powers across all sectors of the Indian economy. It would have had to prescribe standards for all the legal provisions that provided for standard-setting requirements through regulations, modify and update them periodically, conduct the necessary stakeholder consultations across different economic sectors, create or identify research to support its regulatory agenda, and build its regulatory legitimacy. The proposed legislative role of the DPA in 2018 and 2019 was thus one of high regulatory intensity. Given this wide remit, it would have faced obvious challenges related to deciding on its overall approach, prio ...
#  'The DPDP Act does away with the idea of an independent regulator like the DPA. The DPB does not have many regulation-making powers under this law. Its powers are limited to ensuring remedial actions against any data breaches and issuing directions to businesses requiring them to comply with the law. In addition, the DPB can pass orders issuing penalties or imposing voluntary settlements for noncompliance with the law. This is not a design that is “regulatory” in the same way as the proposed DPA in the 2018 and 2019 versions and is a major shift in approach. The DPB’s limited mandate will create less frequent touchpoints with the economy even though its orders regarding compliance or noncompliance will be extremely consequential.\n\nThese shifts have occurred incrementally over the last few years. The 2018 bill proposed an expansive law based closely on the GDPR. The 2019 bill rationalized some provisions while retaining most of them and adding to the regulatory expanse. It imported concerns that were at best tangential to privacy concerns in some cases. The 2022 bill and the 2023 act are a major shift away from this expansive framework. This indicates a change in how Parliament and the Indian government now view the salience of the data protection law to India’s economy. In 2017 and 2018, there were a few animating factors that led to the early versions of the bill. The Supreme Court had recently declared privacy to be a fundamental right and was about to rule on the constitutionality of India’s biometric ID project, Aadhaar. In addition, there was a global debate on data protection regulation sparked off by the impending implementation of the GDPR. The regulation was enacted in 2016 and came into force in 2018. At that point in time, it was viewed as a viable template for adoption and influenced deliberations on the Indian law.29\n\nBy 2022, the GDPR had been in effect for four years, and numerous issues with its design and implementation had been voiced.30 The Indian Supreme Court had upheld the use of Aadhaar for certain purposes and the potential constitutional law issues had been resolved. Arguably, deliberations on the different versions of the data protection legislation also allowed concerns about the proposed framework to be articulated consistently. This was especially visible on issues such as data localization.31 The long period of deliberations, therefore, allowed the shift to a more pragmatic version of the law to be finally enacted.\n\nHowever, one part of the government’s approach toward the law has remained noticeably consistent—the exemptions given for state functions. State surveillance agencies have been consistently exempted from the application of data protection requirements. The 2018 draft bill sought to narrow the scope of exemptions and proposed some checks and balances, which were diluted in the 2019 bill. The 2019 bill instead gave the central government the power to exempt any national security agency from any or all provisions of the proposed legislation. A similar provision has now been enacted into the law—other non-security-related government uses of data will continue to be exempted from certain parts of the law. Lastly, as pointed out earlier, the DPDP Act also gives the government problematic levels of unfettered discretion in some cases.\n\nThe next part of this paper speculates on how two developing strains of data-related regulation—the working of the data protection law and the concerns of national security and sovereignty—are likely to inform the next stage of data regulation in India.\n\nLOOKING FORWARD TO THE IMPLEMENTATION OF THE DATA PROTECTION LAW\nNow that the DPDP Act is law, there will be three key sources of regulatory development under the same.\n\nThe first will be the rules framed by the central government to implement the law. The DPDP Act provides significant rule-making powers to the central government. These include:\n\nthe manner in which notices will be given to cons ...
#  'These include:\n\nthe manner in which notices will be given to consumers;32\nthe manner in which consent managers will function;33\nthe manner in which businesses will inform their consumers and the DPB about data breaches;34\nthe manner in which parental consent will be sought for processing children’s data and related exemptions;35\nthe manner in which consumers will exercise their rights against data fiduciaries;36\nthe manner of appointment of DPB members, the terms and conditions of their service, and the procedures for the functioning of the board;37\ndata impact assessments and other measures to be taken by significant data fiduciaries;38 and\nthe procedure to be followed by the appellate tribunal, the TDSAT, in hearing appeals from the DPB.39\nThese are not insignificant powers. However, as already discussed, these powers of rule-making pale in comparison to the ones that were proposed to be given to the DPA under the previously proposed versions of the law. The intensity of regulation will, therefore, be much lower under the DPDP Act than it would have been under the 2019 bill. In creating this framework, the Indian Parliament has opted for a modest approach to creating elaborate rules and regulations. This will consequentially allow greater scope for experimentation and innovation in the Indian technology landscape relative to the 2019 bill and its predecessor.\n\nWhile many of these powers pertain to procedural issues, the central government has substantive rule-making powers as well. The fact that these rule-making powers are with the central government is problematic.\n\nThe most consequential of these is the power to grant exemptions. The exercise of this power will be contingent on two factors—the degree of technocratic competency within the relevant departments of the central government and the degree to which the relevant officers can function autonomously and technocratically. Historically, the Indian state’s response to improve competence and autonomy in economic regulation has been to move these functions to independent regulatory agencies. In this case, however, such powers have been retained with the central government.\n\nOn the other hand, the lack of any prior regulatory expertise on data protection also lends itself to an argument in favor of greater political inputs at an incipient stage of regulatory development. Historically, the Indian government directly regulated many subjects before transferring them to independent regulators and, in the process, developed a certain degree of institutional capability within the relevant departments. This has been the case for various subjects such as insurance, pension, telecom, electricity, and so on. While these departments did not necessarily regulate well, the exercise of these powers did create some technical and supervisory capacity within the relevant departments.\n\nThe critical consideration, therefore, is whether the drafters of the DPDP Act consider the framework under the law as a first step in the development of an independent regulator.\n\nThe second key source of regulatory development will be the decisions of the DPB in cases where it initiates an inquiry against regulated entities. The reasoning of the DPB and the penalties and directions it issues will be the first set of decisions on data privacy regulation under a new law. These decisions will not just contribute to jurisprudence on the subject but also provide guidance to businesses on how to implement and comply with the DPDP Act. The procedures the board follows, the quality of its reasoning, and the clarity of its decisions will shape both market behavior and future regulation in India.\n\nIn this regard, the composition of the board and the qualifications of its members conducting inquiries will be critical. The law has definite weaknesses in this regard, as discussed earlier. The proper implementation of the law will, therefore, depend on the government adopting best practices in app ...
#  'While the DPDP Act requires the board to observe certain specified procedural rules while conducting inquiries and issuing penalties, it does not provide any such guidance for issuing directions to regulated entities. This is problematic since directions will also be binding and impose compliance costs. It is, therefore, appropriate that the board should create certain checks and balances for issuing directions. At the very least, the board should provide any regulated entity with a formal opportunity to furnish their response to a draft direction before such a direction is formally issued to them. Absent this, the board may develop a predilection toward regulation by direction.\n\nThe trajectory of these three strands of regulatory decision-making will significantly shape India’s technology markets and data-related policy for the next few years. Since the law does not contain adequate checks and balances, the onus will be on the central government to ensure that best practices in administrative law and decisionmaking are incorporated via the procedural rules that the DPDP Act empowers it to make.\n\nThe other main factor that will shape the development of data protection regulation will be the larger imperatives of exercising sovereign control over data and data businesses in India. The development of the DPDP Act was significantly influenced by the call to exercise control over Indian data for the benefit of Indians. This was most visible during the debate on issues related to data localization and nonpersonal data. While the provisions in the final law represent a significant moderation from the provisions in the draft proposals, the larger concerns over sovereignty and security will influence the development of this law.\n\nOne clear example of this is Section 37 of the law that enables the central government to block access to any information that can be communicated by a data fiduciary. This is a new insertion, and it is highly debatable whether this provision has any relevance to personal data privacy.\n\nOutside the DPDP Act, the evolving framework of laws regulating social media companies, IT services, and businesses, among others, will also exercise indirect influence on how data protection regulation develops. In 2021, the Indian government issued new guidelines for social media intermediaries that required, among others, measures to trace originators of social media content on over-the-top (OTT) messaging platforms. These requirements were challenged in courts and a final decision is awaited. The outcome will determine the nature and scope of the powers enjoyed by investigative agencies under the exemptions granted by the DPDP Act.\n\nAnother example is that of data localization. While the DPDP Act does not restrict data flows across borders, many Indian sectoral regulators, like the Reserve Bank of India, do impose localization requirements. The progressive adoption of localization by other regulators may make the liberal provisions of the DPDP Act superfluous.\n\nSome legal requirements aimed at regulating social media and big tech companies are emanating organically due to India’s rapid digital transformation in the past decade and the fact that the regulatory framework is outdated.40 India’s IT minister has stated that a replacement to India’s Information Technology Act, 2000 is in the works. This newer version of the IT Act, as well as other similar legislations, is also likely to influence the working of the DPDP Act. In each of these developments, it will be important to ensure that the nature and scope of sovereign control to be exercised is for a legitimate purpose and that it does not overserve the needs of the Indian state to the detriment of privacy, commerce, and innovation.\n\nCONCLUSION\nWhile the DPDP Act is a culmination of more than five years of debate and deliberation, it marks the start of statutory personal data protection regulation. The regulatory developments and the institutional arrange ...

# %%
topic_2_collection.add(
    documents=chunks,
    metadatas=[{
        'topic': topic,
    } for x in chunks],
    ids=[f'{i}' for i in range(len(chunks))]
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
PROMPT_FOR_TOP_K = (
    "Some information on <<topic>> is provided below. The information is of the form of excerpts from an article. "
    "Answer the user query using the information provided.\n"
    "---------------------\n"
    "<<chunks>>\n"
    "---------------------\n"
    "User query: <<query>>\n"
    "Response: "
)
print(PROMPT_FOR_TOP_K)
# Out:
# Some information on <<topic>> is provided below. The information is of the form of excerpts from an article. Answer the user query using the information provided.
# ---------------------
# <<chunks>>
# ---------------------
# User query: <<query>>
# Response:

# %%
def _query2(query, n_results=2):
    return topic_2_collection.query(query_texts=[query], n_results=n_results)['documents'][0]

# %%
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ['In addition to monetary penalties, the bill allows data fiduciaries to provide voluntary undertakings to the board as a form of settlement of any complaints against them.26 Therefore, the board is a very different institution in design compared to the DPA.\n\nFinally, the 2023 law contains a novel provision not included or discussed in any previous version. This is Section 37, which allows the government, based on a reference from the board, to block the public’s access to any information that enables a data fiduciary to provide goods or services in India. This has to be based on two criteria: (a) the board has imposed penalties against such data fiduciaries on two or more prior occasions, and (b) the board has recommended a blockage. The government has to provide the data fiduciary an opportunity to be heard before taking such action.\n\nANALYZING THE DPDP ACT, 2023\nThis section analyzes the 2023 act from two perspectives. First, it explains the broad structure of the law and highlights its key features and issues. Second, it contextualizes the law in the background of the different drafts proposed before this and elaborates upon the deliberations that have led to it.\n\nHow Well Does the DPDP Act, 2023, Protect Privacy?\n\nThe 2023 act creates, for the first time, a data privacy law in India. It requires consent to be taken before personal data is processed and provides a limited number of exceptions that are clearly enumerated in the law. It provides consumers the right to access, correct, update, and erase their data, in addition to a right to nomination. It creates additional safeguards for the processing of children’s data. For businesses, it creates purpose limitations and obligations to provide notice of data collection and processing and mandates security safeguards. The law requires the creation of grievance redress mechanisms by businesses. The DPB will also handle complaints and grievances and is empowered to issue penalties for noncompliance with the law.\n\nFor the first time, therefore, India has a statutory framework for data protection. The presence of the law will gradually lead to the development of minimal standards of behavior and compliance among businesses that collect data. In this regard, the approach of the government toward implementing and enforcing the law will be the critical variable—for example, whether implementation will be focused on data-heavy businesses or across the economy would be an important factor.\n\nHowever, other than open questions related to implementation, there are some concerns with different provisions of the law and their potential for undermining the protections seemingly accorded in it.\n\nFirst, the exceptions carved out for consent empower the state significantly and place state imperatives on a different pedestal compared to private entities. While this may be truly legitimate in some circumstances, like disasters or emergencies, the law enlarges the scope of such circumstances. For example, Section 7(b) of the law enables the government to sidestep consent requirements where a government service beneficiary has previously consented to receiving any other benefit from the state. While this may allow easier access to personal data of beneficiaries for receiving government services, it also creates a potential for the government to aggregate databases. This is because making true use of the potential of this provision would mean that government agencies would have to be exempted from purpose limitations that require personal data to be deleted after the purpose of the data has been satisfied.\n\nAnother example of this is the set of exemptions to the state for investigative, prosecutorial, and national security purposes. In Section 17(1)(c), the law exempts the requirements of notice and consent, among others, for the purposes of processing for “prevention, detection, investigation or prosecution of any offence or contravention of any law.”27 While this is understandab ...
#  'The 2019 bill required that SDFs register in India. This requirement has been removed from the 2023 act.\n\nModeration of Data Localization Requirements\n\nThe 2023 law reverses course on the issue of data localization. While the 2019 bill restricted certain data flows, the 2023 law only states that the government may restrict flows to certain countries by notification. While this is not explicit, the power to restrict data flows seems to be to provide the government necessary legal powers for national security purposes. The law also states that this will not impact measures taken by sector-specific agencies that have or may impose localization requirements. For example, the Reserve Bank of India’s localization requirements will continue to be legally valid.\n\nExemptions From Obligations Under the Law\n\nThe law provides exemptions from consent and notice requirements as well as most obligations of data fiduciaries and related requirements in certain cases: (a) where processing is necessary for enforcing any legal right or claim; (b) personal data has to be processed by courts or tribunals, or for the prevention, detection, investigation, or prosecution of any offenses; (c) where the personal data of non-Indian residents is being processed within India; and so on.20\n\nIn addition, the law exempts certain purposes and entities completely from its purview.21 These include:\n\nProcessing in the interests of the sovereignty and integrity of India, security of the state, friendly relations with foreign states, maintenance of public order, or preventing incitement to any cognizable offense. This will allow investigative and security agencies to remain outside the purview of this law.\nData processing necessary for research, archiving, or statistical purposes if the personal data is not to be used to take any decision specific to a data principal.\nThe government can exempt certain classes of data fiduciaries, including startups, from some provisions—notice, completeness, accuracy, consistency, and erasure.\nOne problematic provision allows the government to, “before expiry of five years from the date of commencement of this Act,” declare that any provision of this law shall not apply to such data fiduciary or classes of data fiduciaries for such period as may be specified in the notification. This is a significant and wide discretionary power and is not circumscribed by any guidance on the basis for such exemption, the categories that may be exempted, and the time period for which such exemptions can operate.\nNew Regulatory Structure for Regulating Data Privacy\n\nThe 2023 law completely changes the proposed regulatory institutional design. The 2019 bill proposed an independent regulatory agency. The DPA was proposed on the lines of similar government agencies in many EU countries that function independently of government and implement the GDPR. The proposed Indian DPA was arguably more powerful since it was proposed to have much more extensive regulation-making powers than DPAs under the GDPR. In addition to framing regulations, the DPA would have been responsible for framing codes of conduct for businesses, investigating cases of noncompliance, collecting supervisory information, and imposing penalties on businesses.\n\nIn contrast, the 2023 law establishes the DPB.22 The board is not a regulatory entity and is very different from the DPA. Compared to the latter, the board has a limited mandate to oversee the prevention of data breaches and direct remedial action and to conduct inquiries and issue penalties for noncompliance with the law.23 The board does not have any powers to frame regulations or codes of conduct or to call for information to supervise the workings of businesses. It can only do so during the process of conducting inquiries.\n\nThe members of the board will be appointed by the government, and the terms and conditions of their service will be prescribed in rules made by the government.24 The law states that t ...

# %%
def ask_query2(query, n_results=2):
    chunks = "\n".join(_query2(query, n_results))
    prompt = PROMPT_FOR_TOP_K.replace("<<topic>>", topic).replace("<<chunks>>", chunks).replace("<<query>>", query)
    resp = llm.complete(prompt).text
    return resp

# %%
print(ask_query('What are the different aspects of DPDP?, write it in a simple language to describe in an article'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The DPDP (Data Protection and Privacy) Act is a law in India that aims to protect personal data. It is the first law in India that covers personal data protection across different sectors. The Act does away with the idea of having an independent regulator and instead establishes the DPB (Data Protection Board) as a regulatory entity. The DPB has the power to issue penalties or impose settlements for noncompliance with the law. The Act also requires the board to follow certain procedural rules when conducting inquiries and issuing penalties.
#
# The 2018 and 2019 drafts of the Act included provisions that were not directly related to data privacy. However, the 2019 bill proposed a comprehensive framework for data protection, focusing on preventive requirements for businesses and rights for individuals. The regulatory structure of the Act is based on the 2018 draft bill proposed by the Srikrishna Committee.
#
# The Act aims to balance the right of individuals to protect their personal data with the need to process such data for lawful purposes. It creates rights and obligations for individuals and businesses. Businesses are required to inform consumers and the DPB about data breaches, and consumers have the right to exercise their rights against data fiduciaries.
#
# The Act also addresses the issue of data localization, stating that the government may restrict data flows to certain countries. However, the 2023 law reverses course on data localization requirements.
#
# Overall, the DPDP Act is a significant step towards protecting personal data in India, but it also has some limitations and areas that need further improvement. The development of data protection regulation is influenced by larger imperatives and the need to balance various interests.

# %%
print(ask_query2('What are the different aspects of DPDP?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The different aspects of DPDP (Data Protection and Privacy) are as follows:
#
# 1. Regulatory Powers: The DPB (Data Protection Board) under the DPDP Act has limited regulation-making powers. Its main role is to ensure remedial actions against data breaches and issue directions to businesses for compliance with the law. It can also pass orders for penalties or voluntary settlements for noncompliance.
#
# 2. Shift in Approach: The DPDP Act represents a major shift in approach compared to previous versions of the law. It does away with the idea of an independent regulator like the DPA (Data Protection Authority) and focuses more on remedial actions and compliance.
#
# 3. Incremental Shifts: The development of the DPDP Act has occurred incrementally over the years. The 2018 and 2019 versions proposed an expansive law based on the GDPR (General Data Protection Regulation), while the 2022 and 2023 versions represent a more pragmatic approach.
#
# 4. Exemptions for State Functions: One consistent aspect of the government's approach to the law is the exemptions given for state functions. State surveillance agencies are exempted from data protection requirements, and non-security-related government uses of data are also exempted from certain parts of the law.
#
# 5. Rule-Making Powers: The central government has significant rule-making powers under the DPDP Act. These powers include framing rules for various aspects such as consumer notices, consent managers, data breaches, parental consent for children's data, consumer rights, appointment of DPB members, data impact assessments, and appellate tribunal procedures.
#
# 6. Checks and Balances: The DPDP Act lacks adequate checks and balances, especially for issuing directions to regulated entities. It is important for the DPB to create certain checks and balances to ensure fairness and compliance.
#
# 7. Sovereign Control over Data: The development of the DPDP Act was influenced by the larger imperatives of exercising sovereign control over data and data businesses in India. Concerns over sovereignty and security have influenced the law, including provisions related to data localization and blocking access to information.
#
# 8. Influence of Other Laws: The evolving framework of laws regulating social media companies, IT services, and businesses in India will also indirectly influence the development of data protection regulation. The outcome of challenges to new guidelines for social media intermediaries and the adoption of data localization by other regulators will impact the DPDP Act.
#
# Overall, the DPDP Act is a culmination of years of debate and deliberation, but its effectiveness in protecting personal data privacy will depend on regulatory developments, institutional arrangements, and the commitment of the government to privacy protection.

# %%
print(ask_query('What happens on non-compliance?', 30))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# On non-compliance, the DPB (Data Protection Board) can pass orders issuing penalties or imposing voluntary settlements for noncompliance with the law. The DPA (Data Protection Authority) would have had powers to impose penalties for noncompliance. The DPB's powers are limited to ensuring remedial actions against any data breaches and issuing directions to businesses requiring them to comply with the law. The DPDP Act also requires the board to observe certain specified procedural rules while conducting inquiries and issuing penalties.

# %%
print(ask_query2('List the categories DPDP defines?'))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The provided information does not mention any specific categories defined by DPDP (Data Protection and Privacy Act).
